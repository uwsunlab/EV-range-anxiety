# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def_up_test= pd.read_csv(r'test_results/def_up_test.csv')
def_down_test= pd.read_csv(r'test_results/def_down_test.csv')
def_flat_test= pd.read_csv(r'test_results/def_flat_test.csv')
asser_up_test= pd.read_csv(r'test_results/asser_up_test.csv')
asser_down_test= pd.read_csv(r'test_results/asser_down_test.csv')
asser_flat_test= pd.read_csv(r'test_results/asser_flat_test.csv')

# %%
def dataframe_test_gen(df):
    dr1_df= df[df['Step Index']==6].reset_index(drop=True)
    dr2_df= df[df['Step Index']==7].reset_index(drop=True)
    dr3_df= dr1_df[dr1_df['Step Time (s)']<902].reset_index(drop=True)
    return dr3_df, dr2_df

# %%
def dict_gen_test():
    list_arr=[]
    dr1, dr2 = dataframe_test_gen(def_up_test)
    dr3, dr4 = dataframe_test_gen(def_down_test)
    dr5, dr6 = dataframe_test_gen(def_flat_test)
    dr7, dr8 = dataframe_test_gen(asser_up_test)
    dr9, dr10 = dataframe_test_gen(asser_down_test)
    dr11, dr12 = dataframe_test_gen(asser_flat_test)
    list_arr.extend([
    dr1, dr2, dr3, dr4, dr5, dr6, dr7, dr8, dr9, dr10,
    dr11, dr12])
    dict={}
    for d in range (1,13):
        dict[d]= list_arr[d-1]
    return dict

# %%
dict_test= dict_gen_test()
dict_test
# Out:
# {1:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           14  \t05/24/2024 13:01:32.274       602.2645         0.0074
#  1           15  \t05/24/2024 13:01:32.774       602.7646         0.5075
#  2           16  \t05/24/2024 13:01:33.272       603.2628         1.0057
#  3           17  \t05/24/2024 13:01:33.774       603.7650         1.5079
#  4           18  \t05/24/2024 13:01:34.357       604.3483         2.0912
#  ..         ...                        ...            ...            ...
#  92         106  \t05/24/2024 13:16:01.852      1471.8426       869.5855
#  93         107  \t05/24/2024 13:16:11.855      1481.8455       879.5884
#  94         108  \t05/24/2024 13:16:21.855      1491.8456       889.5885
#  95         109  \t05/24/2024 13:16:31.857      1501.8483       899.5912
#  96         110  \t05/24/2024 13:16:32.272      1502.2633       900.0062
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           6            0            0            0
#  1             1           6            0            0            0
#  2             1           6            0            0            0
#  3             1           6            0            0            0
#  4             1           6            0            0            0
#  ..          ...         ...          ...          ...          ...
#  92            1           6            0            0            0
#  93            1           6            0            0            0
#  94            1           6            0            0            0
#  95            1           6            0            0            0
#  96            1           6            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN    -0.009360                        NaN
#  1             0  ...        NaN          NaN                        NaN
#  2             0  ...        NaN     0.041583                        NaN
#  3             0  ...        NaN          NaN                        NaN
#  4             0  ...        NaN     0.004589                        NaN
#  ..          ...  ...        ...          ...                        ...
#  92            0  ...        NaN    -0.000073                        NaN
#  93            0  ...        NaN    -0.000125                        NaN
#  94            0  ...        NaN    -0.009570                        NaN
#  95            0  ...        NaN     0.000149                        NaN
#  96            0  ...        NaN     0.004847                        NaN
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1            NaN           NaN              NaN              NaN
#  2      -0.004755   -210.289597              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4      -0.003644   -220.666504              NaN              NaN
#  ..           ...           ...              ...              ...
#  92           NaN           NaN              NaN              NaN
#  93           NaN           NaN              NaN              NaN
#  94     -0.824825           NaN              NaN              NaN
#  95           NaN           NaN              NaN              NaN
#  96     -0.050722     -4.923710              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              24.789080          -0.007026
#  1               NaN              24.789080          -0.007026
#  2               NaN              24.789080          -0.007026
#  3               NaN              24.789080          -0.007026
#  4               NaN              24.804414          -0.007026
#  ..              ...                    ...                ...
#  92              NaN              25.251290           0.012154
#  93              NaN              25.264089           0.004320
#  94              NaN              25.211380          -0.028850
#  95              NaN              25.227390          -0.001134
#  96              NaN              25.227390          -0.001134
#
#  [97 rows x 29 columns],
#  2:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0          136  \t05/24/2024 13:20:33.286      1743.2764         0.0082
#  1          137  \t05/24/2024 13:20:33.784      1743.7748         0.5066
#  2          138  \t05/24/2024 13:20:34.285      1744.2756         1.0074
#  3          139  \t05/24/2024 13:20:34.783      1744.7742         1.5060
#  4          140  \t05/24/2024 13:20:35.399      1745.3894         2.1212
#  ..         ...                        ...            ...            ...
#  95         231  \t05/24/2024 13:35:21.285      2631.2759       888.0077
#  96         232  \t05/24/2024 13:35:22.284      2632.2751       889.0069
#  97         233  \t05/24/2024 13:35:25.058      2635.0489       891.7807
#  98         234  \t05/24/2024 13:35:31.033      2641.0243       897.7561
#  99         235  \t05/24/2024 13:35:34.281      2644.2719       901.0037
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           7            0            0            0
#  1             1           7            0            0            0
#  2             1           7            0            0            0
#  3             1           7            0            0            0
#  4             1           7            0            0            0
#  ..          ...         ...          ...          ...          ...
#  95            1           7            0            0            0
#  96            1           7            0            0            0
#  97            1           7            0            0            0
#  98            1           7            0            0            0
#  99            1           7            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN    -0.011753                        NaN
#  1             0  ...        NaN          NaN                        NaN
#  2             0  ...        NaN     0.043615                        NaN
#  3             0  ...        NaN          NaN                        NaN
#  4             0  ...        NaN     0.004496                        NaN
#  ..          ...  ...        ...          ...                        ...
#  95            0  ...        NaN     0.000227                        NaN
#  96            0  ...        NaN     0.004039                        NaN
#  97            0  ...        NaN     0.003631                        NaN
#  98            0  ...        NaN     0.001723                        NaN
#  99            0  ...        NaN     0.001763                   0.079586
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1            NaN           NaN              NaN              NaN
#  2      -0.004518   -221.312897              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4      -0.004366   -231.332199              NaN              NaN
#  ..           ...           ...              ...              ...
#  95     -0.005296     -3.143915              NaN              NaN
#  96     -0.004866           NaN              NaN              NaN
#  97     -0.001511   -707.599182              NaN              NaN
#  98      0.009102     71.260048              NaN              NaN
#  99      0.025832     71.260048              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              25.135346          -0.002454
#  1               NaN              25.135350          -0.002456
#  2               NaN              25.135350          -0.002456
#  3               NaN              25.135350          -0.002456
#  4               NaN              25.135350          -0.002456
#  ..              ...                    ...                ...
#  95              NaN              24.882269          -0.003460
#  96              NaN              24.847284          -0.010933
#  97              NaN              24.828049          -0.006010
#  98              NaN              24.813760          -0.009472
#  99              NaN              24.853417           0.012392
#
#  [100 rows x 29 columns],
#  3:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           15  \t05/24/2024 13:01:55.411       612.2654        10.0026
#  1           16  \t05/24/2024 13:02:05.411       622.2657        20.0029
#  2           17  \t05/24/2024 13:02:15.414       632.2682        30.0054
#  3           18  \t05/24/2024 13:02:25.416       642.2706        40.0078
#  4           19  \t05/24/2024 13:02:35.419       652.2733        50.0105
#  ..         ...                        ...            ...            ...
#  86         101  \t05/24/2024 13:16:14.493      1471.3478       869.0850
#  87         102  \t05/24/2024 13:16:24.494      1481.3484       879.0856
#  88         103  \t05/24/2024 13:16:34.496      1491.3511       889.0883
#  89         104  \t05/24/2024 13:16:44.499      1501.3537       899.0909
#  90         105  \t05/24/2024 13:16:45.417      1502.2713       900.0085
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           6            0            0            0
#  1             1           6            0            0            0
#  2             1           6            0            0            0
#  3             1           6            0            0            0
#  4             1           6            0            0            0
#  ..          ...         ...          ...          ...          ...
#  86            1           6            0            0            0
#  87            1           6            0            0            0
#  88            1           6            0            0            0
#  89            1           6            0            0            0
#  90            1           6            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN    -0.000003                        NaN
#  1             0  ...        NaN    -0.001400                        NaN
#  2             0  ...        NaN    -0.000061                        NaN
#  3             0  ...        NaN    -0.000035                        NaN
#  4             0  ...        NaN    -0.000021                        NaN
#  ..          ...  ...        ...          ...                        ...
#  86            0  ...        NaN    -0.000066                        NaN
#  87            0  ...        NaN    -0.000101                        NaN
#  88            0  ...        NaN     0.001066                        NaN
#  89            0  ...        NaN     0.000042                        NaN
#  90            0  ...        NaN     0.005398                        NaN
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1       0.005035           NaN              NaN              NaN
#  2            NaN           NaN              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4            NaN           NaN              NaN              NaN
#  ..           ...           ...              ...              ...
#  86           NaN           NaN              NaN              NaN
#  87           NaN           NaN              NaN              NaN
#  88           NaN           NaN              NaN              NaN
#  89           NaN      0.000000              NaN              NaN
#  90     -0.327857     -2.047071              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              23.799002          -0.007263
#  1               NaN              23.839470          -0.000445
#  2               NaN              23.823700           0.012068
#  3               NaN              23.821194           0.000776
#  4               NaN              23.844120          -0.004129
#  ..              ...                    ...                ...
#  86              NaN              24.249360          -0.003784
#  87              NaN              24.278720           0.017428
#  88              NaN              24.235058          -0.001231
#  89              NaN              24.275776           0.021983
#  90              NaN              24.232869           0.021983
#
#  [91 rows x 29 columns],
#  4:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0          131  \t05/24/2024 13:20:56.421      1753.2758        10.0004
#  1          132  \t05/24/2024 13:21:06.422      1763.2766        20.0012
#  2          133  \t05/24/2024 13:21:16.422      1773.2767        30.0013
#  3          134  \t05/24/2024 13:21:26.424      1783.2791        40.0037
#  4          135  \t05/24/2024 13:21:36.425      1793.2793        50.0039
#  ..         ...                        ...            ...            ...
#  89         220  \t05/24/2024 13:35:30.926      2627.7808       884.5054
#  90         221  \t05/24/2024 13:35:31.923      2628.7774       885.5020
#  91         222  \t05/24/2024 13:35:33.940      2630.7944       887.5190
#  92         223  \t05/24/2024 13:35:42.961      2639.8161       896.5407
#  93         224  \t05/24/2024 13:35:47.425      2644.2798       901.0044
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           7            0            0            0
#  1             1           7            0            0            0
#  2             1           7            0            0            0
#  3             1           7            0            0            0
#  4             1           7            0            0            0
#  ..          ...         ...          ...          ...          ...
#  89            1           7            0            0            0
#  90            1           7            0            0            0
#  91            1           7            0            0            0
#  92            1           7            0            0            0
#  93            1           7            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN          NaN                        NaN
#  1             0  ...        NaN    -0.000706                        NaN
#  2             0  ...        NaN    -0.000060                        NaN
#  3             0  ...        NaN    -0.000117                        NaN
#  4             0  ...        NaN          NaN                        NaN
#  ..          ...  ...        ...          ...                        ...
#  89            0  ...        NaN     0.013699                        NaN
#  90            0  ...        NaN     0.004222                        NaN
#  91            0  ...        NaN     0.003269                        NaN
#  92            0  ...        NaN     0.000839                        NaN
#  93            0  ...        NaN     0.001290                   0.084159
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1       0.006374           NaN              NaN              NaN
#  2            NaN           NaN              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4            NaN           NaN              NaN              NaN
#  ..           ...           ...              ...              ...
#  89           NaN           NaN              NaN              NaN
#  90     -0.003922     -5.514528              NaN              NaN
#  91     -0.002682   -224.942001              NaN              NaN
#  92      0.012553   -547.102478              NaN              NaN
#  93      0.027571     63.686039              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              23.961620          -0.005252
#  1               NaN              23.977672           0.006565
#  2               NaN              23.974754          -0.011867
#  3               NaN              23.975210          -0.028147
#  4               NaN              23.976950           0.009951
#  ..              ...                    ...                ...
#  89              NaN              23.731440           0.012882
#  90              NaN              23.731441           0.012882
#  91              NaN              23.699590          -0.009954
#  92              NaN              23.685740          -0.000225
#  93              NaN              23.723270           0.001773
#
#  [94 rows x 29 columns],
#  5:      Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0            15  \t05/24/2024 13:02:02.067       602.7765         0.5082
#  1            16  \t05/24/2024 13:02:03.575       604.2845         2.0162
#  2            17  \t05/24/2024 13:02:13.576       614.2856        12.0173
#  3            18  \t05/24/2024 13:02:23.576       624.2861        22.0178
#  4            19  \t05/24/2024 13:02:33.578       634.2873        32.0190
#  ..          ...                        ...            ...            ...
#  104         119  \t05/24/2024 13:16:43.102      1483.8119       881.5436
#  105         120  \t05/24/2024 13:16:44.084      1484.7934       882.5251
#  106         121  \t05/24/2024 13:16:50.653      1491.3631       889.0948
#  107         122  \t05/24/2024 13:17:00.654      1501.3633       899.0950
#  108         123  \t05/24/2024 13:17:01.568      1502.2777       900.0094
#
#       Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0              1           6            0            0            0
#  1              1           6            0            0            0
#  2              1           6            0            0            0
#  3              1           6            0            0            0
#  4              1           6            0            0            0
#  ..           ...         ...          ...          ...          ...
#  104            1           6            0            0            0
#  105            1           6            0            0            0
#  106            1           6            0            0            0
#  107            1           6            0            0            0
#  108            1           6            0            0            0
#
#       TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0              0  ...        NaN    -0.001041                        NaN
#  1              0  ...        NaN    -0.005989                        NaN
#  2              0  ...        NaN    -0.001246                        NaN
#  3              0  ...        NaN    -0.000350                        NaN
#  4              0  ...        NaN    -0.000390                        NaN
#  ..           ...  ...        ...          ...                        ...
#  104            0  ...        NaN    -0.000105                        NaN
#  105            0  ...        NaN     0.004533                        NaN
#  106            0  ...        NaN     0.001058                        NaN
#  107            0  ...        NaN     0.000484                        NaN
#  108            0  ...        NaN     0.062091                        NaN
#
#       dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0        0.000047           NaN              NaN              NaN
#  1        0.000883    607.557617              NaN              NaN
#  2        0.017716           NaN              NaN              NaN
#  3             NaN     32.262859              NaN              NaN
#  4        0.065849           NaN              NaN              NaN
#  ..            ...           ...              ...              ...
#  104     -0.141536           NaN              NaN              NaN
#  105     -0.008939           NaN              NaN              NaN
#  106     -0.073198    -18.398411              NaN              NaN
#  107     -0.116617           NaN              NaN              NaN
#  108     -0.002464   -135.033401              NaN              NaN
#
#       MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0                NaN              24.703110           0.006699
#  1                NaN              24.703112           0.006699
#  2                NaN              24.707380           0.018744
#  3                NaN              24.709547          -0.007028
#  4                NaN              24.727762           0.009715
#  ..               ...                    ...                ...
#  104              NaN              25.208580           0.024170
#  105              NaN              25.208580           0.024170
#  106              NaN              25.170857          -0.020710
#  107              NaN              25.205103          -0.000226
#  108              NaN              25.205100          -0.000226
#
#  [109 rows x 29 columns],
#  6:      Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           149  \t05/24/2024 13:21:03.077      1743.7868         0.5090
#  1           150  \t05/24/2024 13:21:05.076      1745.7859         2.5081
#  2           151  \t05/24/2024 13:21:15.077      1755.7869        12.5091
#  3           152  \t05/24/2024 13:21:25.078      1765.7880        22.5102
#  4           153  \t05/24/2024 13:21:35.080      1775.7895        32.5117
#  ..          ...                        ...            ...            ...
#  128         277  \t05/24/2024 13:35:58.078      2638.7872       895.5094
#  129         278  \t05/24/2024 13:35:59.573      2640.2831       897.0053
#  130         279  \t05/24/2024 13:36:01.074      2641.7832       898.5054
#  131         280  \t05/24/2024 13:36:02.575      2643.2847       900.0069
#  132         281  \t05/24/2024 13:36:03.571      2644.2807       901.0029
#
#       Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0              1           7            0            0            0
#  1              1           7            0            0            0
#  2              1           7            0            0            0
#  3              1           7            0            0            0
#  4              1           7            0            0            0
#  ..           ...         ...          ...          ...          ...
#  128            1           7            0            0            0
#  129            1           7            0            0            0
#  130            1           7            0            0            0
#  131            1           7            0            0            0
#  132            1           7            0            0            0
#
#       TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0              0  ...        NaN    -0.001144                        NaN
#  1              0  ...        NaN    -0.004844                        NaN
#  2              0  ...        NaN    -0.000695                        NaN
#  3              0  ...        NaN    -0.000226                        NaN
#  4              0  ...        NaN    -0.000218                        NaN
#  ..           ...  ...        ...          ...                        ...
#  128            0  ...        NaN     0.007725                        NaN
#  129            0  ...        NaN     0.006618                        NaN
#  130            0  ...        NaN     0.003742                        NaN
#  131            0  ...        NaN     0.004745                        NaN
#  132            0  ...        NaN     0.004869                   0.422247
#
#       dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0        0.000050   4812.209961              NaN              NaN
#  1        0.001662    461.245911              NaN              NaN
#  2        0.004608           NaN              NaN              NaN
#  3        0.052396           NaN              NaN              NaN
#  4             NaN     25.408230              NaN              NaN
#  ..            ...           ...              ...              ...
#  128      0.002887    501.574890              NaN              NaN
#  129      0.005257    278.001587              NaN              NaN
#  130      0.005721    171.050095              NaN              NaN
#  131      0.006537    162.547607              NaN              NaN
#  132      0.007288    162.547607              NaN              NaN
#
#       MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0                NaN              24.866180           0.002693
#  1                NaN              24.911522           0.014169
#  2                NaN              24.993844           0.021631
#  3                NaN              24.930033          -0.010237
#  4                NaN              24.896056           0.001320
#  ..               ...                    ...                ...
#  128              NaN              24.720750           0.007238
#  129              NaN              24.684741          -0.011251
#  130              NaN              24.684738          -0.011252
#  131              NaN              24.702521           0.005556
#  132              NaN              24.702522           0.005558
#
#  [133 rows x 29 columns],
#  7:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           16  \t05/17/2024 14:18:59.195       602.2610         0.0074
#  1           17  \t05/17/2024 14:18:59.693       602.7586         0.5050
#  2           18  \t05/17/2024 14:19:00.192       603.2579         1.0043
#  3           19  \t05/17/2024 14:19:00.696       603.7618         1.5082
#  4           20  \t05/17/2024 14:19:01.251       604.3163         2.0627
#  ..         ...                        ...            ...            ...
#  92         108  \t05/17/2024 14:33:15.823      1458.8881       856.6345
#  93         109  \t05/17/2024 14:33:25.823      1468.8884       866.6348
#  94         110  \t05/17/2024 14:33:35.824      1478.8892       876.6356
#  95         111  \t05/17/2024 14:33:45.824      1488.8893       886.6357
#  96         112  \t05/17/2024 14:33:55.825      1498.8902       896.6366
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           6            0            0            0
#  1             1           6            0            0            0
#  2             1           6            0            0            0
#  3             1           6            0            0            0
#  4             1           6            0            0            0
#  ..          ...         ...          ...          ...          ...
#  92            1           6            0            0            0
#  93            1           6            0            0            0
#  94            1           6            0            0            0
#  95            1           6            0            0            0
#  96            1           6            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN    -0.009465                        NaN
#  1             0  ...        NaN          NaN                        NaN
#  2             0  ...        NaN     0.041001                        NaN
#  3             0  ...        NaN          NaN                        NaN
#  4             0  ...        NaN     0.018136                        NaN
#  ..          ...  ...        ...          ...                        ...
#  92            0  ...        NaN     0.000237                        NaN
#  93            0  ...        NaN     0.000008                        NaN
#  94            0  ...        NaN    -0.000012                        NaN
#  95            0  ...        NaN     0.000230                        NaN
#  96            0  ...        NaN     0.006882                        NaN
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1            NaN           NaN              NaN              NaN
#  2      -0.003985   -250.938004              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4      -0.004686   -232.258804              NaN              NaN
#  ..           ...           ...              ...              ...
#  92           NaN           NaN              NaN              NaN
#  93           NaN           NaN              NaN              NaN
#  94           NaN           NaN              NaN              NaN
#  95           NaN           NaN              NaN              NaN
#  96           NaN           NaN              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              24.885610           0.011234
#  1               NaN              24.885607           0.011234
#  2               NaN              24.885607           0.011234
#  3               NaN              24.814483          -0.022224
#  4               NaN              24.814470          -0.022231
#  ..              ...                    ...                ...
#  92              NaN              24.692420          -0.003147
#  93              NaN              24.711650           0.003237
#  94              NaN              24.685270           0.014582
#  95              NaN              24.675670          -0.016714
#  96              NaN              24.679863          -0.024652
#
#  [97 rows x 29 columns],
#  8:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0          138  \t05/17/2024 14:38:00.208      1743.2737         0.0114
#  1          139  \t05/17/2024 14:38:00.702      1743.7675         0.5052
#  2          140  \t05/17/2024 14:38:01.200      1744.2651         1.0028
#  3          141  \t05/17/2024 14:38:01.703      1744.7689         1.5066
#  4          142  \t05/17/2024 14:38:02.269      1745.3346         2.0723
#  ..         ...                        ...            ...            ...
#  93         231  \t05/17/2024 14:52:38.860      2621.9252       878.6629
#  94         232  \t05/17/2024 14:52:48.860      2631.9253       888.6630
#  95         233  \t05/17/2024 14:52:58.861      2641.9261       898.6638
#  96         234  \t05/17/2024 14:53:00.199      2643.2644       900.0021
#  97         235  \t05/17/2024 14:53:01.199      2644.2643       901.0020
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           7            0            0            0
#  1             1           7            0            0            0
#  2             1           7            0            0            0
#  3             1           7            0            0            0
#  4             1           7            0            0            0
#  ..          ...         ...          ...          ...          ...
#  93            1           7            0            0            0
#  94            1           7            0            0            0
#  95            1           7            0            0            0
#  96            1           7            0            0            0
#  97            1           7            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN    -0.018330                        NaN
#  1             0  ...        NaN          NaN                        NaN
#  2             0  ...        NaN     0.040930                        NaN
#  3             0  ...        NaN          NaN                        NaN
#  4             0  ...        NaN     0.004992                        NaN
#  ..          ...  ...        ...          ...                        ...
#  93            0  ...        NaN    -0.000122                        NaN
#  94            0  ...        NaN          NaN                        NaN
#  95            0  ...        NaN     0.003965                        NaN
#  96            0  ...        NaN     0.095494                        NaN
#  97            0  ...        NaN     0.114134                   0.081146
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1            NaN           NaN              NaN              NaN
#  2      -0.004834   -206.869507              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4      -0.004465   -231.392197              NaN              NaN
#  ..           ...           ...              ...              ...
#  93      1.895666           NaN              NaN              NaN
#  94           NaN           NaN              NaN              NaN
#  95           NaN           NaN              NaN              NaN
#  96           NaN           NaN              NaN              NaN
#  97     -0.097637     -3.139457              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              24.893748          -0.007013
#  1               NaN              24.893747          -0.007014
#  2               NaN              24.893750          -0.007014
#  3               NaN              24.893747          -0.007014
#  4               NaN              24.887035          -0.002099
#  ..              ...                    ...                ...
#  93              NaN              24.929611          -0.016159
#  94              NaN              24.940690          -0.007316
#  95              NaN              24.902764          -0.001003
#  96              NaN              24.886031          -0.005229
#  97              NaN              24.886030          -0.005229
#
#  [98 rows x 29 columns],
#  9:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           15  \t05/17/2024 14:19:55.778       612.2589        10.0011
#  1           16  \t05/17/2024 14:20:05.779       622.2598        20.0020
#  2           17  \t05/17/2024 14:20:15.779       632.2600        30.0022
#  3           18  \t05/17/2024 14:20:25.780       642.2607        40.0029
#  4           19  \t05/17/2024 14:20:35.781       652.2619        50.0041
#  ..         ...                        ...            ...            ...
#  90         105  \t05/17/2024 14:34:02.561      1459.0418       856.7840
#  91         106  \t05/17/2024 14:34:12.562      1469.0429       866.7851
#  92         107  \t05/17/2024 14:34:22.563      1479.0438       876.7860
#  93         108  \t05/17/2024 14:34:32.564      1489.0448       886.7870
#  94         109  \t05/17/2024 14:34:42.564      1499.0455       896.7877
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           6            0            0            0
#  1             1           6            0            0            0
#  2             1           6            0            0            0
#  3             1           6            0            0            0
#  4             1           6            0            0            0
#  ..          ...         ...          ...          ...          ...
#  90            1           6            0            0            0
#  91            1           6            0            0            0
#  92            1           6            0            0            0
#  93            1           6            0            0            0
#  94            1           6            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN     0.000029                        NaN
#  1             0  ...        NaN    -0.000501                        NaN
#  2             0  ...        NaN     0.000071                        NaN
#  3             0  ...        NaN    -0.000033                        NaN
#  4             0  ...        NaN    -0.000112                        NaN
#  ..          ...  ...        ...          ...                        ...
#  90            0  ...        NaN          NaN                        NaN
#  91            0  ...        NaN     0.003195                        NaN
#  92            0  ...        NaN     0.000024                        NaN
#  93            0  ...        NaN     0.000035                        NaN
#  94            0  ...        NaN    -0.000031                        NaN
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1       0.039717     45.392399              NaN              NaN
#  2      -0.006725           NaN              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4            NaN           NaN              NaN              NaN
#  ..           ...           ...              ...              ...
#  90           NaN           NaN              NaN              NaN
#  91           NaN           NaN              NaN              NaN
#  92           NaN           NaN              NaN              NaN
#  93           NaN           NaN              NaN              NaN
#  94           NaN           NaN              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              24.131420           0.003009
#  1               NaN              24.127240           0.000764
#  2               NaN              24.191830           0.011472
#  3               NaN              24.162808          -0.019720
#  4               NaN              24.217020           0.026426
#  ..              ...                    ...                ...
#  90              NaN              24.170590          -0.006561
#  91              NaN              24.188370          -0.005476
#  92              NaN              24.256515           0.025767
#  93              NaN              24.221940           0.013185
#  94              NaN              24.244410           0.014273
#
#  [95 rows x 29 columns],
#  10:     Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0          135  \t05/17/2024 14:38:56.788      1753.2692        10.0010
#  1          136  \t05/17/2024 14:39:06.789      1763.2701        20.0019
#  2          137  \t05/17/2024 14:39:16.790      1773.2711        30.0029
#  3          138  \t05/17/2024 14:39:26.791      1783.2719        40.0037
#  4          139  \t05/17/2024 14:39:36.792      1793.2729        50.0047
#  ..         ...                        ...            ...            ...
#  87         222  \t05/17/2024 14:53:24.796      2621.2772       878.0090
#  88         223  \t05/17/2024 14:53:34.796      2631.2774       888.0092
#  89         224  \t05/17/2024 14:53:44.797      2641.2781       898.0099
#  90         225  \t05/17/2024 14:53:46.792      2643.2734       900.0052
#  91         226  \t05/17/2024 14:53:47.789      2644.2700       901.0018
#
#      Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0             1           7            0            0            0
#  1             1           7            0            0            0
#  2             1           7            0            0            0
#  3             1           7            0            0            0
#  4             1           7            0            0            0
#  ..          ...         ...          ...          ...          ...
#  87            1           7            0            0            0
#  88            1           7            0            0            0
#  89            1           7            0            0            0
#  90            1           7            0            0            0
#  91            1           7            0            0            0
#
#      TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0             0  ...        NaN     0.000014                        NaN
#  1             0  ...        NaN    -0.000425                        NaN
#  2             0  ...        NaN     0.000021                        NaN
#  3             0  ...        NaN    -0.000053                        NaN
#  4             0  ...        NaN          NaN                        NaN
#  ..          ...  ...        ...          ...                        ...
#  87            0  ...        NaN     0.000067                        NaN
#  88            0  ...        NaN    -0.000069                        NaN
#  89            0  ...        NaN     0.000020                        NaN
#  90            0  ...        NaN     0.004244                        NaN
#  91            0  ...        NaN     0.023559                   0.086217
#
#      dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0            NaN           NaN              NaN              NaN
#  1       0.004441           NaN              NaN              NaN
#  2            NaN     36.965080              NaN              NaN
#  3            NaN           NaN              NaN              NaN
#  4            NaN           NaN              NaN              NaN
#  ..           ...           ...              ...              ...
#  87           NaN           NaN              NaN              NaN
#  88           NaN           NaN              NaN              NaN
#  89           NaN           NaN              NaN              NaN
#  90           NaN           NaN              NaN              NaN
#  91     -0.413602     -4.076612              NaN              NaN
#
#      MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0               NaN              24.481720      -7.333755e-03
#  1               NaN              24.522660       1.310110e-03
#  2               NaN              24.523851       1.309966e-08
#  3               NaN              24.603770       1.125872e-02
#  4               NaN              24.559590       1.709282e-02
#  ..              ...                    ...                ...
#  87              NaN              24.488390       1.447916e-02
#  88              NaN              24.448710       7.789731e-03
#  89              NaN              24.478035       1.641265e-02
#  90              NaN              24.478035       1.770992e-03
#  91              NaN              24.436620      -1.294136e-02
#
#  [92 rows x 29 columns],
#  11:      Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0            16  \t05/17/2024 14:59:51.951       602.7613         0.5059
#  1            17  \t05/17/2024 14:59:52.954       603.7645         1.5091
#  2            18  \t05/17/2024 15:00:02.955       613.7659        11.5105
#  3            19  \t05/17/2024 15:00:12.957       623.7673        21.5119
#  4            20  \t05/17/2024 15:00:22.958       633.7680        31.5126
#  ..          ...                        ...            ...            ...
#  137         153  \t05/17/2024 15:14:11.454      1462.2649       860.0095
#  138         154  \t05/17/2024 15:14:21.455      1472.2656       870.0102
#  139         155  \t05/17/2024 15:14:31.455      1482.2659       880.0105
#  140         156  \t05/17/2024 15:14:41.456      1492.2662       890.0108
#  141         157  \t05/17/2024 15:14:51.457      1502.2672       900.0118
#
#       Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0              1           6            0            0            0
#  1              1           6            0            0            0
#  2              1           6            0            0            0
#  3              1           6            0            0            0
#  4              1           6            0            0            0
#  ..           ...         ...          ...          ...          ...
#  137            1           6            0            0            0
#  138            1           6            0            0            0
#  139            1           6            0            0            0
#  140            1           6            0            0            0
#  141            1           6            0            0            0
#
#       TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0              0  ...        NaN    -0.001085                        NaN
#  1              0  ...        NaN    -0.004199                        NaN
#  2              0  ...        NaN    -0.000640                        NaN
#  3              0  ...        NaN     0.002396                        NaN
#  4              0  ...        NaN    -0.000487                        NaN
#  ..           ...  ...        ...          ...                        ...
#  137            0  ...        NaN     0.000027                        NaN
#  138            0  ...        NaN     0.000021                        NaN
#  139            0  ...        NaN    -0.000019                        NaN
#  140            0  ...        NaN     0.000007                        NaN
#  141            0  ...        NaN          NaN                        NaN
#
#       dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0        0.000047           NaN              NaN              NaN
#  1        0.001222   5032.258789              NaN              NaN
#  2        0.014460   1071.234009              NaN              NaN
#  3        0.047509     35.100029              NaN              NaN
#  4             NaN           NaN              NaN              NaN
#  ..            ...           ...              ...              ...
#  137           NaN           NaN              NaN              NaN
#  138           NaN           NaN              NaN              NaN
#  139           NaN           NaN              NaN              NaN
#  140           NaN           NaN              NaN              NaN
#  141           NaN           NaN              NaN              NaN
#
#       MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0                NaN              25.195601          -0.013688
#  1                NaN              25.195600          -0.013692
#  2                NaN              25.204229          -0.012534
#  3                NaN              25.245561          -0.017696
#  4                NaN              25.218760           0.009776
#  ..               ...                    ...                ...
#  137              NaN              25.301830          -0.000772
#  138              NaN              25.313131           0.012753
#  139              NaN              25.322002           0.001772
#  140              NaN              25.309200           0.008451
#  141              NaN              25.265416          -0.004460
#
#  [142 rows x 29 columns],
#  12:      Data Point                  Date Time  Test Time (s)  Step Time (s)  \
#  0           183  \t05/17/2024 15:18:52.964      1743.7747         0.5082
#  1           184  \t05/17/2024 15:18:54.466      1745.2764         2.0099
#  2           185  \t05/17/2024 15:19:04.467      1755.2771        12.0106
#  3           186  \t05/17/2024 15:19:14.468      1765.2781        22.0116
#  4           187  \t05/17/2024 15:19:24.468      1775.2782        32.0117
#  ..          ...                        ...            ...            ...
#  99          282  \t05/17/2024 15:33:37.225      2628.0358       884.7693
#  100         283  \t05/17/2024 15:33:47.227      2638.0374       894.7709
#  101         284  \t05/17/2024 15:33:52.464      2643.2747       900.0082
#  102         285  \t05/17/2024 15:33:52.822      2643.6327       900.3662
#  103         286  \t05/17/2024 15:33:53.458      2644.2684       901.0019
#
#       Cycle Index  Step Index  TC_Counter1  TC_Counter2  TC_Counter3  \
#  0              1           7            0            0            0
#  1              1           7            0            0            0
#  2              1           7            0            0            0
#  3              1           7            0            0            0
#  4              1           7            0            0            0
#  ..           ...         ...          ...          ...          ...
#  99             1           7            0            0            0
#  100            1           7            0            0            0
#  101            1           7            0            0            0
#  102            1           7            0            0            0
#  103            1           7            0            0            0
#
#       TC_Counter4  ...  ACR (Ohm)  dV/dt (V/s)  Internal Resistance (Ohm)  \
#  0              0  ...        NaN    -0.000134                        NaN
#  1              0  ...        NaN    -0.004488                        NaN
#  2              0  ...        NaN    -0.000497                        NaN
#  3              0  ...        NaN    -0.000211                        NaN
#  4              0  ...        NaN    -0.000250                        NaN
#  ..           ...  ...        ...          ...                        ...
#  99             0  ...        NaN     0.001629                        NaN
#  100            0  ...        NaN    -0.000151                        NaN
#  101            0  ...        NaN     0.036740                        NaN
#  102            0  ...        NaN          NaN                        NaN
#  103            0  ...        NaN     0.151136                    0.45148
#
#       dQ/dV (Ah/V)  dV/dQ (V/Ah)  MetaCode_MV_UD1  MetaCode_MV_UD2  \
#  0        0.000057           NaN              NaN              NaN
#  1        0.001150     596.69342              NaN              NaN
#  2        0.022924           NaN              NaN              NaN
#  3             NaN      30.89537              NaN              NaN
#  4        0.063889           NaN              NaN              NaN
#  ..            ...           ...              ...              ...
#  99            NaN           NaN              NaN              NaN
#  100           NaN           NaN              NaN              NaN
#  101     -0.018052     -18.90526              NaN              NaN
#  102           NaN           NaN              NaN              NaN
#  103     -0.018052     -18.90526              NaN              NaN
#
#       MetaCode_MV_UD3  Aux_Temperature_1 (C)  Aux_dT/dt_1 (C/s)
#  0                NaN              25.170870           0.000228
#  1                NaN              25.170860          -0.015677
#  2                NaN              25.125037          -0.001000
#  3                NaN              25.115690          -0.001928
#  4                NaN              25.105351          -0.015920
#  ..               ...                    ...                ...
#  99               NaN              24.752260           0.016630
#  100              NaN              24.749830          -0.014282
#  101              NaN              24.729870          -0.017757
#  102              NaN              24.729870          -0.017757
#  103              NaN              24.762604           0.010226
#
#  [104 rows x 29 columns]}

# %%
# %run Database_create.ipynb
# Out:
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'def_Up' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Down'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Flat'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Down'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_64435/3217211228.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Flat'

# %%
info_data_test =pd.DataFrame()
info_data_test['Mini Trip']= dict_test.keys()

# %%
# %run Cons_brk_tests.ipynb

# %%
def features_ext_test(dict_test):
    time_arr=[]
    start_volts_arr=[]
    end_volts_arr=[]
    peak_curr_arr=[]
    min_curr_arr=[]
    discharge_arr=[]
    mean_volts_arr=[]
    med_curr_arr=[]
    soc_cc_arr=[]
    max_dvdt_arr=[]
    min_dvdt_arr=[]
    avg_dvdt_arr=[]
    discharge_area_arr=[]
    soc_area=[]
    t10_arr=[]
    t20_arr=[]
    t30_arr=[]
    t40_arr=[]
    t50_arr=[]
    t60_arr=[]
    t70_arr=[]
    t80_arr=[]
    t90_arr=[]
    t100_arr=[]
    tc10_arr=[]
    tc20_arr=[]
    tc30_arr=[]
    tc40_arr=[]
    tc50_arr=[]
    tc60_arr=[]
    tc70_arr=[]
    tc80_arr=[]
    tc90_arr=[]
    tc100_arr=[]
    dis_drop_tester_arr=[]
    volt_rise=[]
    curr_rise_arr=[]
    brakes=[]
    var_curr_arr=[]
    mean_curr_arr=[]
    for key in dict_test.keys():
        time= (dict_test[key]['Step Time (s)'].max())-(dict_test[key]['Step Time (s)'].min())
        time_arr.append(time)
        start_volts= dict_test[key]['Voltage (V)'].iloc[0]
        end_volts= dict_test[key]['Voltage (V)'].iloc[-1]
        mean_volts= dict_test[key]['Voltage (V)'].mean()
        start_volts_arr.append(start_volts)
        end_volts_arr.append(end_volts)
        mean_volts_arr.append(mean_volts)
        peak_curr= dict_test[key]['Current (A)'].max() 
        min_curr= dict_test[key]['Current (A)'].min()
        med_curr= dict_test[key]['Current (A)'].median()
        med_curr_arr.append(med_curr)
        var_curr= dict_test[key]['Current (A)'].var()
        var_curr_arr.append(var_curr)
        mean_curr= dict_test[key]['Current (A)'].mean()
        mean_curr_arr.append(mean_curr)
        peak_curr_arr.append(peak_curr)
        min_curr_arr.append(min_curr)
        discharge= dis_cap_drop(dict_test[key])
        discharge_int= dis_cap_drop_area(dict_test[key])
        soc_cc= (discharge/(3))*100
        soc_cc_area= (discharge_int/(3))*100
        soc_cc_arr.append(soc_cc)
        soc_area.append(soc_cc_area)
        discharge_arr.append(discharge)
        discharge_area_arr.append(discharge_int)
        max_dvdt= dict_test[key]['dV/dt (V/s)'].max() 
        max_dvdt_arr.append(max_dvdt)
        min_dvdt= dict_test[key]['dV/dt (V/s)'].min() 
        min_dvdt_arr.append(min_dvdt)
        avg_dvdt= dict_test[key]['dV/dt (V/s)'].mean() 
        avg_dvdt_arr.append(avg_dvdt)
        sum_volt_rise= volt_sum(dict_test[key])
        volt_rise.append(sum_volt_rise)
        curr_rise= currdrop_sum(dict_test[key])
        curr_rise_arr.append(curr_rise)
        # t10, t10_20, t20_30, t30_40, t40_50, t50_60, t60_70, t70_80, t80_90, t90_100= find_time_vpercentile(dict_test[key])
        # tc10, tc10_20, tc20_30, tc30_40, tc40_50, tc50_60, tc60_70, tc70_80, tc80_90, tc90_100= find_time_cpercentile(dict_test[key])
        # t10_arr.append(t10)
        # t20_arr.append(t10_20)
        # t30_arr.append(t20_30)
        # t40_arr.append(t30_40)
        # t50_arr.append(t40_50)
        # t60_arr.append(t50_60)
        # t70_arr.append(t60_70)
        # t80_arr.append(t70_80)
        # t90_arr.append(t80_90)
        # t100_arr.append(t90_100)
        # tc10_arr.append(tc10)
        # tc20_arr.append(tc10_20)
        # tc30_arr.append(tc20_30)
        # tc40_arr.append(tc30_40)
        # tc50_arr.append(tc40_50)
        # tc60_arr.append(tc50_60)
        # tc70_arr.append(tc60_70)
        # tc80_arr.append(tc70_80)
        # tc90_arr.append(tc80_90)
        # tc100_arr.append(tc90_100)
        dis_drop_t= dis_cap_drop_tester(dict_test[key])
        dis_drop_tester_arr.append(dis_drop_t)
        brake_num= brake_calc(dict_test[key])
        brakes.append(brake_num)
    info_data_test['Time(s)']= time_arr
    # info_data_test['Time below 10 perc V']= t10_arr
    # info_data_test['Time b/w 10-20 perc V']= t20_arr
    # info_data_test['Time b/w 20-30 perc V']= t30_arr
    # info_data_test['Time b/w 30-40 perc V']= t40_arr
    # info_data_test['Time b/w 40-50 perc V']= t50_arr
    # info_data_test['Time b/w 50-60 perc V']= t60_arr
    # info_data_test['Time b/w 60-70 perc V']= t70_arr
    # info_data_test['Time b/w 70-80 perc V']= t80_arr
    # info_data_test['Time b/w 80-90 perc V']= t90_arr
    # info_data_test['Time b/w 90-100 perc V']= t100_arr
    # info_data_test['Time below 10 perc A']= tc10_arr
    # info_data_test['Time b/w 10-20 perc A']= tc20_arr
    # info_data_test['Time b/w 20-30 perc A']= tc30_arr
    # info_data_test['Time b/w 30-40 perc A']= tc40_arr
    # info_data_test['Time b/w 40-50 perc A']= tc50_arr
    # info_data_test['Time b/w 50-60 perc A']= tc60_arr
    # info_data_test['Time b/w 60-70 perc A']= tc70_arr
    # info_data_test['Time b/w 70-80 perc A']= tc80_arr
    # info_data_test['Time b/w 80-90 perc A']= tc90_arr
    # info_data_test['Time b/w 90-100 perc A']= tc100_arr
    info_data_test['Start Voltage(V)']= start_volts_arr
    info_data_test['End Voltage(V)']= end_volts_arr
    info_data_test['Mean Voltage(V)']= mean_volts_arr
    info_data_test['Peak Current(A)']= peak_curr_arr
    info_data_test['Peak Min_dis Current(A)']= min_curr_arr
    info_data_test['Median Current(A)']= med_curr_arr
    info_data_test['Variance Current(A)']= var_curr_arr
    info_data_test['Mean Current(A)']= mean_curr_arr
    ##info_data_2['SOC_CC (%)']= soc_cc_arr
    info_data_test['Peak dV/dt']= max_dvdt_arr
    info_data_test['Min dV/dt']= min_dvdt_arr
    info_data_test['Avg dV/dt']= avg_dvdt_arr
    info_data_test['Total Voltage Rise']= volt_rise
    info_data_test['Total Current Rise']= curr_rise_arr
    info_data_test['Number of brakes']= brakes
    ##info_data_2['Discharge Cap. Drop tester (Ah)']= dis_drop_tester_arr
    ##info_data_2['Discharge Cap. Drop(Ah)_CC']= discharge_arr
    info_data_test['SOC_drop (%)']= soc_cc_arr
    ##min_soc= max(info_data_2['SOC_drop (%)'])
    info_data_test['Relative_SOC_drop']= (((info_data_test['SOC_drop (%)']-relative_soc)/relative_soc)+1)*100
    ##info_data_2['SOC_drop unit time']= (info_data_2['SOC_drop (%)'])/(info_data_2['Time(s)'])
    return info_data_test

# %%
info_data_test= features_ext_test(dict_test)
info_data_test
# Out:
#     Mini Trip   Time(s)  Start Voltage(V)  End Voltage(V)  Mean Voltage(V)  \
# 0           1  899.9988          3.798208        3.845905         3.847467
# 1           2  900.9955          3.768502        3.822170         3.814090
# 2           3  890.0059          3.882157        3.844372         3.845406
# 3           4  891.0040          3.849991        3.829554         3.814110
# 4           5  899.5012          3.843485        3.802763         3.713744
# 5           6  900.4939          3.802966        3.869991         3.693416
# 6           7  896.6292          3.756692        3.804655         3.800597
# 7           8  900.9906          3.714958        3.778385         3.769176
# 8           9  886.7866          3.875171        3.844726         3.838638
# 9          10  891.0008          3.842507        3.812520         3.806300
# 10         11  899.5059          3.871829        3.851696         3.749729
# 11         12  900.4937          3.841965        3.815004         3.719195
#
#     Peak Current(A)  Peak Min_dis Current(A)  Median Current(A)  \
# 0         -0.015683                -1.123894          -0.307130
# 1          0.141303                -1.125523          -0.294431
# 2         -0.013824                -0.396313          -0.283382
# 3          0.107090                -0.436489          -0.273247
# 4         -0.016184                -0.439259          -0.307257
# 5          0.189375                -0.505642          -0.295245
# 6          0.014999                -1.125725          -0.290039
# 7         -0.000023                -1.126855          -0.306616
# 8          0.000419                -0.483710          -0.263770
# 9          0.000002                -0.379907          -0.282540
# 10         0.040668                -0.580699          -0.295997
# 11         0.000118                -0.437701          -0.307603
#
#     Variance Current(A)  Mean Current(A)  Peak dV/dt  Min dV/dt  Avg dV/dt  \
# 0              0.020079        -0.283190    0.041583  -0.009570   0.000552
# 1              0.024257        -0.259186    0.043639  -0.011753   0.001191
# 2              0.007068        -0.249143    0.007155  -0.009776  -0.000038
# 3              0.010822        -0.231906    0.015894  -0.001979   0.000659
# 4              0.010066        -0.274819    0.087339  -0.125495   0.001384
# 5              0.021434        -0.249794    0.055116  -0.036912   0.000820
# 6              0.027588        -0.255585    0.041001  -0.011050   0.001178
# 7              0.019635        -0.282187    0.114134  -0.018330   0.002782
# 8              0.014130        -0.230313    0.008435  -0.007162   0.000081
# 9              0.006998        -0.248925    0.023559  -0.017683   0.000112
# 10             0.021480        -0.262451    0.105502  -0.105198  -0.000748
# 11             0.010736        -0.269234    0.151136  -0.004605   0.002077
#
#     Total Voltage Rise  Total Current Rise  Number of brakes  SOC_drop (%)  \
# 0             0.052766            0.694277                 6     -2.280846
# 1             0.087029            1.081320                 8     -2.115054
# 2             0.048090            0.630295                 7     -2.091278
# 3             0.083134            0.952912                10     -1.972099
# 4             0.303491            0.737275                 6     -2.286045
# 5             0.509342            1.181116                11     -2.120085
# 6             0.083710            0.977141                14     -2.004422
# 7             0.057288            0.702979                 7     -2.285943
# 8             0.109316            1.234983                10     -1.886132
# 9             0.051828            0.616743                 9     -2.107111
# 10            0.547991            1.255126                14     -2.012154
# 11            0.296589            0.702968                 9     -2.276340
#
#     Relative_SOC_drop
# 0           83.011496
# 1           76.977501
# 2           76.112164
# 3           71.774646
# 4           83.200715
# 5           77.160583
# 6           72.951019
# 7           83.197004
# 8           68.645862
# 9           76.688393
# 10          73.232419
# 11          82.847512

# %%
def corr_map(info_data_test):
    last_column = info_data_test.iloc[:, -1]
    corr_mat = info_data_test.corr()
    target_corr= corr_mat[['Relative_SOC_drop']].drop(['Relative_SOC_drop'], axis=0) 

    rename_dict = {'Mini Trip' : 'Mini trip',
                   'Start Voltage(V)' : 'Start voltage(V)',
                   'End Voltage(V)' : 'End voltage(V)',
                   'Mean Voltage(V)' : 'Mean voltage(V)',
                   'Peak Current(A)' : 'Peak current(A)',
                   'Median Current(A)' : 'Median current(A)',
                   'Mean Current(A)' : 'Mean current(A)',
                   'Variance Current(A)' : 'Variance current(A)',
                   'Min dV/dt' : 'Minimum dV/dt',
                   'Avg dV/dt' : 'Average dV/dt',
                   'Total Voltage Rise' :'Total voltage rise',
                   'Total Current Rise' : 'Total current rise',
                   'Number of brakes': 'Braking frequency',
                    'SOC_drop (%)': 'Actual SOC drop'
                }
    

    target_corr.columns = ['Charge saving score']  # Rename x-axis label
    target_corr.index = target_corr.index.to_series().replace(rename_dict)

    sns.reset_orig()
    plt.rcdefaults()
    plt.rcParams['font.size'] = 12
    plt.rcParams['figure.figsize'] = (2, 6)
    sns.heatmap(target_corr,     
                annot=True,
                cmap="mako",
                fmt=".2f",
                vmin=-1,
                vmax=1,
                linewidths=0.01,
                annot_kws={"color": "white"},  
                cbar_kws={"label": "Correlation Coefficient"} , cbar = False)
    plt.show()

corr_map(info_data_test)
