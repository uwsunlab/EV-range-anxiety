# %% [markdown]
# This notebook contains code related to current model 1
# - comparision of all models
# - early prediction models

# %%
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
import warnings
from sklearn.exceptions import ConvergenceWarning
import sys, os
from tqdm import tqdm
from scipy import stats
import multiprocessing as mp
import seaborn as sns
from pathlib import Path
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic, ExpSineSquared

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
sys.path.append(str(Path().resolve().parent.parent))
from path_manager import TEST_DATA_NB, MISC_DIR

# %%
# %run {TEST_DATA_NB}
# Out:
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'def_Up' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Down'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Flat'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Up'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Down'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/3217211228.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Flat'
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)
# /var/folders/20/47db4tl16cs85c5h4w_qwyt00000gn/T/ipykernel_5244/367856195.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integration = np.trapz(currnp, timenp)

# %%
info_data_2
# Out:
#     Mini Trip   Time(s)  Start Voltage(V)  End Voltage(V)  Mean Voltage(V)  \
# 0           1  838.5301          3.625744        3.883290         3.870859
# 1           2  830.7749          3.635924        3.808598         3.835656
# 2           3  835.6806          3.618710        3.812423         3.830749
# 3           4  832.0687          3.797764        3.779691         3.810151
# 4           5  822.5755          3.878416        3.816445         3.815949
# ..        ...       ...               ...             ...              ...
# 91         92  881.6387          3.793411        3.762675         3.765618
# 92         93  896.1405          3.852625        3.709449         3.740650
# 93         94  895.2206          3.801919        3.754945         3.701342
# 94         95  896.1301          3.777717        3.653281         3.689789
# 95         96  897.0171          3.756208        3.685532         3.666775
#
#     Peak Current(A)  Peak Min_dis Current(A)  Median Current(A)  \
# 0         -0.015272                -1.126501          -0.221077
# 1         -0.022005                -1.125478          -0.333996
# 2         -0.022182                -1.129457          -0.285003
# 3         -0.018094                -1.126538          -0.281176
# 4         -0.024798                -0.385378          -0.247558
# ..              ...                      ...                ...
# 91        -0.064869                -0.450002          -0.274755
# 92        -0.034600                -0.568212          -0.310640
# 93        -0.030949                -0.818060          -0.296477
# 94        -0.034695                -0.533918          -0.291920
# 95        -0.035313                -0.530723          -0.291442
#
#     Variance Current(A)  Mean Current(A)  Peak dV/dt  Min dV/dt  Avg dV/dt  \
# 0              0.032698        -0.236519    0.123397  -0.032355   0.003618
# 1              0.019052        -0.300617    0.177656  -0.027619   0.010053
# 2              0.016756        -0.261694    0.123892  -0.033125   0.005763
# 3              0.018650        -0.282639    0.193953  -0.048424   0.007802
# 4              0.008041        -0.216769    0.112828  -0.027416   0.001599
# ..                  ...              ...         ...        ...        ...
# 91             0.007911        -0.261357    0.045183  -0.009785   0.000633
# 92             0.013628        -0.303141    0.117966  -0.127090   0.000635
# 93             0.023855        -0.296967    0.112069  -0.182226  -0.001153
# 94             0.011841        -0.277675    0.115814  -0.039049   0.000697
# 95             0.011727        -0.281072    0.171685  -0.119220   0.001894
#
#     Total Voltage Rise  Total Current Rise  Number of brakes  \
# 0             0.333304            0.745126                 9
# 1             0.193704            0.221160                15
# 2             0.225856            0.331414                14
# 3             0.348449            0.631515                16
# 4             0.295778            0.684379                 9
# ..                 ...                 ...               ...
# 91            0.108643            1.204570                15
# 92            0.423559            0.941241                18
# 93            0.516790            1.184964                16
# 94            0.452645            1.133279                14
# 95            0.578535            1.427169                20
#
#     Total brake time  SOC_drop (%)  Relative_SOC_drop
# 0           277.8562     -1.714187          62.387902
# 1            99.2912     -2.191082          79.744542
# 2           161.7811     -1.941562          70.663244
# 3           274.9793     -2.052681          74.707409
# 4           275.6830     -1.626870          59.210020
# ..               ...           ...                ...
# 91          140.5351     -2.146716          78.129824
# 92          291.3320     -2.351125          85.569316
# 93          269.7200     -2.222724          80.896135
# 94          253.8221     -2.212659          80.529824
# 95          213.8156     -2.315655          84.278369
#
# [96 rows x 19 columns]

# %% [markdown]
# ### 1. Selecting features
# We take the following four features as the input of our machine learning model: end voltage, median current, min dV/dt, and total current rise since they are more correlated to the output feature, which is SOC drop.

# %% [markdown]
# Correlation heatmap:

# %%
# Select only the relevant columns
selected_columns = ['End Voltage(V)', 'Median Current(A)', 'Min dV/dt', 'Total Current Rise', 'Relative_SOC_drop']
selected_data = info_data_2[selected_columns]

# Calculate the correlation matrix
corr_mat = selected_data.corr()

# Extract the correlation with 'Relative_SOC_drop' and drop the target row itself
target_corr = corr_mat[['Relative_SOC_drop']].drop(['Relative_SOC_drop'], axis=0)

# Plotting the heatmap
sns.heatmap(target_corr, annot=True, cmap='mako', fmt=".2f", cbar=True, vmin=-1, vmax=1)
plt.title('Correlation Heatmap with Relative_SOC_drop')
plt.show()

# %%
info_data_2
# Out:
#     Mini Trip   Time(s)  Start Voltage(V)  End Voltage(V)  Mean Voltage(V)  \
# 0           1  838.5301          3.625744        3.883290         3.870859
# 1           2  830.7749          3.635924        3.808598         3.835656
# 2           3  835.6806          3.618710        3.812423         3.830749
# 3           4  832.0687          3.797764        3.779691         3.810151
# 4           5  822.5755          3.878416        3.816445         3.815949
# ..        ...       ...               ...             ...              ...
# 91         92  881.6387          3.793411        3.762675         3.765618
# 92         93  896.1405          3.852625        3.709449         3.740650
# 93         94  895.2206          3.801919        3.754945         3.701342
# 94         95  896.1301          3.777717        3.653281         3.689789
# 95         96  897.0171          3.756208        3.685532         3.666775
#
#     Peak Current(A)  Peak Min_dis Current(A)  Median Current(A)  \
# 0         -0.015272                -1.126501          -0.221077
# 1         -0.022005                -1.125478          -0.333996
# 2         -0.022182                -1.129457          -0.285003
# 3         -0.018094                -1.126538          -0.281176
# 4         -0.024798                -0.385378          -0.247558
# ..              ...                      ...                ...
# 91        -0.064869                -0.450002          -0.274755
# 92        -0.034600                -0.568212          -0.310640
# 93        -0.030949                -0.818060          -0.296477
# 94        -0.034695                -0.533918          -0.291920
# 95        -0.035313                -0.530723          -0.291442
#
#     Variance Current(A)  Mean Current(A)  Peak dV/dt  Min dV/dt  Avg dV/dt  \
# 0              0.032698        -0.236519    0.123397  -0.032355   0.003618
# 1              0.019052        -0.300617    0.177656  -0.027619   0.010053
# 2              0.016756        -0.261694    0.123892  -0.033125   0.005763
# 3              0.018650        -0.282639    0.193953  -0.048424   0.007802
# 4              0.008041        -0.216769    0.112828  -0.027416   0.001599
# ..                  ...              ...         ...        ...        ...
# 91             0.007911        -0.261357    0.045183  -0.009785   0.000633
# 92             0.013628        -0.303141    0.117966  -0.127090   0.000635
# 93             0.023855        -0.296967    0.112069  -0.182226  -0.001153
# 94             0.011841        -0.277675    0.115814  -0.039049   0.000697
# 95             0.011727        -0.281072    0.171685  -0.119220   0.001894
#
#     Total Voltage Rise  Total Current Rise  Number of brakes  \
# 0             0.333304            0.745126                 9
# 1             0.193704            0.221160                15
# 2             0.225856            0.331414                14
# 3             0.348449            0.631515                16
# 4             0.295778            0.684379                 9
# ..                 ...                 ...               ...
# 91            0.108643            1.204570                15
# 92            0.423559            0.941241                18
# 93            0.516790            1.184964                16
# 94            0.452645            1.133279                14
# 95            0.578535            1.427169                20
#
#     Total brake time  SOC_drop (%)  Relative_SOC_drop
# 0           277.8562     -1.714187          62.387902
# 1            99.2912     -2.191082          79.744542
# 2           161.7811     -1.941562          70.663244
# 3           274.9793     -2.052681          74.707409
# 4           275.6830     -1.626870          59.210020
# ..               ...           ...                ...
# 91          140.5351     -2.146716          78.129824
# 92          291.3320     -2.351125          85.569316
# 93          269.7200     -2.222724          80.896135
# 94          253.8221     -2.212659          80.529824
# 95          213.8156     -2.315655          84.278369
#
# [96 rows x 19 columns]

# %% [markdown]
# Selecting features:

# %%
# Input (different features) is defined as X, output (SOC_drop) is defined as y
number_of_tests = np.shape(info_data_2.values)[0]
X = np.zeros((number_of_tests,4))
y = np.zeros(number_of_tests)

for i in range(number_of_tests):
    X[i,0] = info_data_2['End Voltage(V)'][i]
    X[i,1] = info_data_2['Median Current(A)'][i]
    X[i,2] = info_data_2['Min dV/dt'][i]
    X[i,3] = info_data_2['Total Current Rise'][i]
    y[i] = info_data_2['Relative_SOC_drop'][i]

print(f'{len(X)} points loaded in total, each with {len(X[0])} features')
print('Example point:', X[0])
# Out:
# 96 points loaded in total, each with 4 features
# Example point: [ 3.88329    -0.221077   -0.03235537  0.74512588]

# %%
number_of_new_tests = np.shape(info_data_test.values)[0]
X_new_test = np.zeros((number_of_new_tests,4))
y_new_test = np.zeros(number_of_new_tests)

for i in range(number_of_new_tests):
    X_new_test[i,0] = info_data_test['End Voltage(V)'][i]
    X_new_test[i,1] = info_data_test['Median Current(A)'][i]
    X_new_test[i,2] = info_data_test['Min dV/dt'][i]
    X_new_test[i,3] = info_data_test['Total Current Rise'][i]
    y_new_test[i] = info_data_test['Relative_SOC_drop'][i]

# %% [markdown]
# ### 2. Divide the data into the train set and the test set
# We want 80% of the data to be the train set and the rest (20%) to be the test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ### 3.Compare different models

# %% [markdown]
# #### (3.1) Linear model

# %%
model = LinearRegression()

# Now we use scikit learn to train a simple linear model
model.fit(X_train, y_train)

# And make predictions on the test set
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae1 = mean_absolute_error(y_new_test, y_pred_new_test)
mape1 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae1)
print('MAPE:', mape1)

sns.reset_orig()
plt.rcdefaults()
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (4, 4)
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# MAE: 3.4508288533984306
# MAPE: 0.04659807834657883

# %% [markdown]
# #### (3.2) Decision tree model

# %%
model = DecisionTreeRegressor(random_state=0)

#Now we use scikit learn to train a decision tree model using k-fold cross validation and grid search to find the best model with hyperparameters tunned

#First we define that we use 5 folds to conduct cross validation
skf = KFold(n_splits=5, shuffle=True, random_state=0)
#Then use grid search to tune for the best hyper parameters
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
#Fit the model
model_search.fit(X_train, y_train)
#Get the best model
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae2 = mean_absolute_error(y_new_test, y_pred_new_test)
mape2 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae2)
print('MAPE:', mape2)

plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.349, test=-3.275) neg_mean_squared_error: (train=-9.339, test=-13.262) r2: (train=0.712, test=0.649) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.103, test=-3.692) neg_mean_squared_error: (train=-6.746, test=-24.015) r2: (train=0.792, test=0.381) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.409, test=-2.247) neg_mean_squared_error: (train=-9.551, test=-6.540) r2: (train=0.749, test=0.478) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.396, test=-3.611) neg_mean_squared_error: (train=-9.153, test=-21.174) r2: (train=0.738, test=0.300) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.512, test=-2.384) neg_mean_squared_error: (train=-9.965, test=-16.339) r2: (train=0.695, test=0.571) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.476, test=-2.499) neg_mean_squared_error: (train=-3.928, test=-9.823) r2: (train=0.879, test=0.740) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.648, test=-3.065) neg_mean_squared_error: (train=-4.376, test=-15.337) r2: (train=0.865, test=0.605) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.716, test=-2.102) neg_mean_squared_error: (train=-4.967, test=-6.949) r2: (train=0.869, test=0.446) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.818, test=-2.438) neg_mean_squared_error: (train=-5.007, test=-8.220) r2: (train=0.857, test=0.728) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.790, test=-2.884) neg_mean_squared_error: (train=-5.033, test=-14.888) r2: (train=0.846, test=0.609) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.984, test=-2.533) neg_mean_squared_error: (train=-1.913, test=-16.195) r2: (train=0.941, test=0.571) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.953, test=-2.248) neg_mean_squared_error: (train=-1.541, test=-9.828) r2: (train=0.952, test=0.747) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.109, test=-1.045) neg_mean_squared_error: (train=-2.298, test=-1.990) r2: (train=0.940, test=0.841) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.903, test=-1.225) neg_mean_squared_error: (train=-1.487, test=-2.873) r2: (train=0.957, test=0.905) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.070, test=-2.110) neg_mean_squared_error: (train=-2.091, test=-10.117) r2: (train=0.936, test=0.735) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.430, test=-1.370) neg_mean_squared_error: (train=-0.482, test=-3.243) r2: (train=0.985, test=0.914) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.518, test=-1.619) neg_mean_squared_error: (train=-0.545, test=-6.064) r2: (train=0.983, test=0.844) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.506, test=-1.315) neg_mean_squared_error: (train=-0.573, test=-3.721) r2: (train=0.985, test=0.703) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.365, test=-2.129) neg_mean_squared_error: (train=-0.287, test=-11.332) r2: (train=0.992, test=0.626) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.629, test=-2.674) neg_mean_squared_error: (train=-0.832, test=-16.910) r2: (train=0.975, test=0.556) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.154, test=-2.187) neg_mean_squared_error: (train=-0.091, test=-14.585) r2: (train=0.997, test=0.614) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.191, test=-1.660) neg_mean_squared_error: (train=-0.108, test=-8.086) r2: (train=0.997, test=0.792) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.190, test=-1.161) neg_mean_squared_error: (train=-0.105, test=-3.364) r2: (train=0.997, test=0.732) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.137, test=-2.691) neg_mean_squared_error: (train=-0.080, test=-14.111) r2: (train=0.998, test=0.534) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.202, test=-2.138) neg_mean_squared_error: (train=-0.104, test=-14.769) r2: (train=0.997, test=0.613) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.059, test=-2.180) neg_mean_squared_error: (train=-0.025, test=-14.548) r2: (train=0.999, test=0.615) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.074, test=-1.488) neg_mean_squared_error: (train=-0.033, test=-5.572) r2: (train=0.999, test=0.856) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.059, test=-1.194) neg_mean_squared_error: (train=-0.017, test=-3.344) r2: (train=1.000, test=0.733) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.047, test=-2.332) neg_mean_squared_error: (train=-0.013, test=-12.010) r2: (train=1.000, test=0.603) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.056, test=-1.808) neg_mean_squared_error: (train=-0.014, test=-13.147) r2: (train=1.000, test=0.655) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.020, test=-1.401) neg_mean_squared_error: (train=-0.005, test=-3.753) r2: (train=1.000, test=0.901) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.033, test=-1.774) neg_mean_squared_error: (train=-0.011, test=-8.399) r2: (train=1.000, test=0.783) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.013, test=-1.135) neg_mean_squared_error: (train=-0.004, test=-3.376) r2: (train=1.000, test=0.731) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.010, test=-2.401) neg_mean_squared_error: (train=-0.001, test=-8.893) r2: (train=1.000, test=0.706) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.016, test=-1.896) neg_mean_squared_error: (train=-0.005, test=-9.959) r2: (train=1.000, test=0.739) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.006, test=-2.117) neg_mean_squared_error: (train=-0.001, test=-14.381) r2: (train=1.000, test=0.619) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.009, test=-1.717) neg_mean_squared_error: (train=-0.001, test=-8.295) r2: (train=1.000, test=0.786) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.076) neg_mean_squared_error: (train=-0.000, test=-3.223) r2: (train=1.000, test=0.743) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-2.379) neg_mean_squared_error: (train=-0.000, test=-12.763) r2: (train=1.000, test=0.578) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.002, test=-1.496) neg_mean_squared_error: (train=-0.000, test=-8.130) r2: (train=1.000, test=0.787) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.349, test=-3.275) neg_mean_squared_error: (train=-9.339, test=-13.262) r2: (train=0.712, test=0.649) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.103, test=-3.692) neg_mean_squared_error: (train=-6.746, test=-24.015) r2: (train=0.792, test=0.381) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.409, test=-2.247) neg_mean_squared_error: (train=-9.551, test=-6.540) r2: (train=0.749, test=0.478) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.396, test=-3.611) neg_mean_squared_error: (train=-9.153, test=-21.174) r2: (train=0.738, test=0.300) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.512, test=-2.384) neg_mean_squared_error: (train=-9.965, test=-16.339) r2: (train=0.695, test=0.571) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.476, test=-2.499) neg_mean_squared_error: (train=-3.928, test=-9.823) r2: (train=0.879, test=0.740) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.648, test=-3.065) neg_mean_squared_error: (train=-4.376, test=-15.337) r2: (train=0.865, test=0.605) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.716, test=-2.102) neg_mean_squared_error: (train=-4.967, test=-6.949) r2: (train=0.869, test=0.446) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.818, test=-2.438) neg_mean_squared_error: (train=-5.007, test=-8.220) r2: (train=0.857, test=0.728) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.790, test=-2.884) neg_mean_squared_error: (train=-5.033, test=-14.888) r2: (train=0.846, test=0.609) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.984, test=-2.533) neg_mean_squared_error: (train=-1.913, test=-16.195) r2: (train=0.941, test=0.571) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.953, test=-2.248) neg_mean_squared_error: (train=-1.541, test=-9.828) r2: (train=0.952, test=0.747) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.109, test=-1.045) neg_mean_squared_error: (train=-2.298, test=-1.990) r2: (train=0.940, test=0.841) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.903, test=-1.225) neg_mean_squared_error: (train=-1.487, test=-2.873) r2: (train=0.957, test=0.905) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.070, test=-2.110) neg_mean_squared_error: (train=-2.091, test=-10.117) r2: (train=0.936, test=0.735) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.430, test=-1.370) neg_mean_squared_error: (train=-0.482, test=-3.243) r2: (train=0.985, test=0.914) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.518, test=-1.533) neg_mean_squared_error: (train=-0.545, test=-5.953) r2: (train=0.983, test=0.847) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.506, test=-1.315) neg_mean_squared_error: (train=-0.573, test=-3.721) r2: (train=0.985, test=0.703) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.365, test=-2.129) neg_mean_squared_error: (train=-0.287, test=-11.332) r2: (train=0.992, test=0.626) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.629, test=-2.623) neg_mean_squared_error: (train=-0.832, test=-20.099) r2: (train=0.975, test=0.473) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.154, test=-2.187) neg_mean_squared_error: (train=-0.091, test=-14.585) r2: (train=0.997, test=0.614) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.191, test=-1.461) neg_mean_squared_error: (train=-0.108, test=-5.253) r2: (train=0.997, test=0.865) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.190, test=-1.041) neg_mean_squared_error: (train=-0.105, test=-3.147) r2: (train=0.997, test=0.749) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.137, test=-2.691) neg_mean_squared_error: (train=-0.080, test=-14.111) r2: (train=0.998, test=0.534) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.202, test=-2.593) neg_mean_squared_error: (train=-0.104, test=-17.383) r2: (train=0.997, test=0.544) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.059, test=-2.180) neg_mean_squared_error: (train=-0.025, test=-14.548) r2: (train=0.999, test=0.615) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.074, test=-1.532) neg_mean_squared_error: (train=-0.033, test=-5.869) r2: (train=0.999, test=0.849) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.059, test=-1.116) neg_mean_squared_error: (train=-0.017, test=-3.233) r2: (train=1.000, test=0.742) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.047, test=-2.283) neg_mean_squared_error: (train=-0.013, test=-11.974) r2: (train=1.000, test=0.604) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.056, test=-1.690) neg_mean_squared_error: (train=-0.014, test=-12.870) r2: (train=1.000, test=0.662) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.020, test=-1.391) neg_mean_squared_error: (train=-0.005, test=-3.672) r2: (train=1.000, test=0.903) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.033, test=-1.584) neg_mean_squared_error: (train=-0.011, test=-5.965) r2: (train=1.000, test=0.846) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.013, test=-1.074) neg_mean_squared_error: (train=-0.004, test=-3.286) r2: (train=1.000, test=0.738) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.010, test=-2.263) neg_mean_squared_error: (train=-0.001, test=-11.412) r2: (train=1.000, test=0.623) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.016, test=-1.887) neg_mean_squared_error: (train=-0.005, test=-15.278) r2: (train=1.000, test=0.599) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.006, test=-2.160) neg_mean_squared_error: (train=-0.001, test=-14.350) r2: (train=1.000, test=0.620) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.009, test=-1.467) neg_mean_squared_error: (train=-0.001, test=-5.768) r2: (train=1.000, test=0.851) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.028) neg_mean_squared_error: (train=-0.000, test=-3.144) r2: (train=1.000, test=0.749) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-2.369) neg_mean_squared_error: (train=-0.000, test=-12.693) r2: (train=1.000, test=0.581) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.002, test=-2.157) neg_mean_squared_error: (train=-0.000, test=-15.981) r2: (train=1.000, test=0.581) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.201, test=-2.977) neg_mean_squared_error: (train=-9.940, test=-11.121) r2: (train=0.693, test=0.706) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.034, test=-3.612) neg_mean_squared_error: (train=-7.389, test=-21.561) r2: (train=0.772, test=0.444) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.333, test=-2.500) neg_mean_squared_error: (train=-10.248, test=-9.486) r2: (train=0.731, test=0.243) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.246, test=-3.526) neg_mean_squared_error: (train=-9.430, test=-21.339) r2: (train=0.730, test=0.295) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.345, test=-3.034) neg_mean_squared_error: (train=-10.867, test=-19.001) r2: (train=0.667, test=0.502) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.296, test=-1.944) neg_mean_squared_error: (train=-4.320, test=-5.919) r2: (train=0.867, test=0.843) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.235, test=-2.615) neg_mean_squared_error: (train=-2.838, test=-12.893) r2: (train=0.912, test=0.668) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.384, test=-2.135) neg_mean_squared_error: (train=-4.989, test=-11.485) r2: (train=0.869, test=0.084) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.342, test=-1.687) neg_mean_squared_error: (train=-3.971, test=-4.727) r2: (train=0.886, test=0.844) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.654, test=-2.347) neg_mean_squared_error: (train=-5.711, test=-12.562) r2: (train=0.825, test=0.671) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.716, test=-1.820) neg_mean_squared_error: (train=-1.951, test=-13.043) r2: (train=0.940, test=0.655) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.688, test=-1.776) neg_mean_squared_error: (train=-1.113, test=-6.489) r2: (train=0.966, test=0.833) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.718, test=-1.193) neg_mean_squared_error: (train=-2.349, test=-2.923) r2: (train=0.938, test=0.767) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.776, test=-1.741) neg_mean_squared_error: (train=-1.719, test=-5.172) r2: (train=0.951, test=0.829) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.905, test=-2.034) neg_mean_squared_error: (train=-2.541, test=-11.555) r2: (train=0.922, test=0.697) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.397, test=-2.005) neg_mean_squared_error: (train=-1.136, test=-13.982) r2: (train=0.965, test=0.630) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.276, test=-1.526) neg_mean_squared_error: (train=-0.219, test=-5.432) r2: (train=0.993, test=0.860) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.432, test=-1.155) neg_mean_squared_error: (train=-1.222, test=-2.677) r2: (train=0.968, test=0.786) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.423, test=-1.425) neg_mean_squared_error: (train=-0.840, test=-3.603) r2: (train=0.976, test=0.881) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.582, test=-3.357) neg_mean_squared_error: (train=-1.652, test=-26.045) r2: (train=0.949, test=0.317) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.285, test=-1.531) neg_mean_squared_error: (train=-0.770, test=-4.113) r2: (train=0.976, test=0.891) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.107, test=-2.056) neg_mean_squared_error: (train=-0.064, test=-9.739) r2: (train=0.998, test=0.749) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.216, test=-1.236) neg_mean_squared_error: (train=-0.401, test=-3.829) r2: (train=0.989, test=0.694) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.127, test=-1.521) neg_mean_squared_error: (train=-0.094, test=-4.204) r2: (train=0.997, test=0.861) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.364, test=-2.613) neg_mean_squared_error: (train=-0.708, test=-14.883) r2: (train=0.978, test=0.610) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.079, test=-2.163) neg_mean_squared_error: (train=-0.044, test=-14.291) r2: (train=0.999, test=0.622) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.033, test=-1.909) neg_mean_squared_error: (train=-0.011, test=-7.193) r2: (train=1.000, test=0.815) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.056, test=-1.275) neg_mean_squared_error: (train=-0.017, test=-5.537) r2: (train=1.000, test=0.558) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.046, test=-1.578) neg_mean_squared_error: (train=-0.032, test=-4.514) r2: (train=0.999, test=0.851) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.085, test=-2.407) neg_mean_squared_error: (train=-0.040, test=-15.623) r2: (train=0.999, test=0.590) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.035, test=-1.307) neg_mean_squared_error: (train=-0.016, test=-3.578) r2: (train=1.000, test=0.905) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.009, test=-1.710) neg_mean_squared_error: (train=-0.002, test=-8.524) r2: (train=1.000, test=0.780) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.005, test=-1.308) neg_mean_squared_error: (train=-0.001, test=-5.624) r2: (train=1.000, test=0.551) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.003, test=-1.212) neg_mean_squared_error: (train=-0.000, test=-3.514) r2: (train=1.000, test=0.884) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.026, test=-2.033) neg_mean_squared_error: (train=-0.007, test=-13.974) r2: (train=1.000, test=0.633) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.010, test=-1.906) neg_mean_squared_error: (train=-0.002, test=-13.817) r2: (train=1.000, test=0.634) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.003, test=-2.064) neg_mean_squared_error: (train=-0.000, test=-9.785) r2: (train=1.000, test=0.748) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.001, test=-1.317) neg_mean_squared_error: (train=-0.000, test=-5.627) r2: (train=1.000, test=0.551) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.597) neg_mean_squared_error: (train=-0.000, test=-4.710) r2: (train=1.000, test=0.844) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.010, test=-3.008) neg_mean_squared_error: (train=-0.001, test=-23.378) r2: (train=1.000, test=0.387) total time=   0.0s
# MAE: 4.586871075820963
# MAPE: 0.06061178468835524

# %% [markdown]
# #### (3.3) Extremely randomized tree model
# Extra-trees differ from classic decision trees in the way they are built. When looking for the best split to separate the samples of a node into two groups, random splits are drawn for each of the *max_features* randomly selected features and the best split among those is chosen. When *max_features* is set 1, this amounts to building a totally random decision tree.

# %%
model = ExtraTreeRegressor(random_state=0)

#Now we use scikit learn to train an extremely randomized tree model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae3 = mean_absolute_error(y_new_test, y_pred_new_test)
mape3 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae3)
print('MAPE:', mape3)

plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.287, test=-4.818) neg_mean_squared_error: (train=-16.508, test=-32.689) r2: (train=0.490, test=0.135) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.371, test=-4.035) neg_mean_squared_error: (train=-20.243, test=-24.264) r2: (train=0.374, test=0.374) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.582, test=-3.023) neg_mean_squared_error: (train=-20.584, test=-13.534) r2: (train=0.459, test=-0.080) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.509, test=-3.510) neg_mean_squared_error: (train=-19.829, test=-23.882) r2: (train=0.433, test=0.211) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.658, test=-3.324) neg_mean_squared_error: (train=-22.213, test=-23.777) r2: (train=0.319, test=0.376) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.199, test=-4.059) neg_mean_squared_error: (train=-19.279, test=-28.080) r2: (train=0.405, test=0.257) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.550, test=-4.918) neg_mean_squared_error: (train=-23.235, test=-34.502) r2: (train=0.282, test=0.111) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.667, test=-3.569) neg_mean_squared_error: (train=-26.275, test=-23.712) r2: (train=0.310, test=-0.892) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.598, test=-3.889) neg_mean_squared_error: (train=-20.346, test=-24.006) r2: (train=0.418, test=0.207) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.250, test=-4.134) neg_mean_squared_error: (train=-21.384, test=-27.093) r2: (train=0.345, test=0.289) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.727, test=-4.343) neg_mean_squared_error: (train=-5.230, test=-34.108) r2: (train=0.838, test=0.097) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.121, test=-3.536) neg_mean_squared_error: (train=-8.849, test=-20.434) r2: (train=0.727, test=0.473) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-3.453, test=-3.149) neg_mean_squared_error: (train=-20.164, test=-15.412) r2: (train=0.470, test=-0.230) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.144, test=-3.143) neg_mean_squared_error: (train=-8.325, test=-18.109) r2: (train=0.762, test=0.402) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.008, test=-3.085) neg_mean_squared_error: (train=-8.158, test=-13.704) r2: (train=0.750, test=0.641) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.788, test=-4.207) neg_mean_squared_error: (train=-7.986, test=-31.210) r2: (train=0.753, test=0.174) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.198, test=-3.984) neg_mean_squared_error: (train=-2.686, test=-20.669) r2: (train=0.917, test=0.467) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.681, test=-2.162) neg_mean_squared_error: (train=-6.811, test=-7.278) r2: (train=0.821, test=0.419) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.546, test=-3.213) neg_mean_squared_error: (train=-8.793, test=-23.011) r2: (train=0.748, test=0.240) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.158, test=-2.047) neg_mean_squared_error: (train=-3.900, test=-10.696) r2: (train=0.881, test=0.719) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.532, test=-3.471) neg_mean_squared_error: (train=-1.006, test=-21.678) r2: (train=0.969, test=0.426) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.942, test=-5.221) neg_mean_squared_error: (train=-2.974, test=-40.994) r2: (train=0.908, test=-0.057) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-1.624, test=-1.917) neg_mean_squared_error: (train=-7.350, test=-6.732) r2: (train=0.807, test=0.463) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-1.304, test=-2.757) neg_mean_squared_error: (train=-5.399, test=-10.659) r2: (train=0.846, test=0.648) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.647, test=-2.318) neg_mean_squared_error: (train=-1.522, test=-8.047) r2: (train=0.953, test=0.789) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.570, test=-3.960) neg_mean_squared_error: (train=-1.797, test=-26.934) r2: (train=0.945, test=0.287) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.371, test=-4.310) neg_mean_squared_error: (train=-1.008, test=-27.299) r2: (train=0.969, test=0.296) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-1.476, test=-2.454) neg_mean_squared_error: (train=-6.402, test=-11.971) r2: (train=0.832, test=0.045) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.637, test=-1.671) neg_mean_squared_error: (train=-1.591, test=-5.786) r2: (train=0.954, test=0.809) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.710, test=-2.593) neg_mean_squared_error: (train=-1.724, test=-13.249) r2: (train=0.947, test=0.652) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.034, test=-2.344) neg_mean_squared_error: (train=-0.017, test=-15.966) r2: (train=0.999, test=0.578) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.155, test=-3.779) neg_mean_squared_error: (train=-0.148, test=-25.310) r2: (train=0.995, test=0.347) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.856, test=-2.513) neg_mean_squared_error: (train=-2.333, test=-12.130) r2: (train=0.939, test=0.032) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.964, test=-3.631) neg_mean_squared_error: (train=-3.534, test=-33.070) r2: (train=0.899, test=-0.093) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.218, test=-1.713) neg_mean_squared_error: (train=-0.188, test=-8.587) r2: (train=0.994, test=0.775) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.083, test=-2.474) neg_mean_squared_error: (train=-0.102, test=-16.409) r2: (train=0.997, test=0.566) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.076, test=-4.931) neg_mean_squared_error: (train=-0.052, test=-38.699) r2: (train=0.998, test=0.002) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.263, test=-1.903) neg_mean_squared_error: (train=-0.400, test=-7.668) r2: (train=0.989, test=0.388) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.021, test=-3.223) neg_mean_squared_error: (train=-0.006, test=-22.032) r2: (train=1.000, test=0.272) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.071, test=-2.161) neg_mean_squared_error: (train=-0.074, test=-11.470) r2: (train=0.998, test=0.699) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.287, test=-4.818) neg_mean_squared_error: (train=-16.508, test=-32.689) r2: (train=0.490, test=0.135) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.371, test=-4.035) neg_mean_squared_error: (train=-20.243, test=-24.264) r2: (train=0.374, test=0.374) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.582, test=-3.023) neg_mean_squared_error: (train=-20.584, test=-13.534) r2: (train=0.459, test=-0.080) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.509, test=-3.510) neg_mean_squared_error: (train=-19.829, test=-23.882) r2: (train=0.433, test=0.211) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.658, test=-3.324) neg_mean_squared_error: (train=-22.213, test=-23.777) r2: (train=0.319, test=0.376) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.199, test=-4.059) neg_mean_squared_error: (train=-19.279, test=-28.080) r2: (train=0.405, test=0.257) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.550, test=-4.918) neg_mean_squared_error: (train=-23.235, test=-34.502) r2: (train=0.282, test=0.111) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.667, test=-3.569) neg_mean_squared_error: (train=-26.275, test=-23.712) r2: (train=0.310, test=-0.892) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.598, test=-3.889) neg_mean_squared_error: (train=-20.346, test=-24.006) r2: (train=0.418, test=0.207) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.250, test=-4.134) neg_mean_squared_error: (train=-21.384, test=-27.093) r2: (train=0.345, test=0.289) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.727, test=-3.863) neg_mean_squared_error: (train=-5.230, test=-25.951) r2: (train=0.838, test=0.313) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.121, test=-3.536) neg_mean_squared_error: (train=-8.849, test=-20.434) r2: (train=0.727, test=0.473) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-3.453, test=-3.149) neg_mean_squared_error: (train=-20.164, test=-15.412) r2: (train=0.470, test=-0.230) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.144, test=-3.143) neg_mean_squared_error: (train=-8.325, test=-18.109) r2: (train=0.762, test=0.402) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.008, test=-3.085) neg_mean_squared_error: (train=-8.158, test=-13.704) r2: (train=0.750, test=0.641) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.788, test=-4.207) neg_mean_squared_error: (train=-7.986, test=-31.210) r2: (train=0.753, test=0.174) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.198, test=-3.984) neg_mean_squared_error: (train=-2.686, test=-20.669) r2: (train=0.917, test=0.467) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.681, test=-2.162) neg_mean_squared_error: (train=-6.811, test=-7.278) r2: (train=0.821, test=0.419) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.546, test=-3.213) neg_mean_squared_error: (train=-8.793, test=-23.011) r2: (train=0.748, test=0.240) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.158, test=-2.047) neg_mean_squared_error: (train=-3.900, test=-10.696) r2: (train=0.881, test=0.719) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.532, test=-3.481) neg_mean_squared_error: (train=-1.006, test=-21.621) r2: (train=0.969, test=0.428) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.942, test=-5.221) neg_mean_squared_error: (train=-2.974, test=-40.994) r2: (train=0.908, test=-0.057) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-1.624, test=-1.917) neg_mean_squared_error: (train=-7.350, test=-6.732) r2: (train=0.807, test=0.463) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-1.304, test=-2.536) neg_mean_squared_error: (train=-5.399, test=-9.819) r2: (train=0.846, test=0.676) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.647, test=-2.676) neg_mean_squared_error: (train=-1.522, test=-13.315) r2: (train=0.953, test=0.651) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.570, test=-3.976) neg_mean_squared_error: (train=-1.797, test=-26.949) r2: (train=0.945, test=0.287) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.371, test=-4.310) neg_mean_squared_error: (train=-1.008, test=-27.299) r2: (train=0.969, test=0.296) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-1.476, test=-2.454) neg_mean_squared_error: (train=-6.402, test=-11.971) r2: (train=0.832, test=0.045) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.637, test=-1.670) neg_mean_squared_error: (train=-1.591, test=-5.785) r2: (train=0.954, test=0.809) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.710, test=-2.593) neg_mean_squared_error: (train=-1.724, test=-13.249) r2: (train=0.947, test=0.652) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.034, test=-2.360) neg_mean_squared_error: (train=-0.017, test=-15.981) r2: (train=0.999, test=0.577) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.155, test=-3.779) neg_mean_squared_error: (train=-0.148, test=-25.310) r2: (train=0.995, test=0.347) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.856, test=-2.542) neg_mean_squared_error: (train=-2.333, test=-12.147) r2: (train=0.939, test=0.031) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.964, test=-2.531) neg_mean_squared_error: (train=-3.534, test=-14.400) r2: (train=0.899, test=0.524) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.218, test=-1.713) neg_mean_squared_error: (train=-0.188, test=-8.587) r2: (train=0.994, test=0.775) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.083, test=-2.490) neg_mean_squared_error: (train=-0.102, test=-16.424) r2: (train=0.997, test=0.565) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.076, test=-4.931) neg_mean_squared_error: (train=-0.052, test=-38.699) r2: (train=0.998, test=0.002) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.263, test=-1.903) neg_mean_squared_error: (train=-0.400, test=-7.668) r2: (train=0.989, test=0.388) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.021, test=-3.027) neg_mean_squared_error: (train=-0.006, test=-21.363) r2: (train=1.000, test=0.294) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.071, test=-2.161) neg_mean_squared_error: (train=-0.074, test=-11.470) r2: (train=0.998, test=0.699) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.070, test=-4.326) neg_mean_squared_error: (train=-18.569, test=-29.979) r2: (train=0.427, test=0.207) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.161, test=-4.226) neg_mean_squared_error: (train=-22.749, test=-30.783) r2: (train=0.297, test=0.206) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.411, test=-2.877) neg_mean_squared_error: (train=-22.976, test=-12.146) r2: (train=0.396, test=0.031) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.337, test=-3.507) neg_mean_squared_error: (train=-21.548, test=-26.495) r2: (train=0.384, test=0.125) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.369, test=-3.943) neg_mean_squared_error: (train=-24.805, test=-31.382) r2: (train=0.240, test=0.177) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.625, test=-5.358) neg_mean_squared_error: (train=-29.093, test=-52.392) r2: (train=0.102, test=-0.386) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.011, test=-5.104) neg_mean_squared_error: (train=-18.103, test=-39.087) r2: (train=0.441, test=-0.008) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.527, test=-2.881) neg_mean_squared_error: (train=-27.966, test=-16.634) r2: (train=0.265, test=-0.327) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.500, test=-4.169) neg_mean_squared_error: (train=-23.651, test=-33.863) r2: (train=0.323, test=-0.119) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.238, test=-5.375) neg_mean_squared_error: (train=-24.464, test=-39.468) r2: (train=0.250, test=-0.035) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.946, test=-3.738) neg_mean_squared_error: (train=-9.858, test=-20.108) r2: (train=0.696, test=0.468) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.914, test=-4.517) neg_mean_squared_error: (train=-7.626, test=-29.590) r2: (train=0.764, test=0.237) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-3.368, test=-3.476) neg_mean_squared_error: (train=-27.193, test=-19.089) r2: (train=0.285, test=-0.523) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-2.291, test=-1.798) neg_mean_squared_error: (train=-10.819, test=-7.891) r2: (train=0.690, test=0.739) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-2.365, test=-2.695) neg_mean_squared_error: (train=-14.813, test=-14.148) r2: (train=0.546, test=0.629) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.676, test=-3.841) neg_mean_squared_error: (train=-8.340, test=-23.317) r2: (train=0.742, test=0.383) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.070, test=-3.557) neg_mean_squared_error: (train=-2.473, test=-16.796) r2: (train=0.924, test=0.567) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.656, test=-2.209) neg_mean_squared_error: (train=-7.009, test=-7.205) r2: (train=0.816, test=0.425) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.334, test=-4.005) neg_mean_squared_error: (train=-4.915, test=-35.110) r2: (train=0.859, test=-0.160) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.124, test=-2.972) neg_mean_squared_error: (train=-3.935, test=-12.642) r2: (train=0.879, test=0.668) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.354, test=-3.998) neg_mean_squared_error: (train=-5.366, test=-30.431) r2: (train=0.834, test=0.195) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.129, test=-4.126) neg_mean_squared_error: (train=-4.279, test=-24.089) r2: (train=0.868, test=0.379) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.485, test=-2.308) neg_mean_squared_error: (train=-9.118, test=-11.496) r2: (train=0.760, test=0.083) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.091, test=-2.400) neg_mean_squared_error: (train=-4.098, test=-10.103) r2: (train=0.883, test=0.666) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.647, test=-2.328) neg_mean_squared_error: (train=-1.681, test=-10.091) r2: (train=0.948, test=0.735) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.346, test=-3.341) neg_mean_squared_error: (train=-0.927, test=-16.243) r2: (train=0.971, test=0.570) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.329, test=-3.943) neg_mean_squared_error: (train=-0.820, test=-25.168) r2: (train=0.975, test=0.351) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-1.281, test=-1.260) neg_mean_squared_error: (train=-8.985, test=-3.929) r2: (train=0.764, test=0.686) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-1.040, test=-1.806) neg_mean_squared_error: (train=-6.674, test=-13.617) r2: (train=0.809, test=0.550) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.281, test=-3.409) neg_mean_squared_error: (train=-0.600, test=-15.868) r2: (train=0.982, test=0.584) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.129, test=-2.488) neg_mean_squared_error: (train=-0.272, test=-13.072) r2: (train=0.992, test=0.654) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.213, test=-3.927) neg_mean_squared_error: (train=-0.595, test=-28.320) r2: (train=0.982, test=0.270) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.489, test=-1.900) neg_mean_squared_error: (train=-1.623, test=-15.330) r2: (train=0.957, test=-0.223) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.322, test=-1.219) neg_mean_squared_error: (train=-0.640, test=-3.619) r2: (train=0.982, test=0.880) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.199, test=-2.099) neg_mean_squared_error: (train=-0.219, test=-11.520) r2: (train=0.993, test=0.698) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.082, test=-2.615) neg_mean_squared_error: (train=-0.102, test=-13.514) r2: (train=0.997, test=0.642) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.213, test=-3.229) neg_mean_squared_error: (train=-0.432, test=-18.156) r2: (train=0.987, test=0.532) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.356, test=-2.052) neg_mean_squared_error: (train=-1.065, test=-17.532) r2: (train=0.972, test=-0.399) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.144, test=-1.167) neg_mean_squared_error: (train=-0.206, test=-3.575) r2: (train=0.994, test=0.882) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.034, test=-2.221) neg_mean_squared_error: (train=-0.029, test=-12.361) r2: (train=0.999, test=0.676) total time=   0.0s
# MAE: 4.196225103039066
# MAPE: 0.05570855969882757

# %% [markdown]
# #### (3.4) Random forest model
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.

# %%
model = RandomForestRegressor(random_state=0)

#Now we use scikit learn to train a random forest model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred_train = model.predict(X_train)
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae4 = mean_absolute_error(y_new_test, y_pred_new_test)
mape4 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae4)
print('MAPE:', mape4)

plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.144, test=-2.774) neg_mean_squared_error: (train=-7.448, test=-13.095) r2: (train=0.770, test=0.653) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.203, test=-3.461) neg_mean_squared_error: (train=-7.081, test=-21.341) r2: (train=0.781, test=0.450) total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.199, test=-2.123) neg_mean_squared_error: (train=-7.820, test=-6.538) r2: (train=0.795, test=0.478) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.102, test=-3.158) neg_mean_squared_error: (train=-6.978, test=-14.114) r2: (train=0.800, test=0.534) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.251, test=-1.877) neg_mean_squared_error: (train=-7.891, test=-8.100) r2: (train=0.758, test=0.788) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.484, test=-2.296) neg_mean_squared_error: (train=-3.909, test=-9.653) r2: (train=0.879, test=0.745) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.598, test=-3.015) neg_mean_squared_error: (train=-4.088, test=-15.944) r2: (train=0.874, test=0.589) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.480, test=-1.797) neg_mean_squared_error: (train=-3.738, test=-5.354) r2: (train=0.902, test=0.573) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.490, test=-2.430) neg_mean_squared_error: (train=-3.646, test=-9.325) r2: (train=0.896, test=0.692) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.524, test=-1.817) neg_mean_squared_error: (train=-4.037, test=-8.548) r2: (train=0.876, test=0.776) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.106, test=-2.075) neg_mean_squared_error: (train=-2.195, test=-8.988) r2: (train=0.932, test=0.762) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.113, test=-2.674) neg_mean_squared_error: (train=-2.242, test=-13.359) r2: (train=0.931, test=0.656) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.032, test=-1.474) neg_mean_squared_error: (train=-1.966, test=-4.027) r2: (train=0.948, test=0.679) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.036, test=-2.008) neg_mean_squared_error: (train=-1.795, test=-7.228) r2: (train=0.949, test=0.761) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.111, test=-1.814) neg_mean_squared_error: (train=-2.306, test=-8.324) r2: (train=0.929, test=0.782) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.900, test=-1.940) neg_mean_squared_error: (train=-1.567, test=-7.394) r2: (train=0.952, test=0.804) total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.904, test=-2.373) neg_mean_squared_error: (train=-1.580, test=-10.838) r2: (train=0.951, test=0.721) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.825, test=-1.341) neg_mean_squared_error: (train=-1.440, test=-3.676) r2: (train=0.962, test=0.707) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.844, test=-1.874) neg_mean_squared_error: (train=-1.246, test=-6.702) r2: (train=0.964, test=0.779) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.885, test=-1.724) neg_mean_squared_error: (train=-1.582, test=-8.158) r2: (train=0.952, test=0.786) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.804, test=-1.999) neg_mean_squared_error: (train=-1.361, test=-8.418) r2: (train=0.958, test=0.777) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.802, test=-2.289) neg_mean_squared_error: (train=-1.402, test=-10.395) r2: (train=0.957, test=0.732) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.762, test=-1.332) neg_mean_squared_error: (train=-1.262, test=-3.662) r2: (train=0.967, test=0.708) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.733, test=-1.822) neg_mean_squared_error: (train=-1.007, test=-6.290) r2: (train=0.971, test=0.792) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.799, test=-1.639) neg_mean_squared_error: (train=-1.386, test=-7.756) r2: (train=0.958, test=0.797) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.796, test=-1.972) neg_mean_squared_error: (train=-1.362, test=-8.030) r2: (train=0.958, test=0.788) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.791, test=-2.286) neg_mean_squared_error: (train=-1.376, test=-10.585) r2: (train=0.957, test=0.727) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.744, test=-1.415) neg_mean_squared_error: (train=-1.261, test=-3.957) r2: (train=0.967, test=0.684) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.695, test=-1.823) neg_mean_squared_error: (train=-0.968, test=-6.054) r2: (train=0.972, test=0.800) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.750, test=-1.633) neg_mean_squared_error: (train=-1.285, test=-7.171) r2: (train=0.961, test=0.812) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.769, test=-1.988) neg_mean_squared_error: (train=-1.328, test=-8.177) r2: (train=0.959, test=0.784) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.761, test=-2.286) neg_mean_squared_error: (train=-1.318, test=-10.551) r2: (train=0.959, test=0.728) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.741, test=-1.399) neg_mean_squared_error: (train=-1.278, test=-3.877) r2: (train=0.966, test=0.691) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.686, test=-1.829) neg_mean_squared_error: (train=-0.977, test=-6.283) r2: (train=0.972, test=0.792) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.750, test=-1.624) neg_mean_squared_error: (train=-1.337, test=-7.765) r2: (train=0.959, test=0.796) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.789, test=-1.989) neg_mean_squared_error: (train=-1.368, test=-8.004) r2: (train=0.958, test=0.788) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.771, test=-2.312) neg_mean_squared_error: (train=-1.360, test=-10.679) r2: (train=0.958, test=0.725) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.743, test=-1.404) neg_mean_squared_error: (train=-1.288, test=-3.886) r2: (train=0.966, test=0.690) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.694, test=-1.807) neg_mean_squared_error: (train=-0.982, test=-6.053) r2: (train=0.972, test=0.800) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.738, test=-1.637) neg_mean_squared_error: (train=-1.314, test=-7.740) r2: (train=0.960, test=0.797) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.144, test=-2.774) neg_mean_squared_error: (train=-7.448, test=-13.065) r2: (train=0.770, test=0.654) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.196, test=-3.454) neg_mean_squared_error: (train=-7.015, test=-21.325) r2: (train=0.783, test=0.450) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.197, test=-2.123) neg_mean_squared_error: (train=-7.801, test=-6.538) r2: (train=0.795, test=0.478) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.101, test=-3.154) neg_mean_squared_error: (train=-6.970, test=-14.057) r2: (train=0.801, test=0.536) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.252, test=-1.873) neg_mean_squared_error: (train=-7.900, test=-8.128) r2: (train=0.758, test=0.787) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.488, test=-2.295) neg_mean_squared_error: (train=-3.942, test=-9.679) r2: (train=0.878, test=0.744) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.594, test=-3.021) neg_mean_squared_error: (train=-4.032, test=-15.956) r2: (train=0.875, test=0.589) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.479, test=-1.793) neg_mean_squared_error: (train=-3.739, test=-5.336) r2: (train=0.902, test=0.574) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.484, test=-2.426) neg_mean_squared_error: (train=-3.624, test=-9.315) r2: (train=0.896, test=0.692) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.519, test=-1.816) neg_mean_squared_error: (train=-4.030, test=-8.675) r2: (train=0.877, test=0.772) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.115, test=-2.074) neg_mean_squared_error: (train=-2.242, test=-8.885) r2: (train=0.931, test=0.765) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.102, test=-2.666) neg_mean_squared_error: (train=-2.190, test=-13.317) r2: (train=0.932, test=0.657) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.025, test=-1.479) neg_mean_squared_error: (train=-1.973, test=-4.128) r2: (train=0.948, test=0.671) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.032, test=-1.981) neg_mean_squared_error: (train=-1.791, test=-7.056) r2: (train=0.949, test=0.767) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.110, test=-1.822) neg_mean_squared_error: (train=-2.312, test=-8.376) r2: (train=0.929, test=0.780) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.906, test=-1.909) neg_mean_squared_error: (train=-1.611, test=-7.188) r2: (train=0.950, test=0.810) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.885, test=-2.403) neg_mean_squared_error: (train=-1.518, test=-11.145) r2: (train=0.953, test=0.713) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.820, test=-1.348) neg_mean_squared_error: (train=-1.427, test=-3.833) r2: (train=0.963, test=0.694) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.833, test=-1.890) neg_mean_squared_error: (train=-1.224, test=-6.742) r2: (train=0.965, test=0.777) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.878, test=-1.696) neg_mean_squared_error: (train=-1.571, test=-7.675) r2: (train=0.952, test=0.799) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.802, test=-1.971) neg_mean_squared_error: (train=-1.405, test=-8.259) r2: (train=0.957, test=0.781) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.786, test=-2.325) neg_mean_squared_error: (train=-1.301, test=-10.608) r2: (train=0.960, test=0.727) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.751, test=-1.358) neg_mean_squared_error: (train=-1.224, test=-3.797) r2: (train=0.968, test=0.697) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.731, test=-1.806) neg_mean_squared_error: (train=-0.990, test=-6.199) r2: (train=0.972, test=0.795) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.792, test=-1.613) neg_mean_squared_error: (train=-1.373, test=-7.388) r2: (train=0.958, test=0.806) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.789, test=-1.932) neg_mean_squared_error: (train=-1.369, test=-7.673) r2: (train=0.958, test=0.797) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.773, test=-2.325) neg_mean_squared_error: (train=-1.289, test=-10.678) r2: (train=0.960, test=0.725) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.743, test=-1.393) neg_mean_squared_error: (train=-1.247, test=-3.966) r2: (train=0.967, test=0.684) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.682, test=-1.843) neg_mean_squared_error: (train=-0.942, test=-6.053) r2: (train=0.973, test=0.800) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.742, test=-1.589) neg_mean_squared_error: (train=-1.272, test=-7.391) r2: (train=0.961, test=0.806) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.770, test=-1.920) neg_mean_squared_error: (train=-1.356, test=-7.810) r2: (train=0.958, test=0.793) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.754, test=-2.311) neg_mean_squared_error: (train=-1.251, test=-10.541) r2: (train=0.961, test=0.728) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.735, test=-1.371) neg_mean_squared_error: (train=-1.261, test=-3.884) r2: (train=0.967, test=0.690) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.683, test=-1.860) neg_mean_squared_error: (train=-0.966, test=-6.276) r2: (train=0.972, test=0.793) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.743, test=-1.592) neg_mean_squared_error: (train=-1.324, test=-7.592) r2: (train=0.959, test=0.801) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.792, test=-1.948) neg_mean_squared_error: (train=-1.400, test=-7.851) r2: (train=0.957, test=0.792) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.758, test=-2.324) neg_mean_squared_error: (train=-1.291, test=-10.612) r2: (train=0.960, test=0.726) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.741, test=-1.372) neg_mean_squared_error: (train=-1.282, test=-3.889) r2: (train=0.966, test=0.690) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.694, test=-1.842) neg_mean_squared_error: (train=-0.964, test=-6.084) r2: (train=0.972, test=0.799) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.731, test=-1.606) neg_mean_squared_error: (train=-1.309, test=-7.463) r2: (train=0.960, test=0.804) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.125, test=-2.787) neg_mean_squared_error: (train=-7.684, test=-12.996) r2: (train=0.763, test=0.656) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.150, test=-3.342) neg_mean_squared_error: (train=-7.100, test=-19.261) r2: (train=0.781, test=0.503) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.194, test=-2.165) neg_mean_squared_error: (train=-7.936, test=-6.793) r2: (train=0.791, test=0.458) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.140, test=-3.181) neg_mean_squared_error: (train=-7.449, test=-15.096) r2: (train=0.787, test=0.501) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.229, test=-2.048) neg_mean_squared_error: (train=-8.196, test=-7.978) r2: (train=0.749, test=0.791) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.559, test=-2.382) neg_mean_squared_error: (train=-4.139, test=-10.153) r2: (train=0.872, test=0.731) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.565, test=-2.958) neg_mean_squared_error: (train=-3.859, test=-15.030) r2: (train=0.881, test=0.613) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.498, test=-1.820) neg_mean_squared_error: (train=-3.806, test=-5.300) r2: (train=0.900, test=0.577) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.563, test=-2.491) neg_mean_squared_error: (train=-4.011, test=-9.838) r2: (train=0.885, test=0.675) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.610, test=-1.909) neg_mean_squared_error: (train=-4.523, test=-8.263) r2: (train=0.861, test=0.783) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.144, test=-2.050) neg_mean_squared_error: (train=-2.368, test=-7.649) r2: (train=0.927, test=0.798) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.173, test=-2.631) neg_mean_squared_error: (train=-2.348, test=-12.869) r2: (train=0.927, test=0.668) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.130, test=-1.449) neg_mean_squared_error: (train=-2.249, test=-3.988) r2: (train=0.941, test=0.682) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.160, test=-2.168) neg_mean_squared_error: (train=-2.151, test=-7.634) r2: (train=0.938, test=0.748) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.182, test=-1.722) neg_mean_squared_error: (train=-2.552, test=-7.514) r2: (train=0.922, test=0.803) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.910, test=-1.960) neg_mean_squared_error: (train=-1.592, test=-6.980) r2: (train=0.951, test=0.815) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.957, test=-2.420) neg_mean_squared_error: (train=-1.661, test=-11.060) r2: (train=0.949, test=0.715) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.894, test=-1.327) neg_mean_squared_error: (train=-1.546, test=-3.572) r2: (train=0.959, test=0.715) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.890, test=-2.036) neg_mean_squared_error: (train=-1.310, test=-6.997) r2: (train=0.963, test=0.769) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.938, test=-1.644) neg_mean_squared_error: (train=-1.797, test=-6.864) r2: (train=0.945, test=0.820) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.805, test=-1.893) neg_mean_squared_error: (train=-1.371, test=-6.696) r2: (train=0.958, test=0.823) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.844, test=-2.363) neg_mean_squared_error: (train=-1.432, test=-10.573) r2: (train=0.956, test=0.727) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.838, test=-1.270) neg_mean_squared_error: (train=-1.402, test=-3.215) r2: (train=0.963, test=0.743) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.798, test=-1.970) neg_mean_squared_error: (train=-1.125, test=-6.589) r2: (train=0.968, test=0.782) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.783, test=-1.529) neg_mean_squared_error: (train=-1.416, test=-6.383) r2: (train=0.957, test=0.833) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.765, test=-1.932) neg_mean_squared_error: (train=-1.313, test=-6.924) r2: (train=0.959, test=0.817) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.766, test=-2.328) neg_mean_squared_error: (train=-1.284, test=-10.509) r2: (train=0.960, test=0.729) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.809, test=-1.244) neg_mean_squared_error: (train=-1.340, test=-3.176) r2: (train=0.965, test=0.747) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.772, test=-1.906) neg_mean_squared_error: (train=-1.081, test=-6.373) r2: (train=0.969, test=0.789) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.736, test=-1.522) neg_mean_squared_error: (train=-1.329, test=-6.561) r2: (train=0.959, test=0.828) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.734, test=-1.955) neg_mean_squared_error: (train=-1.213, test=-7.160) r2: (train=0.963, test=0.811) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.784, test=-2.256) neg_mean_squared_error: (train=-1.394, test=-10.208) r2: (train=0.957, test=0.737) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.783, test=-1.210) neg_mean_squared_error: (train=-1.272, test=-3.063) r2: (train=0.967, test=0.756) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.740, test=-1.868) neg_mean_squared_error: (train=-1.031, test=-6.181) r2: (train=0.971, test=0.796) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.693, test=-1.525) neg_mean_squared_error: (train=-1.195, test=-6.774) r2: (train=0.963, test=0.822) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.736, test=-1.922) neg_mean_squared_error: (train=-1.198, test=-6.721) r2: (train=0.963, test=0.822) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.771, test=-2.309) neg_mean_squared_error: (train=-1.297, test=-10.412) r2: (train=0.960, test=0.732) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.787, test=-1.222) neg_mean_squared_error: (train=-1.300, test=-3.137) r2: (train=0.966, test=0.750) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.725, test=-1.879) neg_mean_squared_error: (train=-1.002, test=-6.184) r2: (train=0.971, test=0.796) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.700, test=-1.538) neg_mean_squared_error: (train=-1.233, test=-7.142) r2: (train=0.962, test=0.813) total time=   0.0s
# MAE: 3.9167587388254432
# MAPE: 0.05237261143123797

# %%
np.savez(MISC_DIR / 'current_model_1.npz', 
         y_pred_train_3 = y_pred_train, 
         y_train_3 = y_train, 
         y_pred_val_3 = y_pred, 
         y_val_3 = y_test, 
         y_pred_test_3 = y_pred_new_test,
         y_test_3 = y_new_test)

# %% [markdown]
# #### (3.5) k-nearest neighbors model
# The target is predicted by local interpolation of the targets associated of the nearest neighbors in the training set.

# %%
model = KNeighborsRegressor()

#Now we use scikit learn to train a k-nearest neighbors model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae5 = mean_absolute_error(y_new_test, y_pred_new_test)
mape5 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae5)
print('MAPE:', mape5)

plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.810, test=-3.451) neg_mean_squared_error: (train=-8.759, test=-22.293) r2: (train=0.766, test=0.236) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.363, test=-3.418) neg_mean_squared_error: (train=-5.257, test=-19.846) r2: (train=0.826, test=0.644) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.658, test=-3.960) neg_mean_squared_error: (train=-7.195, test=-26.211) r2: (train=0.769, test=0.515) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-2.003, test=-3.241) neg_mean_squared_error: (train=-9.051, test=-17.496) r2: (train=0.762, test=0.334) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.406, test=-4.021) neg_mean_squared_error: (train=-6.116, test=-18.130) r2: (train=0.852, test=-1.090) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.884) neg_mean_squared_error: (train=-0.000, test=-14.524) r2: (train=1.000, test=0.502) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.109) neg_mean_squared_error: (train=-0.000, test=-16.909) r2: (train=1.000, test=0.697) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-23.807) r2: (train=1.000, test=0.560) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.760) neg_mean_squared_error: (train=-0.000, test=-14.499) r2: (train=1.000, test=0.448) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.826) neg_mean_squared_error: (train=-0.000, test=-17.222) r2: (train=1.000, test=-0.985) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.694, test=-4.077) neg_mean_squared_error: (train=-13.069, test=-30.611) r2: (train=0.651, test=-0.050) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.476, test=-4.218) neg_mean_squared_error: (train=-10.964, test=-30.363) r2: (train=0.637, test=0.456) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.637, test=-4.164) neg_mean_squared_error: (train=-13.266, test=-28.891) r2: (train=0.574, test=0.466) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.873, test=-3.825) neg_mean_squared_error: (train=-14.487, test=-18.221) r2: (train=0.619, test=0.307) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.356, test=-3.487) neg_mean_squared_error: (train=-11.219, test=-15.356) r2: (train=0.729, test=-0.770) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.425) neg_mean_squared_error: (train=-0.000, test=-20.171) r2: (train=1.000, test=0.308) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.555) neg_mean_squared_error: (train=-0.000, test=-21.419) r2: (train=1.000, test=0.616) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.686) neg_mean_squared_error: (train=-0.000, test=-25.123) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.210) neg_mean_squared_error: (train=-0.000, test=-13.488) r2: (train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.400) neg_mean_squared_error: (train=-0.000, test=-14.676) r2: (train=1.000, test=-0.692) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.183, test=-4.078) neg_mean_squared_error: (train=-15.635, test=-34.838) r2: (train=0.583, test=-0.195) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.893, test=-4.562) neg_mean_squared_error: (train=-14.711, test=-35.933) r2: (train=0.513, test=0.356) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.883, test=-4.487) neg_mean_squared_error: (train=-15.341, test=-32.789) r2: (train=0.507, test=0.394) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.089, test=-4.068) neg_mean_squared_error: (train=-16.913, test=-23.750) r2: (train=0.555, test=0.096) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.126, test=-3.171) neg_mean_squared_error: (train=-16.284, test=-13.402) r2: (train=0.607, test=-0.545) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.387) neg_mean_squared_error: (train=-0.000, test=-22.769) r2: (train=1.000, test=0.219) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.731) neg_mean_squared_error: (train=-0.000, test=-25.697) r2: (train=1.000, test=0.539) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.963) neg_mean_squared_error: (train=-0.000, test=-26.965) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.480) neg_mean_squared_error: (train=-0.000, test=-16.459) r2: (train=1.000, test=0.374) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.212) neg_mean_squared_error: (train=-0.000, test=-12.818) r2: (train=1.000, test=-0.477) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.392, test=-3.780) neg_mean_squared_error: (train=-17.677, test=-28.037) r2: (train=0.528, test=0.039) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.087, test=-4.594) neg_mean_squared_error: (train=-16.139, test=-34.656) r2: (train=0.466, test=0.379) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.970, test=-4.161) neg_mean_squared_error: (train=-15.699, test=-31.466) r2: (train=0.496, test=0.418) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.404, test=-4.000) neg_mean_squared_error: (train=-18.574, test=-23.974) r2: (train=0.512, test=0.088) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.532, test=-2.693) neg_mean_squared_error: (train=-21.305, test=-10.339) r2: (train=0.486, test=-0.192) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.288) neg_mean_squared_error: (train=-0.000, test=-19.852) r2: (train=1.000, test=0.319) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.800) neg_mean_squared_error: (train=-0.000, test=-26.298) r2: (train=1.000, test=0.529) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.627) neg_mean_squared_error: (train=-0.000, test=-25.315) r2: (train=1.000, test=0.532) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.229) neg_mean_squared_error: (train=-0.000, test=-15.581) r2: (train=1.000, test=0.407) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.826) neg_mean_squared_error: (train=-0.000, test=-9.883) r2: (train=1.000, test=-0.139) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.631, test=-3.961) neg_mean_squared_error: (train=-20.142, test=-26.732) r2: (train=0.462, test=0.083) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.213, test=-4.701) neg_mean_squared_error: (train=-16.814, test=-35.870) r2: (train=0.444, test=0.357) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.006, test=-4.224) neg_mean_squared_error: (train=-15.840, test=-29.076) r2: (train=0.491, test=0.462) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.557, test=-4.206) neg_mean_squared_error: (train=-19.607, test=-26.554) r2: (train=0.484, test=-0.010) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.533, test=-2.761) neg_mean_squared_error: (train=-21.595, test=-11.474) r2: (train=0.479, test=-0.323) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.442) neg_mean_squared_error: (train=-0.000, test=-19.965) r2: (train=1.000, test=0.315) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.873) neg_mean_squared_error: (train=-0.000, test=-27.639) r2: (train=1.000, test=0.505) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.730) neg_mean_squared_error: (train=-0.000, test=-23.192) r2: (train=1.000, test=0.571) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.348) neg_mean_squared_error: (train=-0.000, test=-17.001) r2: (train=1.000, test=0.353) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.619) neg_mean_squared_error: (train=-0.000, test=-9.685) r2: (train=1.000, test=-0.116) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.524, test=-3.750) neg_mean_squared_error: (train=-20.038, test=-23.368) r2: (train=0.465, test=0.199) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.238, test=-4.724) neg_mean_squared_error: (train=-17.284, test=-34.326) r2: (train=0.428, test=0.385) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.100, test=-4.468) neg_mean_squared_error: (train=-17.979, test=-34.509) r2: (train=0.423, test=0.362) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.586, test=-4.167) neg_mean_squared_error: (train=-20.105, test=-27.937) r2: (train=0.471, test=-0.063) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.730, test=-2.546) neg_mean_squared_error: (train=-22.486, test=-10.425) r2: (train=0.457, test=-0.202) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.308) neg_mean_squared_error: (train=-0.000, test=-18.077) r2: (train=1.000, test=0.380) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.870) neg_mean_squared_error: (train=-0.000, test=-27.006) r2: (train=1.000, test=0.516) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.897) neg_mean_squared_error: (train=-0.000, test=-26.591) r2: (train=1.000, test=0.508) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.336) neg_mean_squared_error: (train=-0.000, test=-18.085) r2: (train=1.000, test=0.312) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.454) neg_mean_squared_error: (train=-0.000, test=-8.866) r2: (train=1.000, test=-0.022) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.719, test=-3.497) neg_mean_squared_error: (train=-21.037, test=-18.976) r2: (train=0.438, test=0.349) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.263, test=-4.916) neg_mean_squared_error: (train=-17.433, test=-36.409) r2: (train=0.423, test=0.347) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.278, test=-4.240) neg_mean_squared_error: (train=-18.596, test=-32.194) r2: (train=0.403, test=0.405) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.657, test=-4.052) neg_mean_squared_error: (train=-20.747, test=-27.010) r2: (train=0.454, test=-0.028) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.642, test=-2.626) neg_mean_squared_error: (train=-20.968, test=-10.401) r2: (train=0.494, test=-0.199) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.127) neg_mean_squared_error: (train=-0.000, test=-15.654) r2: (train=1.000, test=0.463) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.050) neg_mean_squared_error: (train=-0.000, test=-28.342) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.729) neg_mean_squared_error: (train=-0.000, test=-25.126) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.351) neg_mean_squared_error: (train=-0.000, test=-18.536) r2: (train=1.000, test=0.295) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.561) neg_mean_squared_error: (train=-0.000, test=-9.259) r2: (train=1.000, test=-0.067) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.830, test=-3.590) neg_mean_squared_error: (train=-22.141, test=-19.594) r2: (train=0.409, test=0.328) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.352, test=-4.935) neg_mean_squared_error: (train=-18.033, test=-35.498) r2: (train=0.403, test=0.364) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.454, test=-4.321) neg_mean_squared_error: (train=-19.237, test=-29.903) r2: (train=0.382, test=0.447) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.681, test=-4.169) neg_mean_squared_error: (train=-21.167, test=-26.255) r2: (train=0.443, test=0.001) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.862, test=-2.485) neg_mean_squared_error: (train=-23.372, test=-9.809) r2: (train=0.436, test=-0.131) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.201) neg_mean_squared_error: (train=-0.000, test=-16.006) r2: (train=1.000, test=0.451) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.098) neg_mean_squared_error: (train=-0.000, test=-27.848) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.794) neg_mean_squared_error: (train=-0.000, test=-24.097) r2: (train=1.000, test=0.554) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.423) neg_mean_squared_error: (train=-0.000, test=-18.843) r2: (train=1.000, test=0.283) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.444) neg_mean_squared_error: (train=-0.000, test=-8.683) r2: (train=1.000, test=-0.001) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.810, test=-3.451) neg_mean_squared_error: (train=-8.759, test=-22.293) r2: (train=0.766, test=0.236) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.363, test=-3.418) neg_mean_squared_error: (train=-5.257, test=-19.846) r2: (train=0.826, test=0.644) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.658, test=-3.960) neg_mean_squared_error: (train=-7.195, test=-26.211) r2: (train=0.769, test=0.515) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-2.003, test=-3.241) neg_mean_squared_error: (train=-9.051, test=-17.496) r2: (train=0.762, test=0.334) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.406, test=-4.021) neg_mean_squared_error: (train=-6.116, test=-18.130) r2: (train=0.852, test=-1.090) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.884) neg_mean_squared_error: (train=-0.000, test=-14.524) r2: (train=1.000, test=0.502) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.109) neg_mean_squared_error: (train=-0.000, test=-16.909) r2: (train=1.000, test=0.697) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-23.807) r2: (train=1.000, test=0.560) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.760) neg_mean_squared_error: (train=-0.000, test=-14.499) r2: (train=1.000, test=0.448) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.826) neg_mean_squared_error: (train=-0.000, test=-17.222) r2: (train=1.000, test=-0.985) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.694, test=-4.077) neg_mean_squared_error: (train=-13.069, test=-30.611) r2: (train=0.651, test=-0.050) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.476, test=-4.218) neg_mean_squared_error: (train=-10.964, test=-30.363) r2: (train=0.637, test=0.456) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.637, test=-4.164) neg_mean_squared_error: (train=-13.266, test=-28.891) r2: (train=0.574, test=0.466) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.873, test=-3.825) neg_mean_squared_error: (train=-14.487, test=-18.221) r2: (train=0.619, test=0.307) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.356, test=-3.487) neg_mean_squared_error: (train=-11.219, test=-15.356) r2: (train=0.729, test=-0.770) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.425) neg_mean_squared_error: (train=-0.000, test=-20.171) r2: (train=1.000, test=0.308) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.555) neg_mean_squared_error: (train=-0.000, test=-21.419) r2: (train=1.000, test=0.616) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.686) neg_mean_squared_error: (train=-0.000, test=-25.123) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.210) neg_mean_squared_error: (train=-0.000, test=-13.488) r2: (train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.400) neg_mean_squared_error: (train=-0.000, test=-14.676) r2: (train=1.000, test=-0.692) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.183, test=-4.078) neg_mean_squared_error: (train=-15.635, test=-34.838) r2: (train=0.583, test=-0.195) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.893, test=-4.562) neg_mean_squared_error: (train=-14.711, test=-35.933) r2: (train=0.513, test=0.356) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.883, test=-4.487) neg_mean_squared_error: (train=-15.341, test=-32.789) r2: (train=0.507, test=0.394) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.089, test=-4.068) neg_mean_squared_error: (train=-16.913, test=-23.750) r2: (train=0.555, test=0.096) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.126, test=-3.171) neg_mean_squared_error: (train=-16.284, test=-13.402) r2: (train=0.607, test=-0.545) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.387) neg_mean_squared_error: (train=-0.000, test=-22.769) r2: (train=1.000, test=0.219) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.731) neg_mean_squared_error: (train=-0.000, test=-25.697) r2: (train=1.000, test=0.539) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.963) neg_mean_squared_error: (train=-0.000, test=-26.965) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.480) neg_mean_squared_error: (train=-0.000, test=-16.459) r2: (train=1.000, test=0.374) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.212) neg_mean_squared_error: (train=-0.000, test=-12.818) r2: (train=1.000, test=-0.477) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.392, test=-3.780) neg_mean_squared_error: (train=-17.677, test=-28.037) r2: (train=0.528, test=0.039) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.087, test=-4.594) neg_mean_squared_error: (train=-16.139, test=-34.656) r2: (train=0.466, test=0.379) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.970, test=-4.161) neg_mean_squared_error: (train=-15.699, test=-31.466) r2: (train=0.496, test=0.418) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.404, test=-4.000) neg_mean_squared_error: (train=-18.574, test=-23.974) r2: (train=0.512, test=0.088) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.532, test=-2.693) neg_mean_squared_error: (train=-21.305, test=-10.339) r2: (train=0.486, test=-0.192) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.288) neg_mean_squared_error: (train=-0.000, test=-19.852) r2: (train=1.000, test=0.319) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.800) neg_mean_squared_error: (train=-0.000, test=-26.298) r2: (train=1.000, test=0.529) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.627) neg_mean_squared_error: (train=-0.000, test=-25.315) r2: (train=1.000, test=0.532) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.229) neg_mean_squared_error: (train=-0.000, test=-15.581) r2: (train=1.000, test=0.407) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.826) neg_mean_squared_error: (train=-0.000, test=-9.883) r2: (train=1.000, test=-0.139) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.631, test=-3.961) neg_mean_squared_error: (train=-20.142, test=-26.732) r2: (train=0.462, test=0.083) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.213, test=-4.701) neg_mean_squared_error: (train=-16.814, test=-35.870) r2: (train=0.444, test=0.357) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.006, test=-4.224) neg_mean_squared_error: (train=-15.840, test=-29.076) r2: (train=0.491, test=0.462) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.557, test=-4.206) neg_mean_squared_error: (train=-19.607, test=-26.554) r2: (train=0.484, test=-0.010) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.533, test=-2.761) neg_mean_squared_error: (train=-21.595, test=-11.474) r2: (train=0.479, test=-0.323) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.442) neg_mean_squared_error: (train=-0.000, test=-19.965) r2: (train=1.000, test=0.315) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.873) neg_mean_squared_error: (train=-0.000, test=-27.639) r2: (train=1.000, test=0.505) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.730) neg_mean_squared_error: (train=-0.000, test=-23.192) r2: (train=1.000, test=0.571) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.348) neg_mean_squared_error: (train=-0.000, test=-17.001) r2: (train=1.000, test=0.353) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.619) neg_mean_squared_error: (train=-0.000, test=-9.685) r2: (train=1.000, test=-0.116) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.524, test=-3.750) neg_mean_squared_error: (train=-20.038, test=-23.368) r2: (train=0.465, test=0.199) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.238, test=-4.724) neg_mean_squared_error: (train=-17.284, test=-34.326) r2: (train=0.428, test=0.385) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.100, test=-4.468) neg_mean_squared_error: (train=-17.979, test=-34.509) r2: (train=0.423, test=0.362) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.586, test=-4.167) neg_mean_squared_error: (train=-20.105, test=-27.937) r2: (train=0.471, test=-0.063) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.730, test=-2.546) neg_mean_squared_error: (train=-22.486, test=-10.425) r2: (train=0.457, test=-0.202) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.308) neg_mean_squared_error: (train=-0.000, test=-18.077) r2: (train=1.000, test=0.380) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.870) neg_mean_squared_error: (train=-0.000, test=-27.006) r2: (train=1.000, test=0.516) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.897) neg_mean_squared_error: (train=-0.000, test=-26.591) r2: (train=1.000, test=0.508) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.336) neg_mean_squared_error: (train=-0.000, test=-18.085) r2: (train=1.000, test=0.312) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.454) neg_mean_squared_error: (train=-0.000, test=-8.866) r2: (train=1.000, test=-0.022) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.719, test=-3.497) neg_mean_squared_error: (train=-21.037, test=-18.976) r2: (train=0.438, test=0.349) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.263, test=-4.916) neg_mean_squared_error: (train=-17.433, test=-36.409) r2: (train=0.423, test=0.347) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.278, test=-4.240) neg_mean_squared_error: (train=-18.596, test=-32.194) r2: (train=0.403, test=0.405) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.657, test=-4.052) neg_mean_squared_error: (train=-20.747, test=-27.010) r2: (train=0.454, test=-0.028) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.642, test=-2.626) neg_mean_squared_error: (train=-20.968, test=-10.401) r2: (train=0.494, test=-0.199) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.127) neg_mean_squared_error: (train=-0.000, test=-15.654) r2: (train=1.000, test=0.463) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.050) neg_mean_squared_error: (train=-0.000, test=-28.342) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.729) neg_mean_squared_error: (train=-0.000, test=-25.126) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.351) neg_mean_squared_error: (train=-0.000, test=-18.536) r2: (train=1.000, test=0.295) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.561) neg_mean_squared_error: (train=-0.000, test=-9.259) r2: (train=1.000, test=-0.067) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.830, test=-3.590) neg_mean_squared_error: (train=-22.141, test=-19.594) r2: (train=0.409, test=0.328) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.352, test=-4.935) neg_mean_squared_error: (train=-18.033, test=-35.498) r2: (train=0.403, test=0.364) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.454, test=-4.321) neg_mean_squared_error: (train=-19.237, test=-29.903) r2: (train=0.382, test=0.447) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.681, test=-4.169) neg_mean_squared_error: (train=-21.167, test=-26.255) r2: (train=0.443, test=0.001) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.862, test=-2.485) neg_mean_squared_error: (train=-23.372, test=-9.809) r2: (train=0.436, test=-0.131) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.201) neg_mean_squared_error: (train=-0.000, test=-16.006) r2: (train=1.000, test=0.451) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.098) neg_mean_squared_error: (train=-0.000, test=-27.848) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.794) neg_mean_squared_error: (train=-0.000, test=-24.097) r2: (train=1.000, test=0.554) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.423) neg_mean_squared_error: (train=-0.000, test=-18.843) r2: (train=1.000, test=0.283) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.444) neg_mean_squared_error: (train=-0.000, test=-8.683) r2: (train=1.000, test=-0.001) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.810, test=-3.451) neg_mean_squared_error: (train=-8.759, test=-22.293) r2: (train=0.766, test=0.236) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.363, test=-3.418) neg_mean_squared_error: (train=-5.257, test=-19.846) r2: (train=0.826, test=0.644) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.658, test=-3.960) neg_mean_squared_error: (train=-7.195, test=-26.211) r2: (train=0.769, test=0.515) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-2.003, test=-3.241) neg_mean_squared_error: (train=-9.051, test=-17.496) r2: (train=0.762, test=0.334) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.406, test=-4.021) neg_mean_squared_error: (train=-6.116, test=-18.130) r2: (train=0.852, test=-1.090) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.884) neg_mean_squared_error: (train=-0.000, test=-14.524) r2: (train=1.000, test=0.502) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.109) neg_mean_squared_error: (train=-0.000, test=-16.909) r2: (train=1.000, test=0.697) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-23.807) r2: (train=1.000, test=0.560) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.760) neg_mean_squared_error: (train=-0.000, test=-14.499) r2: (train=1.000, test=0.448) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.826) neg_mean_squared_error: (train=-0.000, test=-17.222) r2: (train=1.000, test=-0.985) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.694, test=-4.077) neg_mean_squared_error: (train=-13.069, test=-30.611) r2: (train=0.651, test=-0.050) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.476, test=-4.218) neg_mean_squared_error: (train=-10.964, test=-30.363) r2: (train=0.637, test=0.456) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.637, test=-4.164) neg_mean_squared_error: (train=-13.266, test=-28.891) r2: (train=0.574, test=0.466) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.873, test=-3.825) neg_mean_squared_error: (train=-14.487, test=-18.221) r2: (train=0.619, test=0.307) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.356, test=-3.487) neg_mean_squared_error: (train=-11.219, test=-15.356) r2: (train=0.729, test=-0.770) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.425) neg_mean_squared_error: (train=-0.000, test=-20.171) r2: (train=1.000, test=0.308) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.555) neg_mean_squared_error: (train=-0.000, test=-21.419) r2: (train=1.000, test=0.616) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.686) neg_mean_squared_error: (train=-0.000, test=-25.123) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.210) neg_mean_squared_error: (train=-0.000, test=-13.488) r2: (train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.400) neg_mean_squared_error: (train=-0.000, test=-14.676) r2: (train=1.000, test=-0.692) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.183, test=-4.078) neg_mean_squared_error: (train=-15.635, test=-34.838) r2: (train=0.583, test=-0.195) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.893, test=-4.562) neg_mean_squared_error: (train=-14.711, test=-35.933) r2: (train=0.513, test=0.356) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.883, test=-4.487) neg_mean_squared_error: (train=-15.341, test=-32.789) r2: (train=0.507, test=0.394) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.089, test=-4.068) neg_mean_squared_error: (train=-16.913, test=-23.750) r2: (train=0.555, test=0.096) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-3.126, test=-3.171) neg_mean_squared_error: (train=-16.284, test=-13.402) r2: (train=0.607, test=-0.545) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.387) neg_mean_squared_error: (train=-0.000, test=-22.769) r2: (train=1.000, test=0.219) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.731) neg_mean_squared_error: (train=-0.000, test=-25.697) r2: (train=1.000, test=0.539) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.963) neg_mean_squared_error: (train=-0.000, test=-26.965) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.480) neg_mean_squared_error: (train=-0.000, test=-16.459) r2: (train=1.000, test=0.374) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.212) neg_mean_squared_error: (train=-0.000, test=-12.818) r2: (train=1.000, test=-0.477) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.392, test=-3.780) neg_mean_squared_error: (train=-17.677, test=-28.037) r2: (train=0.528, test=0.039) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.087, test=-4.594) neg_mean_squared_error: (train=-16.139, test=-34.656) r2: (train=0.466, test=0.379) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.970, test=-4.161) neg_mean_squared_error: (train=-15.699, test=-31.466) r2: (train=0.496, test=0.418) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.404, test=-4.000) neg_mean_squared_error: (train=-18.574, test=-23.974) r2: (train=0.512, test=0.088) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.532, test=-2.693) neg_mean_squared_error: (train=-21.305, test=-10.339) r2: (train=0.486, test=-0.192) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.288) neg_mean_squared_error: (train=-0.000, test=-19.852) r2: (train=1.000, test=0.319) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.800) neg_mean_squared_error: (train=-0.000, test=-26.298) r2: (train=1.000, test=0.529) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.627) neg_mean_squared_error: (train=-0.000, test=-25.315) r2: (train=1.000, test=0.532) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.229) neg_mean_squared_error: (train=-0.000, test=-15.581) r2: (train=1.000, test=0.407) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.826) neg_mean_squared_error: (train=-0.000, test=-9.883) r2: (train=1.000, test=-0.139) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.631, test=-3.961) neg_mean_squared_error: (train=-20.142, test=-26.732) r2: (train=0.462, test=0.083) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.213, test=-4.701) neg_mean_squared_error: (train=-16.814, test=-35.870) r2: (train=0.444, test=0.357) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.006, test=-4.224) neg_mean_squared_error: (train=-15.840, test=-29.076) r2: (train=0.491, test=0.462) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.557, test=-4.206) neg_mean_squared_error: (train=-19.607, test=-26.554) r2: (train=0.484, test=-0.010) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.533, test=-2.761) neg_mean_squared_error: (train=-21.595, test=-11.474) r2: (train=0.479, test=-0.323) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.442) neg_mean_squared_error: (train=-0.000, test=-19.965) r2: (train=1.000, test=0.315) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.873) neg_mean_squared_error: (train=-0.000, test=-27.639) r2: (train=1.000, test=0.505) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.730) neg_mean_squared_error: (train=-0.000, test=-23.192) r2: (train=1.000, test=0.571) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.348) neg_mean_squared_error: (train=-0.000, test=-17.001) r2: (train=1.000, test=0.353) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.619) neg_mean_squared_error: (train=-0.000, test=-9.685) r2: (train=1.000, test=-0.116) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.524, test=-3.750) neg_mean_squared_error: (train=-20.038, test=-23.368) r2: (train=0.465, test=0.199) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.238, test=-4.724) neg_mean_squared_error: (train=-17.284, test=-34.326) r2: (train=0.428, test=0.385) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.100, test=-4.468) neg_mean_squared_error: (train=-17.979, test=-34.509) r2: (train=0.423, test=0.362) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.586, test=-4.167) neg_mean_squared_error: (train=-20.105, test=-27.937) r2: (train=0.471, test=-0.063) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.730, test=-2.546) neg_mean_squared_error: (train=-22.486, test=-10.425) r2: (train=0.457, test=-0.202) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.308) neg_mean_squared_error: (train=-0.000, test=-18.077) r2: (train=1.000, test=0.380) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.870) neg_mean_squared_error: (train=-0.000, test=-27.006) r2: (train=1.000, test=0.516) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.897) neg_mean_squared_error: (train=-0.000, test=-26.591) r2: (train=1.000, test=0.508) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.336) neg_mean_squared_error: (train=-0.000, test=-18.085) r2: (train=1.000, test=0.312) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.454) neg_mean_squared_error: (train=-0.000, test=-8.866) r2: (train=1.000, test=-0.022) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.719, test=-3.497) neg_mean_squared_error: (train=-21.037, test=-18.976) r2: (train=0.438, test=0.349) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.263, test=-4.916) neg_mean_squared_error: (train=-17.433, test=-36.409) r2: (train=0.423, test=0.347) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.278, test=-4.240) neg_mean_squared_error: (train=-18.596, test=-32.194) r2: (train=0.403, test=0.405) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.657, test=-4.052) neg_mean_squared_error: (train=-20.747, test=-27.010) r2: (train=0.454, test=-0.028) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.642, test=-2.626) neg_mean_squared_error: (train=-20.968, test=-10.401) r2: (train=0.494, test=-0.199) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.127) neg_mean_squared_error: (train=-0.000, test=-15.654) r2: (train=1.000, test=0.463) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.050) neg_mean_squared_error: (train=-0.000, test=-28.342) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.729) neg_mean_squared_error: (train=-0.000, test=-25.126) r2: (train=1.000, test=0.535) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.351) neg_mean_squared_error: (train=-0.000, test=-18.536) r2: (train=1.000, test=0.295) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.561) neg_mean_squared_error: (train=-0.000, test=-9.259) r2: (train=1.000, test=-0.067) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.830, test=-3.590) neg_mean_squared_error: (train=-22.141, test=-19.594) r2: (train=0.409, test=0.328) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.352, test=-4.935) neg_mean_squared_error: (train=-18.033, test=-35.498) r2: (train=0.403, test=0.364) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.454, test=-4.321) neg_mean_squared_error: (train=-19.237, test=-29.903) r2: (train=0.382, test=0.447) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.681, test=-4.169) neg_mean_squared_error: (train=-21.167, test=-26.255) r2: (train=0.443, test=0.001) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.862, test=-2.485) neg_mean_squared_error: (train=-23.372, test=-9.809) r2: (train=0.436, test=-0.131) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.201) neg_mean_squared_error: (train=-0.000, test=-16.006) r2: (train=1.000, test=0.451) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.098) neg_mean_squared_error: (train=-0.000, test=-27.848) r2: (train=1.000, test=0.501) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.794) neg_mean_squared_error: (train=-0.000, test=-24.097) r2: (train=1.000, test=0.554) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.423) neg_mean_squared_error: (train=-0.000, test=-18.843) r2: (train=1.000, test=0.283) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.444) neg_mean_squared_error: (train=-0.000, test=-8.683) r2: (train=1.000, test=-0.001) total time=   0.0s
# MAE: 5.123250790686661
# MAPE: 0.06778697745964983

# %% [markdown]
# #### (3.6) Gaussian process model

# %%
model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)

#Now we use scikit learn to train a random forest model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
y_pred_new_test = model.predict(X_new_test)
mae6 = mean_absolute_error(y_new_test, y_pred_new_test)
mape6 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae6)
print('MAPE:', mape6)

plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-2.194) neg_mean_squared_error: (train=-0.000, test=-9.479) r2: (train=1.000, test=0.675) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.487) neg_mean_squared_error: (train=-0.000, test=-11.126) r2: (train=1.000, test=0.801) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.721) neg_mean_squared_error: (train=-0.000, test=-12.376) r2: (train=1.000, test=0.771) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-1.534) neg_mean_squared_error: (train=-0.000, test=-6.531) r2: (train=1.000, test=0.751) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.003, test=-2.570) neg_mean_squared_error: (train=-0.000, test=-9.077) r2: (train=1.000, test=-0.046) total time=   0.0s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.002, test=-1.844) neg_mean_squared_error: (train=-0.000, test=-10.039) r2: (train=1.000, test=0.656) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.001, test=-1.916) neg_mean_squared_error: (train=-0.000, test=-7.001) r2: (train=1.000, test=0.875) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.002, test=-1.655) neg_mean_squared_error: (train=-0.000, test=-4.608) r2: (train=1.000, test=0.915) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.002, test=-0.986) neg_mean_squared_error: (train=-0.000, test=-2.916) r2: (train=1.000, test=0.889) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.002, test=-2.177) neg_mean_squared_error: (train=-0.000, test=-6.351) r2: (train=1.000, test=0.268) total time=   0.0s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-1.987) neg_mean_squared_error: (train=-0.000, test=-10.112) r2: (train=1.000, test=0.653) total time=   0.1s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-2.141) neg_mean_squared_error: (train=-0.000, test=-8.071) r2: (train=1.000, test=0.855) total time=   0.1s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.471) neg_mean_squared_error: (train=-0.000, test=-10.074) r2: (train=1.000, test=0.814) total time=   0.1s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-1.134) neg_mean_squared_error: (train=-0.000, test=-3.713) r2: (train=1.000, test=0.859) total time=   0.1s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-2.223) neg_mean_squared_error: (train=-0.000, test=-7.162) r2: (train=1.000, test=0.174) total time=   0.1s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-4.294) neg_mean_squared_error: (train=-0.000, test=-29.174) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-6.049) neg_mean_squared_error: (train=-0.000, test=-58.561) r2: (train=1.000, test=-0.050) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-5.494) neg_mean_squared_error: (train=-0.000, test=-54.339) r2: (train=1.000, test=-0.005) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-3.408) neg_mean_squared_error: (train=-0.000, test=-26.290) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-3.079) neg_mean_squared_error: (train=-0.000, test=-13.377) r2: (train=1.000, test=-0.542) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.021, test=-2.184) neg_mean_squared_error: (train=-0.001, test=-9.656) r2: (train=1.000, test=0.669) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.013, test=-2.460) neg_mean_squared_error: (train=-0.000, test=-10.852) r2: (train=1.000, test=0.805) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.009, test=-2.703) neg_mean_squared_error: (train=-0.000, test=-12.222) r2: (train=1.000, test=0.774) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.016, test=-1.524) neg_mean_squared_error: (train=-0.001, test=-6.268) r2: (train=1.000, test=0.761) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.025, test=-2.635) neg_mean_squared_error: (train=-0.001, test=-9.502) r2: (train=1.000, test=-0.095) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.017, test=-1.840) neg_mean_squared_error: (train=-0.001, test=-9.996) r2: (train=1.000, test=0.657) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.014, test=-1.917) neg_mean_squared_error: (train=-0.001, test=-7.000) r2: (train=1.000, test=0.875) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.015, test=-1.652) neg_mean_squared_error: (train=-0.001, test=-4.593) r2: (train=1.000, test=0.915) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.018, test=-0.998) neg_mean_squared_error: (train=-0.001, test=-2.914) r2: (train=1.000, test=0.889) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.019, test=-2.176) neg_mean_squared_error: (train=-0.001, test=-6.355) r2: (train=1.000, test=0.268) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.020, test=-2.028) neg_mean_squared_error: (train=-0.001, test=-10.048) r2: (train=1.000, test=0.655) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.015, test=-2.134) neg_mean_squared_error: (train=-0.001, test=-7.968) r2: (train=1.000, test=0.857) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.008, test=-2.461) neg_mean_squared_error: (train=-0.000, test=-9.980) r2: (train=1.000, test=0.815) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.017, test=-1.110) neg_mean_squared_error: (train=-0.001, test=-3.624) r2: (train=1.000, test=0.862) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.021, test=-2.296) neg_mean_squared_error: (train=-0.001, test=-7.348) r2: (train=1.000, test=0.153) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-4.294) neg_mean_squared_error: (train=-0.000, test=-29.174) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-6.049) neg_mean_squared_error: (train=-0.000, test=-58.561) r2: (train=1.000, test=-0.050) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-5.494) neg_mean_squared_error: (train=-0.000, test=-54.339) r2: (train=1.000, test=-0.005) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.005, test=-3.408) neg_mean_squared_error: (train=-0.000, test=-26.290) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.005, test=-3.079) neg_mean_squared_error: (train=-0.000, test=-13.377) r2: (train=1.000, test=-0.542) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.161, test=-2.203) neg_mean_squared_error: (train=-0.059, test=-10.176) r2: (train=0.998, test=0.651) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.155, test=-2.223) neg_mean_squared_error: (train=-0.055, test=-7.825) r2: (train=0.998, test=0.860) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.088, test=-2.506) neg_mean_squared_error: (train=-0.019, test=-10.395) r2: (train=0.999, test=0.808) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.170, test=-1.443) neg_mean_squared_error: (train=-0.060, test=-5.258) r2: (train=0.998, test=0.800) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.167, test=-2.590) neg_mean_squared_error: (train=-0.059, test=-9.108) r2: (train=0.999, test=-0.050) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.150, test=-1.796) neg_mean_squared_error: (train=-0.051, test=-9.703) r2: (train=0.999, test=0.667) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.133, test=-1.916) neg_mean_squared_error: (train=-0.044, test=-7.079) r2: (train=0.999, test=0.873) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.143, test=-1.633) neg_mean_squared_error: (train=-0.045, test=-4.410) r2: (train=0.999, test=0.918) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.169, test=-1.073) neg_mean_squared_error: (train=-0.059, test=-2.929) r2: (train=0.998, test=0.889) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.155, test=-2.139) neg_mean_squared_error: (train=-0.052, test=-6.243) r2: (train=0.999, test=0.280) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.162, test=-2.040) neg_mean_squared_error: (train=-0.061, test=-10.228) r2: (train=0.998, test=0.649) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.139, test=-2.090) neg_mean_squared_error: (train=-0.049, test=-7.287) r2: (train=0.998, test=0.869) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.077, test=-2.366) neg_mean_squared_error: (train=-0.014, test=-8.981) r2: (train=1.000, test=0.834) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.177, test=-1.139) neg_mean_squared_error: (train=-0.065, test=-3.402) r2: (train=0.998, test=0.871) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.161, test=-2.350) neg_mean_squared_error: (train=-0.056, test=-7.519) r2: (train=0.999, test=0.133) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.045, test=-4.294) neg_mean_squared_error: (train=-0.004, test=-29.174) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.040, test=-6.049) neg_mean_squared_error: (train=-0.003, test=-58.561) r2: (train=1.000, test=-0.050) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.041, test=-5.494) neg_mean_squared_error: (train=-0.003, test=-54.339) r2: (train=1.000, test=-0.005) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.047, test=-3.408) neg_mean_squared_error: (train=-0.004, test=-26.290) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.055, test=-3.079) neg_mean_squared_error: (train=-0.011, test=-13.377) r2: (train=1.000, test=-0.542) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.087, test=-2.159) neg_mean_squared_error: (train=-2.232, test=-8.770) r2: (train=0.940, test=0.699) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.349, test=-2.445) neg_mean_squared_error: (train=-3.339, test=-11.325) r2: (train=0.890, test=0.797) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.239, test=-1.551) neg_mean_squared_error: (train=-2.868, test=-5.231) r2: (train=0.908, test=0.903) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.284, test=-1.864) neg_mean_squared_error: (train=-2.960, test=-5.339) r2: (train=0.922, test=0.797) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.216, test=-2.012) neg_mean_squared_error: (train=-3.107, test=-5.827) r2: (train=0.925, test=0.328) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.932, test=-1.765) neg_mean_squared_error: (train=-1.683, test=-5.970) r2: (train=0.955, test=0.795) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.962, test=-2.010) neg_mean_squared_error: (train=-1.877, test=-8.226) r2: (train=0.938, test=0.853) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-1.010, test=-1.586) neg_mean_squared_error: (train=-1.949, test=-5.138) r2: (train=0.937, test=0.905) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-1.138, test=-1.619) neg_mean_squared_error: (train=-2.463, test=-4.268) r2: (train=0.935, test=0.838) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-1.016, test=-1.851) neg_mean_squared_error: (train=-2.230, test=-4.871) r2: (train=0.946, test=0.439) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.087, test=-2.159) neg_mean_squared_error: (train=-2.232, test=-8.770) r2: (train=0.940, test=0.699) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.349, test=-2.445) neg_mean_squared_error: (train=-3.339, test=-11.325) r2: (train=0.890, test=0.797) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.025, test=-1.532) neg_mean_squared_error: (train=-2.036, test=-4.824) r2: (train=0.935, test=0.911) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.284, test=-1.864) neg_mean_squared_error: (train=-2.960, test=-5.339) r2: (train=0.922, test=0.797) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.216, test=-2.012) neg_mean_squared_error: (train=-3.107, test=-5.827) r2: (train=0.925, test=0.328) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.087, test=-2.159) neg_mean_squared_error: (train=-2.232, test=-8.770) r2: (train=0.940, test=0.699) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.349, test=-2.445) neg_mean_squared_error: (train=-3.339, test=-11.326) r2: (train=0.890, test=0.797) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.917, test=-1.616) neg_mean_squared_error: (train=-1.706, test=-4.665) r2: (train=0.945, test=0.914) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.284, test=-1.864) neg_mean_squared_error: (train=-2.960, test=-5.339) r2: (train=0.922, test=0.797) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.216, test=-2.012) neg_mean_squared_error: (train=-3.107, test=-5.827) r2: (train=0.925, test=0.328) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-3.196, test=-3.281) neg_mean_squared_error: (train=-18.522, test=-16.186) r2: (train=0.505, test=0.445) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.812, test=-4.628) neg_mean_squared_error: (train=-14.994, test=-33.912) r2: (train=0.504, test=0.392) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.932, test=-4.288) neg_mean_squared_error: (train=-16.086, test=-31.874) r2: (train=0.483, test=0.410) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-3.113, test=-3.041) neg_mean_squared_error: (train=-17.105, test=-16.485) r2: (train=0.550, test=0.373) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-3.198, test=-2.256) neg_mean_squared_error: (train=-17.813, test=-7.900) r2: (train=0.570, test=0.089) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-3.175, test=-3.306) neg_mean_squared_error: (train=-18.633, test=-16.863) r2: (train=0.502, test=0.422) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.801, test=-4.675) neg_mean_squared_error: (train=-15.313, test=-34.939) r2: (train=0.493, test=0.374) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.892, test=-4.275) neg_mean_squared_error: (train=-15.848, test=-32.113) r2: (train=0.491, test=0.406) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-3.107, test=-3.069) neg_mean_squared_error: (train=-17.327, test=-16.769) r2: (train=0.544, test=0.362) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-3.204, test=-2.179) neg_mean_squared_error: (train=-18.038, test=-7.639) r2: (train=0.565, test=0.119) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-3.196, test=-3.281) neg_mean_squared_error: (train=-18.522, test=-16.186) r2: (train=0.505, test=0.445) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.812, test=-4.628) neg_mean_squared_error: (train=-14.994, test=-33.912) r2: (train=0.504, test=0.392) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.932, test=-4.288) neg_mean_squared_error: (train=-16.085, test=-31.872) r2: (train=0.483, test=0.411) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-3.113, test=-3.041) neg_mean_squared_error: (train=-17.105, test=-16.485) r2: (train=0.550, test=0.373) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-3.198, test=-2.256) neg_mean_squared_error: (train=-17.813, test=-7.900) r2: (train=0.570, test=0.089) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-3.196, test=-3.281) neg_mean_squared_error: (train=-18.522, test=-16.186) r2: (train=0.505, test=0.445) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.812, test=-4.628) neg_mean_squared_error: (train=-14.994, test=-33.914) r2: (train=0.504, test=0.392) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.932, test=-4.288) neg_mean_squared_error: (train=-16.087, test=-31.877) r2: (train=0.483, test=0.410) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-3.113, test=-3.042) neg_mean_squared_error: (train=-17.109, test=-16.491) r2: (train=0.550, test=0.372) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-3.198, test=-2.256) neg_mean_squared_error: (train=-17.814, test=-7.900) r2: (train=0.570, test=0.089) total time=   0.0s
# MAE: 4.225194259082038
# MAPE: 0.05650726091233963

# %% [markdown]
# #### (3.7) Summary
# Compare the mean absolute percent error of each regression method. Each method is repeated 10 times by random train and test data, and average mean absolute percent errors are taken in order to make the results more general.

# %%
mape_t=np.zeros((10,6))
original_stdout = sys.stdout

for i in tqdm(range(10)):
    sys.stdout = open(os.devnull, 'w')
    
    mape=[]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    model = DecisionTreeRegressor()
    skf = KFold(n_splits=5, random_state=10, shuffle=True)
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    model = ExtraTreeRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    model = RandomForestRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    model = KNeighborsRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)
    model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    y_pred_new_test = model.predict(X_new_test)
    mape.append(mean_absolute_percentage_error(y_new_test, y_pred_new_test))

    mape_t[i]=mape
    sys.stdout = original_stdout
# Out:
# 100%|██████████| 10/10 [01:25<00:00,  8.56s/it]

# %%
sns.reset_orig()
plt.rcdefaults()
fig = plt.figure()
bars=plt.bar(['Linear','Decision tree','Extremely \nrandomrized tree',
              'Random forest','k-nearest \nneighbors','Gaussian process'],
              np.mean(mape_t,axis=0)*100, width = 0.5, color = '#5DA0B8')

plt.ylabel("Mean absolute percent error")
plt.bar_label(bars, fmt='%.2f%%')
plt.xticks(rotation = 45) 
plt.tight_layout()
plt.ylim(0, 12)
plt.savefig(PLOT_DIR / 'regression_current1.svg', format='svg', dpi=2000, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4. Benchmark how many seconds of data used for featurization affect the accuracy of prediction of SOC at 800 seconds

# %% [markdown]
# In this part, we will first obtain the SOC of all the time series data at 800 seconds. Then, we will cut all the data to 300 ~ $x$ seconds, and extract features from the already cut data. After that, we will use these features to predict the SOC at 800 seconds using different regression methods. We will increase $x$ from 325 to 800, with increments of 25, and observe the accuracy of prediction (mean absolute percent error) when $x$ is increasing. We will run the test for 10 times and take the average to ensure the accuracy of the result. The x axis of the plots will be calculated as (x-300) seconds.

# %%
def curve_plot(mape_t, label, color):
    # Calculate mean and standard error
    mean_mape = np.mean(mape_t, axis=0)
    std_error = np.std(mape_t, axis=0) / np.sqrt(mape_t.shape[0])

    # Calculate confidence interval
    confidence = 0.95
    n = mape_t.shape[0]
    t = np.abs(stats.t.ppf((1 - confidence) / 2, n - 1))
    margin_of_error = t * std_error
    confidence_interval = margin_of_error

    plt.plot(np.arange(25, 501, 25), mean_mape * 100, label = label, color = color)
    plt.fill_between(np.arange(25, 501, 25), (mean_mape - confidence_interval) * 100, (mean_mape + confidence_interval) * 100, alpha = 0.2, color = tuple(np.array(color) / 2))

# %%
def features_ext(dict):
    end_volts_arr = []
    med_curr_arr = []
    min_dvdt_arr = []
    curr_rise_arr = []
    soc_cc_arr = []
    
    for key in dict.keys():
        # End Voltage
        end_volts = dict[key]['Voltage (V)'].iloc[-1]
        end_volts_arr.append(end_volts)

        # Median Current
        med_curr = dict[key]['Current (A)'].median()
        med_curr_arr.append(med_curr)

        # Min dV/dt
        min_dvdt = dict[key]['dV/dt (V/s)'].min()
        min_dvdt_arr.append(min_dvdt)

        # Total Current Rise
        curr_rise = currdrop_sum(dict[key])
        curr_rise_arr.append(curr_rise)

        # SOC Drop
        discharge = dis_cap_drop(dict[key])
        soc_cc = (discharge / 3) * 100
        soc_cc_arr.append(soc_cc)

    info_data_2['End Voltage(V)'] = end_volts_arr
    info_data_2['Median Current(A)'] = med_curr_arr
    info_data_2['Min dV/dt'] = min_dvdt_arr
    info_data_2['Total Current Rise'] = curr_rise_arr
    info_data_2['SOC_drop (%)'] = soc_cc_arr
    info_data_2['Relative_SOC_drop'] = (((info_data_2['SOC_drop (%)'] - relative_soc) / relative_soc) + 1) * 100

    return info_data_2

# %%
def features_ext_test(dict_test):
    end_volts_arr = []
    med_curr_arr = []
    min_dvdt_arr = []
    curr_rise_arr = []
    soc_cc_arr = []

    for key in dict_test.keys():
        # End Voltage
        end_volts = dict_test[key]['Voltage (V)'].iloc[-1]
        end_volts_arr.append(end_volts)
        
        # Median Current
        med_curr = dict_test[key]['Current (A)'].median()
        med_curr_arr.append(med_curr)
        
        # Min dV/dt
        min_dvdt = dict_test[key]['dV/dt (V/s)'].min()
        min_dvdt_arr.append(min_dvdt)
        
        # Total Current Rise
        curr_rise = currdrop_sum(dict_test[key])
        curr_rise_arr.append(curr_rise)
        
        # Relative_SOC_drop
        discharge = dis_cap_drop(dict_test[key])
        soc_cc = (discharge / 3) * 100
        soc_cc_arr.append(soc_cc)
    
    info_data_test['End Voltage(V)'] = end_volts_arr
    info_data_test['Median Current(A)'] = med_curr_arr
    info_data_test['Min dV/dt'] = min_dvdt_arr
    info_data_test['Total Current Rise'] = curr_rise_arr
    info_data_test['SOC_drop (%)'] = soc_cc_arr
    info_data_test['Relative_SOC_drop'] = (((info_data_test['SOC_drop (%)'] - relative_soc) / relative_soc) + 1) * 100
    
    return info_data_test

# %%
iteration = 10

mape_t1 = np.zeros((iteration, 20))
mape_t2 = np.zeros((iteration, 20))
mape_t3 = np.zeros((iteration, 20))
mape_t4 = np.zeros((iteration, 20))
mape_t5 = np.zeros((iteration, 20))
mape_t6 = np.zeros((iteration, 20))
mape_test_t1 = np.zeros((iteration, 20))
mape_test_t2 = np.zeros((iteration, 20))
mape_test_t3 = np.zeros((iteration, 20))
mape_test_t4 = np.zeros((iteration, 20))
mape_test_t5 = np.zeros((iteration, 20))
mape_test_t6 = np.zeros((iteration, 20))
original_stdout = sys.stdout

cut_dict = {}
data_list = []
for key in dict.keys():
    datafr = cut_time(dict[key], 300, 800)
    data_list.append(datafr)
cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

cut_data = features_ext(cut_dict)

number_of_tests = np.shape(cut_data.values)[0]
y = np.zeros(number_of_tests)

for i in range(number_of_tests):
    y[i] = cut_data['Relative_SOC_drop'][i]

cut_dict = {}
data_list = []
for key in dict_test.keys():
    datafr = cut_time(dict_test[key], 300, 800)
    data_list.append(datafr)
cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

cut_data = features_ext_test(cut_dict)

number_of_tests = np.shape(cut_data.values)[0]
y_test2 = np.zeros(number_of_tests)

for i in range(number_of_tests):
    y_test2[i] = cut_data['Relative_SOC_drop'][i]

for ii in tqdm(range(iteration)):
    mape1 = []
    mape2 = []
    mape3 = []
    mape4 = []
    mape5 = []
    mape6 = []
    mape_test_1 = []
    mape_test_2 = []
    mape_test_3 = []
    mape_test_4 = []
    mape_test_5 = []
    mape_test_6 = []

    for kk in range(325, 801, 25):
        sys.stdout = open(os.devnull, 'w')

        cut_dict = {}
        data_list = []
        for key in dict.keys():
            datafr = cut_time(dict[key], 300, kk)
            data_list.append(datafr)
        cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

        cut_data = features_ext(cut_dict)

        number_of_tests = np.shape(cut_data.values)[0]
        X = np.zeros((number_of_tests, 4))

        for i in range(number_of_tests):
            X[i, 0] = cut_data['End Voltage(V)'][i]
            X[i, 1] = cut_data['Median Current(A)'][i]
            X[i, 2] = cut_data['Min dV/dt'][i]
            X[i, 3] = cut_data['Total Current Rise'][i]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        cut_dict = {}
        data_list = []
        for key in dict_test.keys():
            datafr = cut_time(dict_test[key], 300, kk)
            data_list.append(datafr)
        cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

        cut_data = features_ext_test(cut_dict)

        number_of_tests = np.shape(cut_data.values)[0]
        X_test2 = np.zeros((number_of_tests, 4))

        for i in range(number_of_tests):
            X_test2[i, 0] = cut_data['End Voltage(V)'][i]
            X_test2[i, 1] = cut_data['Median Current(A)'][i]
            X_test2[i, 2] = cut_data['Min dV/dt'][i]
            X_test2[i, 3] = cut_data['Total Current Rise'][i]
        
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mape1.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_1.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = DecisionTreeRegressor()
        skf = KFold(n_splits=5, random_state=10, shuffle=True)
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape2.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_2.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = ExtraTreeRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape3.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_3.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = RandomForestRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape4.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_4.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = KNeighborsRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape5.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_5.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)
        model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape6.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_6.append(mean_absolute_percentage_error(y_test2, y_pred2))

        sys.stdout = original_stdout
        original_stdout.close()

    mape_t1[ii] = mape1
    mape_t2[ii] = mape2
    mape_t3[ii] = mape3
    mape_t4[ii] = mape4
    mape_t5[ii] = mape5
    mape_t6[ii] = mape6
    mape_test_t1[ii] = mape_test_1
    mape_test_t2[ii] = mape_test_2
    mape_test_t3[ii] = mape_test_3
    mape_test_t4[ii] = mape_test_4
    mape_test_t5[ii] = mape_test_5
    mape_test_t6[ii] = mape_test_6

# Saving for replotting
np.save( MISC_DIR / 'plot1.npy', [mape_t1, mape_t2, mape_t3, mape_t4, mape_t5, mape_t6, mape_test_t1, mape_test_t2, mape_test_t3, mape_test_t4, mape_test_t5, mape_test_t6])
# Out:
# 100%|██████████| 10/10 [27:56<00:00, 167.67s/it]

# %%
plt.figure(figsize=(10, 6))

curve_plot(mape_t1, 'Linear model', (230/255, 25/255, 75/255))
curve_plot(mape_t2, 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(mape_t3, 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(mape_t4, 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(mape_t5, 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(mape_t6, 'Gaussian process model', (0/255, 130/255, 200/255))

plt.xlabel("Number of seconds of data used for featurization (sec)")
plt.ylabel("Mean absolute percent error of relative SOC drop (%)")
plt.legend()
plt.show()

# %% [markdown]
# **We also add new 12 test data in addition to the original 96 test results and check the performance of the models using them.**

# %%
plt.figure(figsize=(10, 6))

curve_plot(mape_test_t1, 'Linear model', (230/255, 25/255, 75/255))
curve_plot(mape_test_t2, 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(mape_test_t3, 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(mape_test_t4, 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(mape_test_t5, 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(mape_test_t6, 'Gaussian process model', (0/255, 130/255, 200/255))

plt.xlabel("Number of seconds of data used for featurization (sec)")
plt.ylabel("Mean absolute percent error of relative SOC drop (%)")
plt.legend()
plt.show()
