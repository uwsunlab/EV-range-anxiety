# %% [markdown]
# ## Predicting State of Charge (SOC) using featurization method

# %%
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
import warnings
from sklearn.exceptions import ConvergenceWarning
import sys, os
from tqdm import tqdm
from scipy import stats
import multiprocessing as mp
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic, ExpSineSquared

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %run Test_data_create.ipynb
# Out:
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'def_Up' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Down'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'def_Flat'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Up'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Down'
# /var/folders/bv/5yzv5x3d5sb44fl8wn3sdr540000gn/T/ipykernel_71405/3217211228.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['Classification'].iloc[mt]= 'asser_Flat'

# %%
info_data_2
# Out:
#     Mini Trip   Time(s)  Time below 10 perc V  Time b/w 10-20 perc V  \
# 0           1  838.5301               58.5452                93.2589
# 1           2  830.7749               73.7439                80.4931
# 2           3  835.6806               73.6227                90.5066
# 3           4  832.0687               48.9809                57.2786
# 4           5  822.5755               66.1437                68.7245
# ..        ...       ...                   ...                    ...
# 91         92  881.6387              100.0075                85.9462
# 92         93  896.1405               13.4896                50.1867
# 93         94  895.2206               20.0035                65.4538
# 94         95  896.1301               37.7802                76.2951
# 95         96  897.0171               63.8285                80.4272
#
#     Time b/w 20-30 perc V  Time b/w 30-40 perc V  Time b/w 40-50 perc V  \
# 0                118.4125               109.4456                60.1064
# 1                 80.1424                79.0237               104.9993
# 2                 89.4256                83.8234                94.5700
# 3                 92.3736                74.5756               110.5599
# 4                 90.0178                85.2328                97.3233
# ..                    ...                    ...                    ...
# 91                90.0051                83.6781                77.9656
# 92               106.5362               122.4614               103.1086
# 93                82.0709               120.1072               112.3646
# 94               103.4657               105.7574                88.6432
# 95                96.8856               120.4487                99.1012
#
#     Time b/w 50-60 perc V  Time b/w 60-70 perc V  Time b/w 70-80 perc V  ...  \
# 0                 80.5666                93.4686                65.8015  ...
# 1                 90.0154                68.0520                71.7833  ...
# 2                 68.1439                86.2034                85.5223  ...
# 3                 89.9098                99.5994                98.0787  ...
# 4                 56.8206                88.4279                83.9642  ...
# ..                    ...                    ...                    ...  ...
# 91                88.6784                87.1975                88.1432  ...
# 92                92.0530               111.5962               103.4858  ...
# 93               122.8152                80.5031                99.5567  ...
# 94                99.8588                97.7829                85.2635  ...
# 95                86.9497                95.9286                46.8342  ...
#
#     Mean Current(A)  Peak dV/dt  Min dV/dt  Avg dV/dt  Total Voltage Rise  \
# 0         -0.236519    0.123397  -0.032355   0.003618            0.333304
# 1         -0.300617    0.177656  -0.027619   0.010053            0.193704
# 2         -0.261694    0.123892  -0.033125   0.005763            0.225856
# 3         -0.282639    0.193953  -0.048424   0.007802            0.348449
# 4         -0.216769    0.112828  -0.027416   0.001599            0.295778
# ..              ...         ...        ...        ...                 ...
# 91        -0.261357    0.045183  -0.009785   0.000633            0.108643
# 92        -0.303141    0.117966  -0.127090   0.000635            0.423559
# 93        -0.296967    0.112069  -0.182226  -0.001153            0.516790
# 94        -0.277675    0.115814  -0.039049   0.000697            0.452645
# 95        -0.281072    0.171685  -0.119220   0.001894            0.578535
#
#     Total Current Rise  Number of brakes  Total brake time  SOC_drop (%)  \
# 0             0.745126                 9          277.8562     -1.714187
# 1             0.221160                15           99.2912     -2.191082
# 2             0.331414                14          161.7811     -1.941562
# 3             0.631515                16          274.9793     -2.052681
# 4             0.684379                 9          275.6830     -1.626870
# ..                 ...               ...               ...           ...
# 91            1.204570                15          140.5351     -2.146716
# 92            0.941241                18          291.3320     -2.351125
# 93            1.184964                16          269.7200     -2.222724
# 94            1.133279                14          253.8221     -2.212659
# 95            1.427169                20          213.8156     -2.315655
#
#     Relative_SOC_drop
# 0           62.387902
# 1           79.744542
# 2           70.663244
# 3           74.707409
# 4           59.210020
# ..                ...
# 91          78.129824
# 92          85.569316
# 93          80.896135
# 94          80.529824
# 95          84.278369
#
# [96 rows x 39 columns]

# %% [markdown]
# ### 1. Selecting features
# We take the following four features as the input of our machine learning model: end voltage, median current, min dV/dt, and total current rise since they are more correlated to the output feature, which is SOC drop.

# %% [markdown]
# Correlation heatmap:

# %%
# Select only the relevant columns
selected_columns = ['End Voltage(V)', 'Median Current(A)', 'Min dV/dt', 'Total Current Rise', 'Relative_SOC_drop']
selected_data = info_data_2[selected_columns]

# Calculate the correlation matrix
corr_mat = selected_data.corr()

# Extract the correlation with 'Relative_SOC_drop' and drop the target row itself
target_corr = corr_mat[['Relative_SOC_drop']].drop(['Relative_SOC_drop'], axis=0)

# Plotting the heatmap
sns.heatmap(target_corr, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, vmin=-1, vmax=1)
plt.title('Correlation Heatmap with Relative_SOC_drop')
plt.show()

# %% [markdown]
# Selecting features:

# %%
# Input (different features) is defined as X, output (SOC_drop) is defined as y
number_of_tests = np.shape(info_data_2.values)[0]
X = np.zeros((number_of_tests,4))
y = np.zeros(number_of_tests)

for i in range(number_of_tests):
    X[i,0] = info_data_2['End Voltage(V)'][i]
    X[i,1] = info_data_2['Median Current(A)'][i]
    X[i,2] = info_data_2['Min dV/dt'][i]
    X[i,3] = info_data_2['Total Current Rise'][i]
    y[i] = info_data_2['Relative_SOC_drop'][i]

print(f'{len(X)} points loaded in total, each with {len(X[0])} features')
print('Example point:', X[0])
# Out:
# 96 points loaded in total, each with 4 features
# Example point: [ 3.88329    -0.221077   -0.03235537  0.74512588]

# %%
number_of_new_tests = np.shape(info_data_test.values)[0]
X_new_test = np.zeros((number_of_new_tests,4))
y_new_test = np.zeros(number_of_new_tests)

for i in range(number_of_new_tests):
    X_new_test[i,0] = info_data_test['End Voltage(V)'][i]
    X_new_test[i,1] = info_data_test['Median Current(A)'][i]
    X_new_test[i,2] = info_data_test['Min dV/dt'][i]
    X_new_test[i,3] = info_data_test['Total Current Rise'][i]
    y_new_test[i] = info_data_test['Relative_SOC_drop'][i]

# %% [markdown]
# ### 2. Divide the data into the train set and the test set
# We want 80% of the data to be the train set and the rest (20%) to be the test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### 3. Build and test different models

# %% [markdown]
# #### (3.1) Linear model

# %%
model = LinearRegression()

# Now we use scikit learn to train a simple linear model
model.fit(X_train, y_train)

# And make predictions on the test set
y_pred = model.predict(X_test)
# Let's examine the mean absolute error and mean absolute percentage error
mae1 = mean_absolute_error(y_test, y_pred)
mape1 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae1)
print('MAPE:', mape1)
# Out:
# MAE: 2.5597085934706687
# MAPE: 0.03414209219277477

# %% [markdown]
# Visualize the predicting result:

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %% [markdown]
# #### (3.2) Decision tree model

# %%
model = DecisionTreeRegressor(random_state=0)

#Now we use scikit learn to train a decision tree model using k-fold cross validation and grid search to find the best model with hyperparameters tunned

#First we define that we use 5 folds to conduct cross validation
skf = KFold(n_splits=5, random_state=10, shuffle=True)
#Then use grid search to tune for the best hyper parameters
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
#Fit the model
model_search.fit(X_train, y_train)
#Get the best model
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
#Let's examine the mean absolute error and mean absolute percentage error
mae2 = mean_absolute_error(y_test, y_pred)
mape2 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae2)
print('MAPE:', mape2)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.539, test=-2.533) neg_mean_squared_error: (train=-10.387, test=-10.827) r2: (train=0.725, test=0.174) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.201, test=-4.641) neg_mean_squared_error: (train=-8.301, test=-31.945) r2: (train=0.716, test=0.276) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.335, test=-4.207) neg_mean_squared_error: (train=-9.636, test=-23.059) r2: (train=0.695, test=0.377) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.483, test=-3.044) neg_mean_squared_error: (train=-9.284, test=-22.199) r2: (train=0.698, test=0.420) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.228, test=-2.862) neg_mean_squared_error: (train=-7.068, test=-15.850) r2: (train=0.791, test=0.437) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.474, test=-1.986) neg_mean_squared_error: (train=-3.433, test=-6.988) r2: (train=0.909, test=0.467) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.244, test=-3.634) neg_mean_squared_error: (train=-3.253, test=-22.204) r2: (train=0.889, test=0.497) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.439, test=-2.911) neg_mean_squared_error: (train=-3.987, test=-14.555) r2: (train=0.874, test=0.607) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.559, test=-2.879) neg_mean_squared_error: (train=-4.216, test=-22.838) r2: (train=0.863, test=0.403) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.591, test=-2.562) neg_mean_squared_error: (train=-4.130, test=-9.082) r2: (train=0.878, test=0.677) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.802, test=-1.470) neg_mean_squared_error: (train=-1.359, test=-4.107) r2: (train=0.964, test=0.687) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.805, test=-4.438) neg_mean_squared_error: (train=-1.586, test=-45.850) r2: (train=0.946, test=-0.039) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.801, test=-2.561) neg_mean_squared_error: (train=-1.454, test=-14.736) r2: (train=0.954, test=0.602) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.875, test=-3.028) neg_mean_squared_error: (train=-1.445, test=-25.729) r2: (train=0.953, test=0.328) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.972, test=-2.078) neg_mean_squared_error: (train=-1.586, test=-6.997) r2: (train=0.953, test=0.751) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.298, test=-1.396) neg_mean_squared_error: (train=-0.241, test=-3.807) r2: (train=0.994, test=0.710) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.449, test=-4.389) neg_mean_squared_error: (train=-0.663, test=-46.587) r2: (train=0.977, test=-0.055) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.445, test=-2.183) neg_mean_squared_error: (train=-0.441, test=-10.074) r2: (train=0.986, test=0.728) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.394, test=-2.478) neg_mean_squared_error: (train=-0.423, test=-21.243) r2: (train=0.986, test=0.445) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.408, test=-1.804) neg_mean_squared_error: (train=-0.374, test=-5.995) r2: (train=0.989, test=0.787) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.137, test=-1.211) neg_mean_squared_error: (train=-0.086, test=-2.585) r2: (train=0.998, test=0.803) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.172, test=-2.340) neg_mean_squared_error: (train=-0.125, test=-12.787) r2: (train=0.996, test=0.710) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.191, test=-2.448) neg_mean_squared_error: (train=-0.116, test=-15.290) r2: (train=0.996, test=0.587) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.116, test=-2.390) neg_mean_squared_error: (train=-0.068, test=-18.773) r2: (train=0.998, test=0.509) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.212, test=-1.700) neg_mean_squared_error: (train=-0.130, test=-5.022) r2: (train=0.996, test=0.822) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.038, test=-1.187) neg_mean_squared_error: (train=-0.010, test=-2.559) r2: (train=1.000, test=0.805) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.061, test=-2.435) neg_mean_squared_error: (train=-0.023, test=-12.900) r2: (train=0.999, test=0.708) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.046, test=-3.467) neg_mean_squared_error: (train=-0.008, test=-29.321) r2: (train=1.000, test=0.207) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.048, test=-2.250) neg_mean_squared_error: (train=-0.014, test=-18.429) r2: (train=1.000, test=0.518) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.078, test=-1.310) neg_mean_squared_error: (train=-0.046, test=-3.224) r2: (train=0.999, test=0.885) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.016, test=-1.342) neg_mean_squared_error: (train=-0.002, test=-4.007) r2: (train=1.000, test=0.694) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.017, test=-2.487) neg_mean_squared_error: (train=-0.004, test=-13.469) r2: (train=1.000, test=0.695) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.004, test=-3.077) neg_mean_squared_error: (train=-0.000, test=-22.125) r2: (train=1.000, test=0.402) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.012, test=-2.607) neg_mean_squared_error: (train=-0.002, test=-19.751) r2: (train=1.000, test=0.484) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.025, test=-1.324) neg_mean_squared_error: (train=-0.012, test=-3.242) r2: (train=1.000, test=0.885) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.585) neg_mean_squared_error: (train=-0.000, test=-5.538) r2: (train=1.000, test=0.578) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.006, test=-4.162) neg_mean_squared_error: (train=-0.001, test=-44.761) r2: (train=1.000, test=-0.014) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.001, test=-3.189) neg_mean_squared_error: (train=-0.000, test=-24.516) r2: (train=1.000, test=0.337) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-2.642) neg_mean_squared_error: (train=-0.000, test=-19.918) r2: (train=1.000, test=0.479) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.280) neg_mean_squared_error: (train=-0.000, test=-3.141) r2: (train=1.000, test=0.888) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.539, test=-2.533) neg_mean_squared_error: (train=-10.387, test=-10.827) r2: (train=0.725, test=0.174) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.201, test=-4.641) neg_mean_squared_error: (train=-8.301, test=-31.945) r2: (train=0.716, test=0.276) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.335, test=-4.207) neg_mean_squared_error: (train=-9.636, test=-23.059) r2: (train=0.695, test=0.377) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.483, test=-3.044) neg_mean_squared_error: (train=-9.284, test=-22.199) r2: (train=0.698, test=0.420) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.228, test=-2.862) neg_mean_squared_error: (train=-7.068, test=-15.850) r2: (train=0.791, test=0.437) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.474, test=-1.986) neg_mean_squared_error: (train=-3.433, test=-6.988) r2: (train=0.909, test=0.467) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.244, test=-5.115) neg_mean_squared_error: (train=-3.253, test=-52.724) r2: (train=0.889, test=-0.194) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.439, test=-2.911) neg_mean_squared_error: (train=-3.987, test=-14.555) r2: (train=0.874, test=0.607) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.559, test=-2.879) neg_mean_squared_error: (train=-4.216, test=-22.838) r2: (train=0.863, test=0.403) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.591, test=-2.562) neg_mean_squared_error: (train=-4.130, test=-9.082) r2: (train=0.878, test=0.677) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.802, test=-1.470) neg_mean_squared_error: (train=-1.359, test=-4.107) r2: (train=0.964, test=0.687) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.805, test=-4.438) neg_mean_squared_error: (train=-1.586, test=-45.850) r2: (train=0.946, test=-0.039) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.801, test=-2.374) neg_mean_squared_error: (train=-1.454, test=-14.120) r2: (train=0.954, test=0.618) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.875, test=-3.028) neg_mean_squared_error: (train=-1.445, test=-25.729) r2: (train=0.953, test=0.328) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.972, test=-2.078) neg_mean_squared_error: (train=-1.586, test=-6.997) r2: (train=0.953, test=0.751) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.298, test=-1.158) neg_mean_squared_error: (train=-0.241, test=-2.350) r2: (train=0.994, test=0.821) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.449, test=-4.059) neg_mean_squared_error: (train=-0.663, test=-44.886) r2: (train=0.977, test=-0.017) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.445, test=-2.183) neg_mean_squared_error: (train=-0.441, test=-10.074) r2: (train=0.986, test=0.728) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.394, test=-2.478) neg_mean_squared_error: (train=-0.423, test=-21.243) r2: (train=0.986, test=0.445) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.408, test=-1.804) neg_mean_squared_error: (train=-0.374, test=-5.995) r2: (train=0.989, test=0.787) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.137, test=-1.412) neg_mean_squared_error: (train=-0.086, test=-3.700) r2: (train=0.998, test=0.718) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.172, test=-4.138) neg_mean_squared_error: (train=-0.125, test=-45.570) r2: (train=0.996, test=-0.032) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.191, test=-2.448) neg_mean_squared_error: (train=-0.116, test=-15.290) r2: (train=0.996, test=0.587) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.116, test=-2.380) neg_mean_squared_error: (train=-0.068, test=-18.669) r2: (train=0.998, test=0.512) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.212, test=-1.700) neg_mean_squared_error: (train=-0.130, test=-5.022) r2: (train=0.996, test=0.822) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.038, test=-1.387) neg_mean_squared_error: (train=-0.010, test=-3.671) r2: (train=1.000, test=0.720) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.061, test=-4.564) neg_mean_squared_error: (train=-0.023, test=-47.384) r2: (train=0.999, test=-0.073) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.046, test=-3.467) neg_mean_squared_error: (train=-0.008, test=-29.321) r2: (train=1.000, test=0.207) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.048, test=-2.238) neg_mean_squared_error: (train=-0.014, test=-18.305) r2: (train=1.000, test=0.522) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.078, test=-1.310) neg_mean_squared_error: (train=-0.046, test=-3.224) r2: (train=0.999, test=0.885) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.016, test=-1.064) neg_mean_squared_error: (train=-0.002, test=-2.130) r2: (train=1.000, test=0.838) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.017, test=-4.543) neg_mean_squared_error: (train=-0.004, test=-47.310) r2: (train=1.000, test=-0.072) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.004, test=-3.107) neg_mean_squared_error: (train=-0.000, test=-22.294) r2: (train=1.000, test=0.397) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.012, test=-2.350) neg_mean_squared_error: (train=-0.002, test=-18.825) r2: (train=1.000, test=0.508) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.025, test=-1.349) neg_mean_squared_error: (train=-0.012, test=-3.273) r2: (train=1.000, test=0.884) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.595) neg_mean_squared_error: (train=-0.000, test=-5.548) r2: (train=1.000, test=0.577) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.006, test=-4.522) neg_mean_squared_error: (train=-0.001, test=-46.490) r2: (train=1.000, test=-0.053) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.001, test=-3.189) neg_mean_squared_error: (train=-0.000, test=-24.516) r2: (train=1.000, test=0.337) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-2.385) neg_mean_squared_error: (train=-0.000, test=-18.992) r2: (train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.280) neg_mean_squared_error: (train=-0.000, test=-3.141) r2: (train=1.000, test=0.888) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.405, test=-2.624) neg_mean_squared_error: (train=-11.103, test=-12.322) r2: (train=0.707, test=0.060) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.179, test=-4.587) neg_mean_squared_error: (train=-8.672, test=-30.577) r2: (train=0.703, test=0.307) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.199, test=-4.357) neg_mean_squared_error: (train=-10.897, test=-27.985) r2: (train=0.655, test=0.244) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.366, test=-3.152) neg_mean_squared_error: (train=-10.213, test=-24.074) r2: (train=0.668, test=0.371) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.168, test=-3.516) neg_mean_squared_error: (train=-8.314, test=-24.647) r2: (train=0.754, test=0.124) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.573, test=-1.638) neg_mean_squared_error: (train=-4.185, test=-4.572) r2: (train=0.889, test=0.651) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.166, test=-3.745) neg_mean_squared_error: (train=-3.506, test=-23.867) r2: (train=0.880, test=0.459) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.428, test=-3.507) neg_mean_squared_error: (train=-3.733, test=-19.777) r2: (train=0.882, test=0.465) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.407, test=-3.099) neg_mean_squared_error: (train=-5.334, test=-24.535) r2: (train=0.827, test=0.359) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.367, test=-2.329) neg_mean_squared_error: (train=-3.366, test=-7.781) r2: (train=0.900, test=0.724) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.857, test=-1.088) neg_mean_squared_error: (train=-1.810, test=-2.322) r2: (train=0.952, test=0.823) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.763, test=-5.015) neg_mean_squared_error: (train=-2.189, test=-50.369) r2: (train=0.925, test=-0.141) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.773, test=-2.462) neg_mean_squared_error: (train=-1.353, test=-14.507) r2: (train=0.957, test=0.608) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.753, test=-2.491) neg_mean_squared_error: (train=-1.836, test=-20.200) r2: (train=0.940, test=0.472) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-0.655, test=-1.929) neg_mean_squared_error: (train=-0.958, test=-6.392) r2: (train=0.972, test=0.773) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.342, test=-1.199) neg_mean_squared_error: (train=-0.321, test=-3.000) r2: (train=0.992, test=0.771) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.350, test=-3.529) neg_mean_squared_error: (train=-0.665, test=-23.491) r2: (train=0.977, test=0.468) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.327, test=-1.896) neg_mean_squared_error: (train=-0.300, test=-8.097) r2: (train=0.991, test=0.781) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.453, test=-2.710) neg_mean_squared_error: (train=-1.139, test=-21.523) r2: (train=0.963, test=0.438) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.391, test=-1.954) neg_mean_squared_error: (train=-0.624, test=-7.206) r2: (train=0.982, test=0.744) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.127, test=-1.595) neg_mean_squared_error: (train=-0.098, test=-5.654) r2: (train=0.997, test=0.569) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.134, test=-3.307) neg_mean_squared_error: (train=-0.080, test=-22.024) r2: (train=0.997, test=0.501) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.102, test=-2.417) neg_mean_squared_error: (train=-0.035, test=-17.179) r2: (train=0.999, test=0.536) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.165, test=-2.456) neg_mean_squared_error: (train=-0.245, test=-21.100) r2: (train=0.992, test=0.449) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.142, test=-1.469) neg_mean_squared_error: (train=-0.085, test=-5.062) r2: (train=0.997, test=0.820) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.038, test=-1.238) neg_mean_squared_error: (train=-0.010, test=-3.236) r2: (train=1.000, test=0.753) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.064, test=-3.150) neg_mean_squared_error: (train=-0.021, test=-20.984) r2: (train=0.999, test=0.525) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.025, test=-2.174) neg_mean_squared_error: (train=-0.003, test=-13.430) r2: (train=1.000, test=0.637) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.029, test=-2.758) neg_mean_squared_error: (train=-0.005, test=-22.911) r2: (train=1.000, test=0.401) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.043, test=-1.424) neg_mean_squared_error: (train=-0.012, test=-3.475) r2: (train=1.000, test=0.877) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.013, test=-1.296) neg_mean_squared_error: (train=-0.002, test=-3.404) r2: (train=1.000, test=0.740) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.014, test=-4.921) neg_mean_squared_error: (train=-0.002, test=-53.406) r2: (train=1.000, test=-0.210) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.004, test=-1.698) neg_mean_squared_error: (train=-0.000, test=-8.160) r2: (train=1.000, test=0.779) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.007, test=-2.789) neg_mean_squared_error: (train=-0.001, test=-22.940) r2: (train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.019, test=-1.149) neg_mean_squared_error: (train=-0.003, test=-2.903) r2: (train=1.000, test=0.897) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.003, test=-1.429) neg_mean_squared_error: (train=-0.000, test=-5.114) r2: (train=1.000, test=0.610) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.003, test=-4.868) neg_mean_squared_error: (train=-0.000, test=-53.024) r2: (train=1.000, test=-0.201) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.000, test=-1.995) neg_mean_squared_error: (train=-0.000, test=-12.428) r2: (train=1.000, test=0.664) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.001, test=-2.585) neg_mean_squared_error: (train=-0.000, test=-21.277) r2: (train=1.000, test=0.444) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.004, test=-1.232) neg_mean_squared_error: (train=-0.000, test=-3.008) r2: (train=1.000, test=0.893) total time=   0.0s
# MAE: 1.2617854586791988
# MAPE: 0.016151761033983116

# %% [markdown]
# Visualize the predicting result:

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %% [markdown]
# #### (3.3) Extremely randomized tree model
# Extra-trees differ from classic decision trees in the way they are built. When looking for the best split to separate the samples of a node into two groups, random splits are drawn for each of the *max_features* randomly selected features and the best split among those is chosen. When *max_features* is set 1, this amounts to building a totally random decision tree.

# %%
model = ExtraTreeRegressor(random_state=0)

#Now we use scikit learn to train an extremely randomized tree model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
#Let's examine the mean absolute error and mean absolute percentage error
mae3 = mean_absolute_error(y_test, y_pred)
mape3 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae3)
print('MAPE:', mape3)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.606, test=-2.418) neg_mean_squared_error: (train=-21.396, test=-10.349) r2: (train=0.434, test=0.211) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.169, test=-4.463) neg_mean_squared_error: (train=-18.258, test=-33.607) r2: (train=0.375, test=0.239) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.124, test=-4.005) neg_mean_squared_error: (train=-16.961, test=-26.650) r2: (train=0.463, test=0.280) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.112, test=-4.012) neg_mean_squared_error: (train=-16.821, test=-27.470) r2: (train=0.454, test=0.282) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-3.455, test=-2.961) neg_mean_squared_error: (train=-20.760, test=-11.864) r2: (train=0.385, test=0.578) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.741, test=-3.119) neg_mean_squared_error: (train=-21.281, test=-17.567) r2: (train=0.438, test=-0.339) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.442, test=-5.283) neg_mean_squared_error: (train=-24.314, test=-45.938) r2: (train=0.168, test=-0.041) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.452, test=-4.341) neg_mean_squared_error: (train=-25.183, test=-34.002) r2: (train=0.203, test=0.081) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.193, test=-5.868) neg_mean_squared_error: (train=-22.191, test=-49.513) r2: (train=0.279, test=-0.294) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-3.741, test=-3.931) neg_mean_squared_error: (train=-27.561, test=-25.661) r2: (train=0.184, test=0.088) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.289, test=-1.919) neg_mean_squared_error: (train=-9.646, test=-5.838) r2: (train=0.745, test=0.555) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.127, test=-3.826) neg_mean_squared_error: (train=-8.733, test=-21.823) r2: (train=0.701, test=0.506) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.194, test=-3.387) neg_mean_squared_error: (train=-9.322, test=-15.908) r2: (train=0.705, test=0.570) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-2.226, test=-3.251) neg_mean_squared_error: (train=-8.793, test=-18.946) r2: (train=0.714, test=0.505) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-3.164, test=-5.147) neg_mean_squared_error: (train=-17.660, test=-34.223) r2: (train=0.477, test=-0.216) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.887, test=-2.835) neg_mean_squared_error: (train=-7.562, test=-11.926) r2: (train=0.800, test=0.091) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.942, test=-3.008) neg_mean_squared_error: (train=-2.466, test=-12.493) r2: (train=0.916, test=0.717) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.866, test=-2.600) neg_mean_squared_error: (train=-8.308, test=-18.326) r2: (train=0.737, test=0.505) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.479, test=-3.796) neg_mean_squared_error: (train=-3.884, test=-32.424) r2: (train=0.874, test=0.153) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-1.594, test=-2.031) neg_mean_squared_error: (train=-5.056, test=-5.904) r2: (train=0.850, test=0.790) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-1.201, test=-2.821) neg_mean_squared_error: (train=-2.961, test=-12.274) r2: (train=0.922, test=0.064) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.604, test=-2.234) neg_mean_squared_error: (train=-1.610, test=-8.062) r2: (train=0.945, test=0.817) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-1.142, test=-2.706) neg_mean_squared_error: (train=-4.217, test=-14.242) r2: (train=0.867, test=0.615) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.887, test=-4.151) neg_mean_squared_error: (train=-3.221, test=-33.332) r2: (train=0.895, test=0.129) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.951, test=-2.252) neg_mean_squared_error: (train=-2.341, test=-9.251) r2: (train=0.931, test=0.671) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.431, test=-2.179) neg_mean_squared_error: (train=-0.715, test=-8.963) r2: (train=0.981, test=0.317) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.272, test=-2.456) neg_mean_squared_error: (train=-0.304, test=-10.520) r2: (train=0.990, test=0.762) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.748, test=-3.375) neg_mean_squared_error: (train=-1.952, test=-19.710) r2: (train=0.938, test=0.467) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.794, test=-3.517) neg_mean_squared_error: (train=-2.305, test=-21.690) r2: (train=0.925, test=0.433) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.518, test=-1.629) neg_mean_squared_error: (train=-1.049, test=-5.862) r2: (train=0.969, test=0.792) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.227, test=-2.201) neg_mean_squared_error: (train=-0.343, test=-10.000) r2: (train=0.991, test=0.238) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.103, test=-1.938) neg_mean_squared_error: (train=-0.099, test=-7.198) r2: (train=0.997, test=0.837) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.375, test=-4.136) neg_mean_squared_error: (train=-0.585, test=-30.297) r2: (train=0.981, test=0.181) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.375, test=-2.329) neg_mean_squared_error: (train=-0.649, test=-11.195) r2: (train=0.979, test=0.707) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.181, test=-2.054) neg_mean_squared_error: (train=-0.148, test=-6.731) r2: (train=0.996, test=0.761) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.078, test=-2.755) neg_mean_squared_error: (train=-0.056, test=-13.742) r2: (train=0.999, test=-0.048) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.009, test=-2.184) neg_mean_squared_error: (train=-0.002, test=-8.356) r2: (train=1.000, test=0.811) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.422, test=-3.096) neg_mean_squared_error: (train=-0.971, test=-18.264) r2: (train=0.969, test=0.506) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.109, test=-2.049) neg_mean_squared_error: (train=-0.069, test=-10.253) r2: (train=0.998, test=0.732) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.090, test=-1.931) neg_mean_squared_error: (train=-0.067, test=-7.158) r2: (train=0.998, test=0.746) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.606, test=-2.418) neg_mean_squared_error: (train=-21.396, test=-10.349) r2: (train=0.434, test=0.211) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.169, test=-4.463) neg_mean_squared_error: (train=-18.258, test=-33.607) r2: (train=0.375, test=0.239) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.124, test=-4.005) neg_mean_squared_error: (train=-16.961, test=-26.650) r2: (train=0.463, test=0.280) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.112, test=-4.012) neg_mean_squared_error: (train=-16.821, test=-27.470) r2: (train=0.454, test=0.282) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-3.455, test=-2.961) neg_mean_squared_error: (train=-20.760, test=-11.864) r2: (train=0.385, test=0.578) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.741, test=-3.119) neg_mean_squared_error: (train=-21.281, test=-17.567) r2: (train=0.438, test=-0.339) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.442, test=-5.283) neg_mean_squared_error: (train=-24.314, test=-45.938) r2: (train=0.168, test=-0.041) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.452, test=-4.341) neg_mean_squared_error: (train=-25.183, test=-34.002) r2: (train=0.203, test=0.081) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.193, test=-5.868) neg_mean_squared_error: (train=-22.191, test=-49.513) r2: (train=0.279, test=-0.294) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-3.741, test=-3.931) neg_mean_squared_error: (train=-27.561, test=-25.661) r2: (train=0.184, test=0.088) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.289, test=-1.919) neg_mean_squared_error: (train=-9.646, test=-5.838) r2: (train=0.745, test=0.555) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.127, test=-4.282) neg_mean_squared_error: (train=-8.733, test=-27.832) r2: (train=0.701, test=0.370) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.194, test=-3.387) neg_mean_squared_error: (train=-9.322, test=-15.908) r2: (train=0.705, test=0.570) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-2.226, test=-3.337) neg_mean_squared_error: (train=-8.793, test=-19.844) r2: (train=0.714, test=0.481) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-3.164, test=-5.147) neg_mean_squared_error: (train=-17.660, test=-34.223) r2: (train=0.477, test=-0.216) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.887, test=-2.835) neg_mean_squared_error: (train=-7.562, test=-11.926) r2: (train=0.800, test=0.091) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.942, test=-3.008) neg_mean_squared_error: (train=-2.466, test=-12.493) r2: (train=0.916, test=0.717) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.866, test=-2.600) neg_mean_squared_error: (train=-8.308, test=-18.326) r2: (train=0.737, test=0.505) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.479, test=-3.883) neg_mean_squared_error: (train=-3.884, test=-33.322) r2: (train=0.874, test=0.129) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-1.594, test=-2.031) neg_mean_squared_error: (train=-5.056, test=-5.904) r2: (train=0.850, test=0.790) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-1.201, test=-2.821) neg_mean_squared_error: (train=-2.961, test=-12.274) r2: (train=0.922, test=0.064) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.604, test=-2.030) neg_mean_squared_error: (train=-1.610, test=-7.105) r2: (train=0.945, test=0.839) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-1.142, test=-2.706) neg_mean_squared_error: (train=-4.217, test=-14.242) r2: (train=0.867, test=0.615) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.887, test=-4.238) neg_mean_squared_error: (train=-3.221, test=-34.230) r2: (train=0.895, test=0.105) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.951, test=-2.103) neg_mean_squared_error: (train=-2.341, test=-8.931) r2: (train=0.931, test=0.683) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.431, test=-2.171) neg_mean_squared_error: (train=-0.715, test=-8.927) r2: (train=0.981, test=0.319) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.272, test=-3.398) neg_mean_squared_error: (train=-0.304, test=-22.912) r2: (train=0.990, test=0.481) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.748, test=-2.726) neg_mean_squared_error: (train=-1.952, test=-16.585) r2: (train=0.938, test=0.552) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.794, test=-3.603) neg_mean_squared_error: (train=-2.305, test=-22.588) r2: (train=0.925, test=0.410) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.518, test=-1.629) neg_mean_squared_error: (train=-1.049, test=-5.862) r2: (train=0.969, test=0.792) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.227, test=-2.197) neg_mean_squared_error: (train=-0.343, test=-9.979) r2: (train=0.991, test=0.239) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.103, test=-1.938) neg_mean_squared_error: (train=-0.099, test=-7.198) r2: (train=0.997, test=0.837) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.375, test=-3.640) neg_mean_squared_error: (train=-0.585, test=-28.426) r2: (train=0.981, test=0.232) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.375, test=-2.415) neg_mean_squared_error: (train=-0.649, test=-12.093) r2: (train=0.979, test=0.684) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.181, test=-2.054) neg_mean_squared_error: (train=-0.148, test=-6.731) r2: (train=0.996, test=0.761) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.078, test=-2.760) neg_mean_squared_error: (train=-0.056, test=-13.748) r2: (train=0.999, test=-0.048) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.009, test=-2.184) neg_mean_squared_error: (train=-0.002, test=-8.356) r2: (train=1.000, test=0.811) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.422, test=-2.599) neg_mean_squared_error: (train=-0.971, test=-16.393) r2: (train=0.969, test=0.557) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.109, test=-2.135) neg_mean_squared_error: (train=-0.069, test=-11.151) r2: (train=0.998, test=0.709) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.090, test=-1.993) neg_mean_squared_error: (train=-0.067, test=-7.782) r2: (train=0.998, test=0.724) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.444, test=-2.056) neg_mean_squared_error: (train=-23.917, test=-6.262) r2: (train=0.368, test=0.522) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.044, test=-4.573) neg_mean_squared_error: (train=-19.012, test=-38.570) r2: (train=0.349, test=0.126) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.905, test=-4.254) neg_mean_squared_error: (train=-19.000, test=-30.116) r2: (train=0.399, test=0.186) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.952, test=-4.178) neg_mean_squared_error: (train=-18.154, test=-32.600) r2: (train=0.410, test=0.148) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-3.376, test=-2.420) neg_mean_squared_error: (train=-21.719, test=-11.183) r2: (train=0.357, test=0.603) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.732, test=-2.936) neg_mean_squared_error: (train=-30.275, test=-13.392) r2: (train=0.200, test=-0.021) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.321, test=-5.264) neg_mean_squared_error: (train=-23.451, test=-42.483) r2: (train=0.197, test=0.038) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.397, test=-4.194) neg_mean_squared_error: (train=-25.493, test=-33.583) r2: (train=0.193, test=0.092) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.097, test=-5.598) neg_mean_squared_error: (train=-22.576, test=-47.457) r2: (train=0.267, test=-0.240) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-3.543, test=-4.134) neg_mean_squared_error: (train=-28.636, test=-25.731) r2: (train=0.152, test=0.086) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-3.364, test=-3.339) neg_mean_squared_error: (train=-19.700, test=-16.695) r2: (train=0.479, test=-0.273) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.949, test=-4.190) neg_mean_squared_error: (train=-10.065, test=-26.237) r2: (train=0.655, test=0.406) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-2.027, test=-4.377) neg_mean_squared_error: (train=-10.895, test=-33.252) r2: (train=0.655, test=0.101) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-2.090, test=-3.976) neg_mean_squared_error: (train=-11.782, test=-31.610) r2: (train=0.617, test=0.174) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-3.031, test=-4.174) neg_mean_squared_error: (train=-18.906, test=-28.276) r2: (train=0.440, test=-0.005) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.758, test=-1.830) neg_mean_squared_error: (train=-9.185, test=-5.026) r2: (train=0.757, test=0.617) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.143, test=-5.132) neg_mean_squared_error: (train=-8.861, test=-44.013) r2: (train=0.697, test=0.003) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.840, test=-2.525) neg_mean_squared_error: (train=-8.644, test=-17.923) r2: (train=0.727, test=0.516) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-2.363, test=-2.988) neg_mean_squared_error: (train=-14.515, test=-26.289) r2: (train=0.528, test=0.313) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-1.458, test=-2.283) neg_mean_squared_error: (train=-5.580, test=-6.646) r2: (train=0.835, test=0.764) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.689, test=-1.501) neg_mean_squared_error: (train=-1.539, test=-4.125) r2: (train=0.959, test=0.685) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.362, test=-4.006) neg_mean_squared_error: (train=-0.856, test=-33.910) r2: (train=0.971, test=0.232) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.506, test=-3.868) neg_mean_squared_error: (train=-7.579, test=-24.297) r2: (train=0.760, test=0.343) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.025, test=-4.193) neg_mean_squared_error: (train=-4.342, test=-33.387) r2: (train=0.859, test=0.127) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-1.370, test=-2.005) neg_mean_squared_error: (train=-5.615, test=-11.421) r2: (train=0.834, test=0.594) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.681, test=-1.358) neg_mean_squared_error: (train=-1.752, test=-2.931) r2: (train=0.954, test=0.777) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.249, test=-4.352) neg_mean_squared_error: (train=-0.401, test=-36.930) r2: (train=0.986, test=0.163) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.952, test=-2.782) neg_mean_squared_error: (train=-3.858, test=-16.053) r2: (train=0.878, test=0.566) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.731, test=-3.522) neg_mean_squared_error: (train=-2.459, test=-22.506) r2: (train=0.920, test=0.412) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.485, test=-1.599) neg_mean_squared_error: (train=-1.156, test=-5.097) r2: (train=0.966, test=0.819) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.252, test=-1.260) neg_mean_squared_error: (train=-0.492, test=-3.533) r2: (train=0.987, test=0.731) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.106, test=-2.969) neg_mean_squared_error: (train=-0.100, test=-20.958) r2: (train=0.997, test=0.525) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.449, test=-4.453) neg_mean_squared_error: (train=-2.005, test=-31.990) r2: (train=0.937, test=0.135) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.327, test=-2.505) neg_mean_squared_error: (train=-0.808, test=-12.104) r2: (train=0.974, test=0.684) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.237, test=-1.783) neg_mean_squared_error: (train=-0.341, test=-5.332) r2: (train=0.990, test=0.811) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.145, test=-1.608) neg_mean_squared_error: (train=-0.402, test=-4.720) r2: (train=0.989, test=0.640) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.022, test=-2.926) neg_mean_squared_error: (train=-0.007, test=-21.511) r2: (train=1.000, test=0.513) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.272, test=-3.072) neg_mean_squared_error: (train=-0.744, test=-14.126) r2: (train=0.976, test=0.618) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.103, test=-2.040) neg_mean_squared_error: (train=-0.075, test=-10.282) r2: (train=0.998, test=0.731) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.093, test=-1.945) neg_mean_squared_error: (train=-0.094, test=-6.707) r2: (train=0.997, test=0.762) total time=   0.0s
# MAE: 2.0974660439057624
# MAPE: 0.02782786668567721

# %% [markdown]
# Visualize the predicting result:

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %% [markdown]
# #### (3.4) Random forest model
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.

# %%
model = RandomForestRegressor(random_state=0)

#Now we use scikit learn to train a random forest model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
#Let's examine the mean absolute error and mean absolute percentage error
mae4 = mean_absolute_error(y_test, y_pred)
mape4 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae4)
print('MAPE:', mape4)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.327, test=-2.411) neg_mean_squared_error: (train=-8.261, test=-8.358) r2: (train=0.782, test=0.363) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-1.760, test=-3.439) neg_mean_squared_error: (train=-5.716, test=-15.358) r2: (train=0.804, test=0.652) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.082, test=-3.740) neg_mean_squared_error: (train=-6.933, test=-18.733) r2: (train=0.781, test=0.494) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.149, test=-2.423) neg_mean_squared_error: (train=-7.115, test=-14.026) r2: (train=0.769, test=0.633) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2; neg_mean_absolute_error: (train=-2.279, test=-3.196) neg_mean_squared_error: (train=-7.182, test=-18.735) r2: (train=0.787, test=0.334) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.535, test=-1.909) neg_mean_squared_error: (train=-3.898, test=-6.136) r2: (train=0.897, test=0.532) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.184, test=-2.860) neg_mean_squared_error: (train=-2.705, test=-11.895) r2: (train=0.907, test=0.731) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.328, test=-3.200) neg_mean_squared_error: (train=-3.137, test=-14.717) r2: (train=0.901, test=0.602) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.444, test=-2.301) neg_mean_squared_error: (train=-3.438, test=-12.521) r2: (train=0.888, test=0.673) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3; neg_mean_absolute_error: (train=-1.499, test=-2.552) neg_mean_squared_error: (train=-3.461, test=-11.399) r2: (train=0.897, test=0.595) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.031, test=-1.705) neg_mean_squared_error: (train=-2.021, test=-5.725) r2: (train=0.947, test=0.563) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.882, test=-2.612) neg_mean_squared_error: (train=-1.512, test=-9.785) r2: (train=0.948, test=0.778) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-0.949, test=-2.718) neg_mean_squared_error: (train=-1.598, test=-11.388) r2: (train=0.949, test=0.692) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.044, test=-2.154) neg_mean_squared_error: (train=-1.927, test=-11.108) r2: (train=0.937, test=0.710) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4; neg_mean_absolute_error: (train=-1.052, test=-2.227) neg_mean_squared_error: (train=-1.776, test=-9.207) r2: (train=0.947, test=0.673) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.813, test=-1.669) neg_mean_squared_error: (train=-1.352, test=-5.535) r2: (train=0.964, test=0.578) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.706, test=-2.478) neg_mean_squared_error: (train=-1.006, test=-8.781) r2: (train=0.966, test=0.801) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.786, test=-2.556) neg_mean_squared_error: (train=-1.086, test=-9.962) r2: (train=0.966, test=0.731) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.846, test=-2.081) neg_mean_squared_error: (train=-1.423, test=-10.945) r2: (train=0.954, test=0.714) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5; neg_mean_absolute_error: (train=-0.828, test=-2.040) neg_mean_squared_error: (train=-1.242, test=-8.276) r2: (train=0.963, test=0.706) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.769, test=-1.655) neg_mean_squared_error: (train=-1.241, test=-5.323) r2: (train=0.967, test=0.594) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.642, test=-2.538) neg_mean_squared_error: (train=-0.888, test=-9.148) r2: (train=0.970, test=0.793) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.709, test=-2.549) neg_mean_squared_error: (train=-0.987, test=-10.256) r2: (train=0.969, test=0.723) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.791, test=-2.035) neg_mean_squared_error: (train=-1.347, test=-10.377) r2: (train=0.956, test=0.729) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6; neg_mean_absolute_error: (train=-0.785, test=-2.036) neg_mean_squared_error: (train=-1.212, test=-8.421) r2: (train=0.964, test=0.701) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.724, test=-1.640) neg_mean_squared_error: (train=-1.182, test=-5.554) r2: (train=0.969, test=0.576) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.633, test=-2.548) neg_mean_squared_error: (train=-0.861, test=-9.572) r2: (train=0.971, test=0.783) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.716, test=-2.471) neg_mean_squared_error: (train=-0.988, test=-9.463) r2: (train=0.969, test=0.744) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.792, test=-2.024) neg_mean_squared_error: (train=-1.323, test=-10.375) r2: (train=0.957, test=0.729) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=7; neg_mean_absolute_error: (train=-0.735, test=-2.003) neg_mean_squared_error: (train=-1.124, test=-8.151) r2: (train=0.967, test=0.710) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.726, test=-1.644) neg_mean_squared_error: (train=-1.169, test=-5.700) r2: (train=0.969, test=0.565) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.636, test=-2.605) neg_mean_squared_error: (train=-0.889, test=-9.939) r2: (train=0.970, test=0.775) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.715, test=-2.453) neg_mean_squared_error: (train=-0.978, test=-9.931) r2: (train=0.969, test=0.732) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.763, test=-2.007) neg_mean_squared_error: (train=-1.249, test=-9.903) r2: (train=0.959, test=0.741) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=8; neg_mean_absolute_error: (train=-0.727, test=-1.992) neg_mean_squared_error: (train=-1.101, test=-8.157) r2: (train=0.967, test=0.710) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.722, test=-1.659) neg_mean_squared_error: (train=-1.200, test=-5.801) r2: (train=0.968, test=0.558) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.625, test=-2.483) neg_mean_squared_error: (train=-0.873, test=-8.724) r2: (train=0.970, test=0.802) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.702, test=-2.485) neg_mean_squared_error: (train=-0.966, test=-10.347) r2: (train=0.969, test=0.720) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.759, test=-2.026) neg_mean_squared_error: (train=-1.276, test=-10.281) r2: (train=0.959, test=0.731) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9; neg_mean_absolute_error: (train=-0.729, test=-1.977) neg_mean_squared_error: (train=-1.115, test=-7.918) r2: (train=0.967, test=0.719) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.328, test=-2.413) neg_mean_squared_error: (train=-8.274, test=-8.384) r2: (train=0.781, test=0.361) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-1.760, test=-3.439) neg_mean_squared_error: (train=-5.716, test=-15.325) r2: (train=0.804, test=0.653) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.083, test=-3.740) neg_mean_squared_error: (train=-6.940, test=-18.733) r2: (train=0.780, test=0.494) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.152, test=-2.423) neg_mean_squared_error: (train=-7.125, test=-14.026) r2: (train=0.769, test=0.633) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2; neg_mean_absolute_error: (train=-2.284, test=-3.202) neg_mean_squared_error: (train=-7.197, test=-18.611) r2: (train=0.787, test=0.339) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.543, test=-1.909) neg_mean_squared_error: (train=-3.930, test=-6.165) r2: (train=0.896, test=0.530) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.189, test=-2.878) neg_mean_squared_error: (train=-2.689, test=-12.112) r2: (train=0.908, test=0.726) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.330, test=-3.183) neg_mean_squared_error: (train=-3.134, test=-14.423) r2: (train=0.901, test=0.610) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.444, test=-2.311) neg_mean_squared_error: (train=-3.441, test=-12.574) r2: (train=0.888, test=0.671) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3; neg_mean_absolute_error: (train=-1.507, test=-2.566) neg_mean_squared_error: (train=-3.490, test=-11.360) r2: (train=0.897, test=0.596) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.041, test=-1.719) neg_mean_squared_error: (train=-2.061, test=-5.711) r2: (train=0.946, test=0.565) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.875, test=-2.631) neg_mean_squared_error: (train=-1.491, test=-10.109) r2: (train=0.949, test=0.771) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-0.954, test=-2.688) neg_mean_squared_error: (train=-1.604, test=-10.898) r2: (train=0.949, test=0.705) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.036, test=-2.168) neg_mean_squared_error: (train=-1.914, test=-11.054) r2: (train=0.938, test=0.711) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4; neg_mean_absolute_error: (train=-1.060, test=-2.238) neg_mean_squared_error: (train=-1.802, test=-9.225) r2: (train=0.947, test=0.672) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.816, test=-1.681) neg_mean_squared_error: (train=-1.389, test=-5.619) r2: (train=0.963, test=0.572) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.691, test=-2.481) neg_mean_squared_error: (train=-0.973, test=-9.074) r2: (train=0.967, test=0.794) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.793, test=-2.531) neg_mean_squared_error: (train=-1.107, test=-9.434) r2: (train=0.965, test=0.745) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.830, test=-2.085) neg_mean_squared_error: (train=-1.347, test=-10.412) r2: (train=0.956, test=0.728) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=5; neg_mean_absolute_error: (train=-0.841, test=-2.076) neg_mean_squared_error: (train=-1.281, test=-8.375) r2: (train=0.962, test=0.702) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.771, test=-1.663) neg_mean_squared_error: (train=-1.273, test=-5.340) r2: (train=0.966, test=0.593) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.639, test=-2.555) neg_mean_squared_error: (train=-0.883, test=-9.521) r2: (train=0.970, test=0.784) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.719, test=-2.527) neg_mean_squared_error: (train=-1.001, test=-9.920) r2: (train=0.968, test=0.732) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.774, test=-2.046) neg_mean_squared_error: (train=-1.298, test=-10.177) r2: (train=0.958, test=0.734) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=6; neg_mean_absolute_error: (train=-0.788, test=-2.049) neg_mean_squared_error: (train=-1.217, test=-8.354) r2: (train=0.964, test=0.703) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.735, test=-1.668) neg_mean_squared_error: (train=-1.237, test=-5.585) r2: (train=0.967, test=0.574) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.627, test=-2.530) neg_mean_squared_error: (train=-0.852, test=-9.519) r2: (train=0.971, test=0.784) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.729, test=-2.451) neg_mean_squared_error: (train=-1.014, test=-9.311) r2: (train=0.968, test=0.748) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.781, test=-2.051) neg_mean_squared_error: (train=-1.299, test=-10.251) r2: (train=0.958, test=0.732) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=7; neg_mean_absolute_error: (train=-0.735, test=-2.015) neg_mean_squared_error: (train=-1.124, test=-8.055) r2: (train=0.967, test=0.714) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.737, test=-1.653) neg_mean_squared_error: (train=-1.206, test=-5.608) r2: (train=0.968, test=0.572) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.633, test=-2.623) neg_mean_squared_error: (train=-0.873, test=-10.302) r2: (train=0.970, test=0.767) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.724, test=-2.439) neg_mean_squared_error: (train=-0.984, test=-9.818) r2: (train=0.969, test=0.735) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.760, test=-2.034) neg_mean_squared_error: (train=-1.268, test=-9.964) r2: (train=0.959, test=0.740) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8; neg_mean_absolute_error: (train=-0.729, test=-2.025) neg_mean_squared_error: (train=-1.113, test=-8.150) r2: (train=0.967, test=0.710) total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.731, test=-1.663) neg_mean_squared_error: (train=-1.232, test=-5.790) r2: (train=0.967, test=0.559) total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.628, test=-2.526) neg_mean_squared_error: (train=-0.873, test=-9.303) r2: (train=0.970, test=0.789) total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.723, test=-2.475) neg_mean_squared_error: (train=-0.995, test=-10.313) r2: (train=0.969, test=0.721) total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.758, test=-2.039) neg_mean_squared_error: (train=-1.276, test=-10.169) r2: (train=0.959, test=0.734) total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9; neg_mean_absolute_error: (train=-0.727, test=-2.019) neg_mean_squared_error: (train=-1.122, test=-7.913) r2: (train=0.967, test=0.719) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.271, test=-2.171) neg_mean_squared_error: (train=-8.320, test=-6.820) r2: (train=0.780, test=0.480) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-1.807, test=-3.220) neg_mean_squared_error: (train=-6.804, test=-14.388) r2: (train=0.767, test=0.674) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.031, test=-3.724) neg_mean_squared_error: (train=-7.888, test=-20.215) r2: (train=0.750, test=0.454) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.125, test=-2.575) neg_mean_squared_error: (train=-7.941, test=-16.875) r2: (train=0.742, test=0.559) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2; neg_mean_absolute_error: (train=-2.184, test=-2.950) neg_mean_squared_error: (train=-6.884, test=-15.446) r2: (train=0.796, test=0.451) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.579, test=-1.849) neg_mean_squared_error: (train=-4.352, test=-6.288) r2: (train=0.885, test=0.521) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.300, test=-2.840) neg_mean_squared_error: (train=-3.520, test=-11.491) r2: (train=0.880, test=0.740) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.451, test=-3.251) neg_mean_squared_error: (train=-4.156, test=-16.211) r2: (train=0.869, test=0.562) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.460, test=-2.385) neg_mean_squared_error: (train=-3.955, test=-13.039) r2: (train=0.872, test=0.659) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3; neg_mean_absolute_error: (train=-1.518, test=-2.456) neg_mean_squared_error: (train=-3.503, test=-10.297) r2: (train=0.896, test=0.634) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.161, test=-1.712) neg_mean_squared_error: (train=-2.677, test=-5.786) r2: (train=0.929, test=0.559) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.003, test=-2.622) neg_mean_squared_error: (train=-1.976, test=-10.091) r2: (train=0.932, test=0.771) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.078, test=-2.863) neg_mean_squared_error: (train=-2.372, test=-13.015) r2: (train=0.925, test=0.648) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.138, test=-2.212) neg_mean_squared_error: (train=-2.349, test=-11.539) r2: (train=0.924, test=0.698) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4; neg_mean_absolute_error: (train=-1.114, test=-2.246) neg_mean_squared_error: (train=-1.942, test=-9.171) r2: (train=0.942, test=0.674) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.909, test=-1.731) neg_mean_squared_error: (train=-1.590, test=-5.932) r2: (train=0.958, test=0.548) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.800, test=-2.425) neg_mean_squared_error: (train=-1.222, test=-8.579) r2: (train=0.958, test=0.806) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.881, test=-2.713) neg_mean_squared_error: (train=-1.391, test=-11.852) r2: (train=0.956, test=0.680) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.922, test=-2.116) neg_mean_squared_error: (train=-1.685, test=-11.203) r2: (train=0.945, test=0.707) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5; neg_mean_absolute_error: (train=-0.937, test=-2.134) neg_mean_squared_error: (train=-1.473, test=-8.188) r2: (train=0.956, test=0.709) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.778, test=-1.668) neg_mean_squared_error: (train=-1.239, test=-5.862) r2: (train=0.967, test=0.553) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.708, test=-2.349) neg_mean_squared_error: (train=-1.006, test=-8.360) r2: (train=0.966, test=0.811) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.802, test=-2.643) neg_mean_squared_error: (train=-1.169, test=-12.282) r2: (train=0.963, test=0.668) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.847, test=-2.067) neg_mean_squared_error: (train=-1.502, test=-11.015) r2: (train=0.951, test=0.712) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6; neg_mean_absolute_error: (train=-0.874, test=-2.155) neg_mean_squared_error: (train=-1.289, test=-8.574) r2: (train=0.962, test=0.695) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.725, test=-1.576) neg_mean_squared_error: (train=-1.125, test=-5.026) r2: (train=0.970, test=0.617) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.687, test=-2.245) neg_mean_squared_error: (train=-0.939, test=-7.225) r2: (train=0.968, test=0.836) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.738, test=-2.520) neg_mean_squared_error: (train=-0.999, test=-11.150) r2: (train=0.968, test=0.699) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.801, test=-2.048) neg_mean_squared_error: (train=-1.399, test=-10.809) r2: (train=0.955, test=0.718) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7; neg_mean_absolute_error: (train=-0.841, test=-2.154) neg_mean_squared_error: (train=-1.258, test=-8.466) r2: (train=0.963, test=0.699) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.721, test=-1.619) neg_mean_squared_error: (train=-1.140, test=-5.402) r2: (train=0.970, test=0.588) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.669, test=-2.354) neg_mean_squared_error: (train=-0.929, test=-7.976) r2: (train=0.968, test=0.819) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.732, test=-2.448) neg_mean_squared_error: (train=-0.953, test=-10.429) r2: (train=0.970, test=0.718) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.812, test=-2.061) neg_mean_squared_error: (train=-1.423, test=-11.283) r2: (train=0.954, test=0.705) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8; neg_mean_absolute_error: (train=-0.802, test=-2.131) neg_mean_squared_error: (train=-1.152, test=-8.194) r2: (train=0.966, test=0.709) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.727, test=-1.661) neg_mean_squared_error: (train=-1.173, test=-5.709) r2: (train=0.969, test=0.565) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.650, test=-2.260) neg_mean_squared_error: (train=-0.896, test=-7.096) r2: (train=0.969, test=0.839) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.727, test=-2.451) neg_mean_squared_error: (train=-0.961, test=-10.811) r2: (train=0.970, test=0.708) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.788, test=-2.026) neg_mean_squared_error: (train=-1.387, test=-10.865) r2: (train=0.955, test=0.716) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9; neg_mean_absolute_error: (train=-0.789, test=-2.093) neg_mean_squared_error: (train=-1.132, test=-7.985) r2: (train=0.966, test=0.716) total time=   0.0s
# MAE: 1.7072833454725405
# MAPE: 0.022437252042857674

# %% [markdown]
# Visualize the predicting result:

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %%
y_pred_train = model.predict(X_train)
plt.figure()
plt.scatter(y_pred_train, y_train)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

mae4 = mean_absolute_error(y_train, y_pred_train)
mape4 = mean_absolute_percentage_error(y_train, y_pred_train)

print('MAE:', mae4)
print('MAPE:', mape4)
# Out:
# MAE: 0.7079408353044216
# MAPE: 0.009698772268265507

# %%
y_pred_new_test = model.predict(X_new_test)
plt.figure()
plt.scatter(y_pred_new_test, y_new_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

mae4 = mean_absolute_error(y_new_test, y_pred_new_test)
mape4 = mean_absolute_percentage_error(y_new_test, y_pred_new_test)

print('MAE:', mae4)
print('MAPE:', mape4)
# Out:
# MAE: 3.7941695779948597
# MAPE: 0.05115059724756526

# %%
np.savez('predictions_and_labels_for_battery_data.npz', 
         y_pred_train_3 = y_pred_train, 
         y_train_3 = y_train, 
         y_pred_val_3 = y_pred, 
         y_val_3 = y_test, 
         y_pred_test_3 = y_pred_new_test,
         y_test_3 = y_new_test)

# %% [markdown]
# #### (3.5) k-nearest neighbors model
# The target is predicted by local interpolation of the targets associated of the nearest neighbors in the training set.

# %%
model = KNeighborsRegressor()

#Now we use scikit learn to train a k-nearest neighbors model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
#Let's examine the mean absolute error and mean absolute percentage error
mae5 = mean_absolute_error(y_test, y_pred)
mape5 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae5)
print('MAPE:', mape5)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-3.523) neg_mean_squared_error: (train=-7.192, test=-19.416) r2: (train=0.810, test=-0.480) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.316, test=-3.879) neg_mean_squared_error: (train=-5.115, test=-27.497) r2: (train=0.825, test=0.377) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.791, test=-4.092) neg_mean_squared_error: (train=-8.816, test=-28.703) r2: (train=0.721, test=0.224) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-4.180) neg_mean_squared_error: (train=-8.488, test=-28.640) r2: (train=0.724, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.858, test=-3.073) neg_mean_squared_error: (train=-8.604, test=-14.654) r2: (train=0.745, test=0.479) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.291) neg_mean_squared_error: (train=-0.000, test=-17.922) r2: (train=1.000, test=-0.367) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.616) neg_mean_squared_error: (train=-0.000, test=-24.769) r2: (train=1.000, test=0.439) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.434) neg_mean_squared_error: (train=-0.000, test=-21.875) r2: (train=1.000, test=0.409) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.720) neg_mean_squared_error: (train=-0.000, test=-21.176) r2: (train=1.000, test=0.447) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.919) neg_mean_squared_error: (train=-0.000, test=-14.408) r2: (train=1.000, test=0.488) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.541, test=-3.248) neg_mean_squared_error: (train=-10.952, test=-19.027) r2: (train=0.711, test=-0.451) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.279, test=-3.592) neg_mean_squared_error: (train=-8.616, test=-21.499) r2: (train=0.705, test=0.513) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.520, test=-4.046) neg_mean_squared_error: (train=-13.596, test=-28.635) r2: (train=0.570, test=0.226) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.419, test=-3.952) neg_mean_squared_error: (train=-11.373, test=-28.639) r2: (train=0.631, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.639, test=-2.632) neg_mean_squared_error: (train=-10.750, test=-10.979) r2: (train=0.682, test=0.610) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.019) neg_mean_squared_error: (train=-0.000, test=-17.313) r2: (train=1.000, test=-0.320) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.393) neg_mean_squared_error: (train=-0.000, test=-20.282) r2: (train=1.000, test=0.541) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-25.025) r2: (train=1.000, test=0.324) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-22.727) r2: (train=1.000, test=0.406) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.285) neg_mean_squared_error: (train=-0.000, test=-9.384) r2: (train=1.000, test=0.667) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.858, test=-3.437) neg_mean_squared_error: (train=-12.528, test=-22.198) r2: (train=0.669, test=-0.693) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.706, test=-3.859) neg_mean_squared_error: (train=-13.139, test=-20.069) r2: (train=0.550, test=0.545) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.581, test=-4.311) neg_mean_squared_error: (train=-13.460, test=-30.275) r2: (train=0.574, test=0.182) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.847, test=-3.827) neg_mean_squared_error: (train=-15.601, test=-26.396) r2: (train=0.493, test=0.310) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.903, test=-3.129) neg_mean_squared_error: (train=-14.474, test=-14.036) r2: (train=0.571, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.023) neg_mean_squared_error: (train=-0.000, test=-18.853) r2: (train=1.000, test=-0.438) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.458) neg_mean_squared_error: (train=-0.000, test=-16.750) r2: (train=1.000, test=0.621) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.030) neg_mean_squared_error: (train=-0.000, test=-27.224) r2: (train=1.000, test=0.264) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.622) neg_mean_squared_error: (train=-0.000, test=-23.053) r2: (train=1.000, test=0.398) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.557) neg_mean_squared_error: (train=-0.000, test=-10.116) r2: (train=1.000, test=0.641) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.141, test=-3.541) neg_mean_squared_error: (train=-15.718, test=-23.346) r2: (train=0.585, test=-0.780) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.874, test=-3.813) neg_mean_squared_error: (train=-14.650, test=-22.932) r2: (train=0.498, test=0.481) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.799, test=-4.540) neg_mean_squared_error: (train=-14.177, test=-32.405) r2: (train=0.551, test=0.124) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.703, test=-3.687) neg_mean_squared_error: (train=-13.821, test=-23.463) r2: (train=0.551, test=0.387) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.194, test=-3.594) neg_mean_squared_error: (train=-16.672, test=-16.195) r2: (train=0.506, test=0.425) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.982) neg_mean_squared_error: (train=-0.000, test=-18.941) r2: (train=1.000, test=-0.444) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.501) neg_mean_squared_error: (train=-0.000, test=-19.738) r2: (train=1.000, test=0.553) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.111) neg_mean_squared_error: (train=-0.000, test=-28.126) r2: (train=1.000, test=0.240) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.435) neg_mean_squared_error: (train=-0.000, test=-21.189) r2: (train=1.000, test=0.446) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.779) neg_mean_squared_error: (train=-0.000, test=-11.332) r2: (train=1.000, test=0.597) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.148, test=-3.267) neg_mean_squared_error: (train=-15.704, test=-20.101) r2: (train=0.585, test=-0.533) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.927, test=-3.824) neg_mean_squared_error: (train=-14.553, test=-24.656) r2: (train=0.502, test=0.441) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.992, test=-4.089) neg_mean_squared_error: (train=-15.371, test=-26.621) r2: (train=0.514, test=0.280) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.673, test=-3.676) neg_mean_squared_error: (train=-12.857, test=-24.292) r2: (train=0.582, test=0.365) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.262, test=-3.301) neg_mean_squared_error: (train=-16.675, test=-14.053) r2: (train=0.506, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.804) neg_mean_squared_error: (train=-0.000, test=-16.598) r2: (train=1.000, test=-0.266) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.455) neg_mean_squared_error: (train=-0.000, test=-20.768) r2: (train=1.000, test=0.530) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.834) neg_mean_squared_error: (train=-0.000, test=-24.436) r2: (train=1.000, test=0.339) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.438) neg_mean_squared_error: (train=-0.000, test=-21.787) r2: (train=1.000, test=0.431) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.710) neg_mean_squared_error: (train=-0.000, test=-11.432) r2: (train=1.000, test=0.594) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.308, test=-3.596) neg_mean_squared_error: (train=-17.094, test=-20.583) r2: (train=0.548, test=-0.569) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.978, test=-3.932) neg_mean_squared_error: (train=-14.762, test=-26.627) r2: (train=0.495, test=0.397) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.048, test=-3.784) neg_mean_squared_error: (train=-16.050, test=-22.170) r2: (train=0.492, test=0.401) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.764, test=-3.668) neg_mean_squared_error: (train=-13.739, test=-23.609) r2: (train=0.554, test=0.383) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.173, test=-3.181) neg_mean_squared_error: (train=-15.923, test=-13.272) r2: (train=0.528, test=0.528) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.928) neg_mean_squared_error: (train=-0.000, test=-16.104) r2: (train=1.000, test=-0.228) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.544) neg_mean_squared_error: (train=-0.000, test=-22.410) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.651) neg_mean_squared_error: (train=-0.000, test=-21.817) r2: (train=1.000, test=0.410) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.427) neg_mean_squared_error: (train=-0.000, test=-21.078) r2: (train=1.000, test=0.449) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.682) neg_mean_squared_error: (train=-0.000, test=-11.113) r2: (train=1.000, test=0.605) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.390, test=-3.718) neg_mean_squared_error: (train=-18.209, test=-20.917) r2: (train=0.519, test=-0.595) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.220, test=-4.003) neg_mean_squared_error: (train=-16.669, test=-27.993) r2: (train=0.429, test=0.366) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.102, test=-3.603) neg_mean_squared_error: (train=-16.097, test=-22.064) r2: (train=0.491, test=0.404) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.016, test=-3.428) neg_mean_squared_error: (train=-15.562, test=-22.095) r2: (train=0.494, test=0.423) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.316, test=-3.345) neg_mean_squared_error: (train=-17.722, test=-14.867) r2: (train=0.475, test=0.472) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.965) neg_mean_squared_error: (train=-0.000, test=-15.566) r2: (train=1.000, test=-0.187) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.491) neg_mean_squared_error: (train=-0.000, test=-22.684) r2: (train=1.000, test=0.486) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.536) neg_mean_squared_error: (train=-0.000, test=-21.290) r2: (train=1.000, test=0.424) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.271) neg_mean_squared_error: (train=-0.000, test=-19.744) r2: (train=1.000, test=0.484) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.749) neg_mean_squared_error: (train=-0.000, test=-11.615) r2: (train=1.000, test=0.587) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.365, test=-3.563) neg_mean_squared_error: (train=-18.857, test=-19.320) r2: (train=0.502, test=-0.473) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.200, test=-4.364) neg_mean_squared_error: (train=-17.299, test=-34.211) r2: (train=0.408, test=0.225) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.174, test=-3.523) neg_mean_squared_error: (train=-17.049, test=-23.514) r2: (train=0.461, test=0.364) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.082, test=-3.454) neg_mean_squared_error: (train=-16.459, test=-22.190) r2: (train=0.465, test=0.420) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.361, test=-3.338) neg_mean_squared_error: (train=-18.504, test=-15.034) r2: (train=0.452, test=0.466) total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.929) neg_mean_squared_error: (train=-0.000, test=-14.931) r2: (train=1.000, test=-0.138) total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-26.442) r2: (train=1.000, test=0.401) total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.441) neg_mean_squared_error: (train=-0.000, test=-21.753) r2: (train=1.000, test=0.412) total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.279) neg_mean_squared_error: (train=-0.000, test=-19.509) r2: (train=1.000, test=0.490) total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.751) neg_mean_squared_error: (train=-0.000, test=-11.576) r2: (train=1.000, test=0.589) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-3.523) neg_mean_squared_error: (train=-7.192, test=-19.416) r2: (train=0.810, test=-0.480) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.316, test=-3.879) neg_mean_squared_error: (train=-5.115, test=-27.497) r2: (train=0.825, test=0.377) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.791, test=-4.092) neg_mean_squared_error: (train=-8.816, test=-28.703) r2: (train=0.721, test=0.224) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-4.180) neg_mean_squared_error: (train=-8.488, test=-28.640) r2: (train=0.724, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.858, test=-3.073) neg_mean_squared_error: (train=-8.604, test=-14.654) r2: (train=0.745, test=0.479) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.291) neg_mean_squared_error: (train=-0.000, test=-17.922) r2: (train=1.000, test=-0.367) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.616) neg_mean_squared_error: (train=-0.000, test=-24.769) r2: (train=1.000, test=0.439) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.434) neg_mean_squared_error: (train=-0.000, test=-21.875) r2: (train=1.000, test=0.409) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.720) neg_mean_squared_error: (train=-0.000, test=-21.176) r2: (train=1.000, test=0.447) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.919) neg_mean_squared_error: (train=-0.000, test=-14.408) r2: (train=1.000, test=0.488) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.541, test=-3.248) neg_mean_squared_error: (train=-10.952, test=-19.027) r2: (train=0.711, test=-0.451) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.279, test=-3.592) neg_mean_squared_error: (train=-8.616, test=-21.499) r2: (train=0.705, test=0.513) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.520, test=-4.046) neg_mean_squared_error: (train=-13.596, test=-28.635) r2: (train=0.570, test=0.226) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.419, test=-3.952) neg_mean_squared_error: (train=-11.373, test=-28.639) r2: (train=0.631, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.639, test=-2.632) neg_mean_squared_error: (train=-10.750, test=-10.979) r2: (train=0.682, test=0.610) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.019) neg_mean_squared_error: (train=-0.000, test=-17.313) r2: (train=1.000, test=-0.320) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.393) neg_mean_squared_error: (train=-0.000, test=-20.282) r2: (train=1.000, test=0.541) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-25.025) r2: (train=1.000, test=0.324) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-22.727) r2: (train=1.000, test=0.406) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.285) neg_mean_squared_error: (train=-0.000, test=-9.384) r2: (train=1.000, test=0.667) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.858, test=-3.437) neg_mean_squared_error: (train=-12.528, test=-22.198) r2: (train=0.669, test=-0.693) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.706, test=-3.859) neg_mean_squared_error: (train=-13.139, test=-20.069) r2: (train=0.550, test=0.545) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.581, test=-4.311) neg_mean_squared_error: (train=-13.460, test=-30.275) r2: (train=0.574, test=0.182) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.847, test=-3.827) neg_mean_squared_error: (train=-15.601, test=-26.396) r2: (train=0.493, test=0.310) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.903, test=-3.129) neg_mean_squared_error: (train=-14.474, test=-14.036) r2: (train=0.571, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.023) neg_mean_squared_error: (train=-0.000, test=-18.853) r2: (train=1.000, test=-0.438) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.458) neg_mean_squared_error: (train=-0.000, test=-16.750) r2: (train=1.000, test=0.621) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.030) neg_mean_squared_error: (train=-0.000, test=-27.224) r2: (train=1.000, test=0.264) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.622) neg_mean_squared_error: (train=-0.000, test=-23.053) r2: (train=1.000, test=0.398) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.557) neg_mean_squared_error: (train=-0.000, test=-10.116) r2: (train=1.000, test=0.641) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.141, test=-3.541) neg_mean_squared_error: (train=-15.718, test=-23.346) r2: (train=0.585, test=-0.780) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.874, test=-3.813) neg_mean_squared_error: (train=-14.650, test=-22.932) r2: (train=0.498, test=0.481) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.799, test=-4.540) neg_mean_squared_error: (train=-14.177, test=-32.405) r2: (train=0.551, test=0.124) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.703, test=-3.687) neg_mean_squared_error: (train=-13.821, test=-23.463) r2: (train=0.551, test=0.387) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.194, test=-3.594) neg_mean_squared_error: (train=-16.672, test=-16.195) r2: (train=0.506, test=0.425) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.982) neg_mean_squared_error: (train=-0.000, test=-18.941) r2: (train=1.000, test=-0.444) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.501) neg_mean_squared_error: (train=-0.000, test=-19.738) r2: (train=1.000, test=0.553) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.111) neg_mean_squared_error: (train=-0.000, test=-28.126) r2: (train=1.000, test=0.240) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.435) neg_mean_squared_error: (train=-0.000, test=-21.189) r2: (train=1.000, test=0.446) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.779) neg_mean_squared_error: (train=-0.000, test=-11.332) r2: (train=1.000, test=0.597) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.148, test=-3.267) neg_mean_squared_error: (train=-15.704, test=-20.101) r2: (train=0.585, test=-0.533) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.927, test=-3.824) neg_mean_squared_error: (train=-14.553, test=-24.656) r2: (train=0.502, test=0.441) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.992, test=-4.089) neg_mean_squared_error: (train=-15.371, test=-26.621) r2: (train=0.514, test=0.280) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.673, test=-3.676) neg_mean_squared_error: (train=-12.857, test=-24.292) r2: (train=0.582, test=0.365) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.262, test=-3.301) neg_mean_squared_error: (train=-16.675, test=-14.053) r2: (train=0.506, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.804) neg_mean_squared_error: (train=-0.000, test=-16.598) r2: (train=1.000, test=-0.266) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.455) neg_mean_squared_error: (train=-0.000, test=-20.768) r2: (train=1.000, test=0.530) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.834) neg_mean_squared_error: (train=-0.000, test=-24.436) r2: (train=1.000, test=0.339) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.438) neg_mean_squared_error: (train=-0.000, test=-21.787) r2: (train=1.000, test=0.431) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.710) neg_mean_squared_error: (train=-0.000, test=-11.432) r2: (train=1.000, test=0.594) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.308, test=-3.596) neg_mean_squared_error: (train=-17.094, test=-20.583) r2: (train=0.548, test=-0.569) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.978, test=-3.932) neg_mean_squared_error: (train=-14.762, test=-26.627) r2: (train=0.495, test=0.397) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.048, test=-3.784) neg_mean_squared_error: (train=-16.050, test=-22.170) r2: (train=0.492, test=0.401) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.764, test=-3.668) neg_mean_squared_error: (train=-13.739, test=-23.609) r2: (train=0.554, test=0.383) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.173, test=-3.181) neg_mean_squared_error: (train=-15.923, test=-13.272) r2: (train=0.528, test=0.528) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.928) neg_mean_squared_error: (train=-0.000, test=-16.104) r2: (train=1.000, test=-0.228) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.544) neg_mean_squared_error: (train=-0.000, test=-22.410) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.651) neg_mean_squared_error: (train=-0.000, test=-21.817) r2: (train=1.000, test=0.410) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.427) neg_mean_squared_error: (train=-0.000, test=-21.078) r2: (train=1.000, test=0.449) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.682) neg_mean_squared_error: (train=-0.000, test=-11.113) r2: (train=1.000, test=0.605) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.390, test=-3.718) neg_mean_squared_error: (train=-18.209, test=-20.917) r2: (train=0.519, test=-0.595) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.220, test=-4.003) neg_mean_squared_error: (train=-16.669, test=-27.993) r2: (train=0.429, test=0.366) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.102, test=-3.603) neg_mean_squared_error: (train=-16.097, test=-22.064) r2: (train=0.491, test=0.404) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.016, test=-3.428) neg_mean_squared_error: (train=-15.562, test=-22.095) r2: (train=0.494, test=0.423) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.316, test=-3.345) neg_mean_squared_error: (train=-17.722, test=-14.867) r2: (train=0.475, test=0.472) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.965) neg_mean_squared_error: (train=-0.000, test=-15.566) r2: (train=1.000, test=-0.187) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.491) neg_mean_squared_error: (train=-0.000, test=-22.684) r2: (train=1.000, test=0.486) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.536) neg_mean_squared_error: (train=-0.000, test=-21.290) r2: (train=1.000, test=0.424) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.271) neg_mean_squared_error: (train=-0.000, test=-19.744) r2: (train=1.000, test=0.484) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.749) neg_mean_squared_error: (train=-0.000, test=-11.615) r2: (train=1.000, test=0.587) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.365, test=-3.563) neg_mean_squared_error: (train=-18.857, test=-19.320) r2: (train=0.502, test=-0.473) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.200, test=-4.364) neg_mean_squared_error: (train=-17.299, test=-34.211) r2: (train=0.408, test=0.225) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.174, test=-3.523) neg_mean_squared_error: (train=-17.049, test=-23.514) r2: (train=0.461, test=0.364) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.082, test=-3.454) neg_mean_squared_error: (train=-16.459, test=-22.190) r2: (train=0.465, test=0.420) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.361, test=-3.338) neg_mean_squared_error: (train=-18.504, test=-15.034) r2: (train=0.452, test=0.466) total time=   0.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.929) neg_mean_squared_error: (train=-0.000, test=-14.931) r2: (train=1.000, test=-0.138) total time=   0.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-26.442) r2: (train=1.000, test=0.401) total time=   0.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.441) neg_mean_squared_error: (train=-0.000, test=-21.753) r2: (train=1.000, test=0.412) total time=   0.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.279) neg_mean_squared_error: (train=-0.000, test=-19.509) r2: (train=1.000, test=0.490) total time=   0.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.751) neg_mean_squared_error: (train=-0.000, test=-11.576) r2: (train=1.000, test=0.589) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-3.523) neg_mean_squared_error: (train=-7.192, test=-19.416) r2: (train=0.810, test=-0.480) total time=   0.1s
# [CV 2/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.316, test=-3.879) neg_mean_squared_error: (train=-5.115, test=-27.497) r2: (train=0.825, test=0.377) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.791, test=-4.092) neg_mean_squared_error: (train=-8.816, test=-28.703) r2: (train=0.721, test=0.224) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.654, test=-4.180) neg_mean_squared_error: (train=-8.488, test=-28.640) r2: (train=0.724, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, weights=uniform; neg_mean_absolute_error: (train=-1.858, test=-3.073) neg_mean_squared_error: (train=-8.604, test=-14.654) r2: (train=0.745, test=0.479) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.291) neg_mean_squared_error: (train=-0.000, test=-17.922) r2: (train=1.000, test=-0.367) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.616) neg_mean_squared_error: (train=-0.000, test=-24.769) r2: (train=1.000, test=0.439) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.434) neg_mean_squared_error: (train=-0.000, test=-21.875) r2: (train=1.000, test=0.409) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.720) neg_mean_squared_error: (train=-0.000, test=-21.176) r2: (train=1.000, test=0.447) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.919) neg_mean_squared_error: (train=-0.000, test=-14.408) r2: (train=1.000, test=0.488) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.541, test=-3.248) neg_mean_squared_error: (train=-10.952, test=-19.027) r2: (train=0.711, test=-0.451) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.279, test=-3.592) neg_mean_squared_error: (train=-8.616, test=-21.499) r2: (train=0.705, test=0.513) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.520, test=-4.046) neg_mean_squared_error: (train=-13.596, test=-28.635) r2: (train=0.570, test=0.226) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.419, test=-3.952) neg_mean_squared_error: (train=-11.373, test=-28.639) r2: (train=0.631, test=0.252) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, weights=uniform; neg_mean_absolute_error: (train=-2.639, test=-2.632) neg_mean_squared_error: (train=-10.750, test=-10.979) r2: (train=0.682, test=0.610) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.019) neg_mean_squared_error: (train=-0.000, test=-17.313) r2: (train=1.000, test=-0.320) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.393) neg_mean_squared_error: (train=-0.000, test=-20.282) r2: (train=1.000, test=0.541) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-25.025) r2: (train=1.000, test=0.324) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.655) neg_mean_squared_error: (train=-0.000, test=-22.727) r2: (train=1.000, test=0.406) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.285) neg_mean_squared_error: (train=-0.000, test=-9.384) r2: (train=1.000, test=0.667) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.858, test=-3.437) neg_mean_squared_error: (train=-12.528, test=-22.198) r2: (train=0.669, test=-0.693) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.706, test=-3.859) neg_mean_squared_error: (train=-13.139, test=-20.069) r2: (train=0.550, test=0.545) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.581, test=-4.311) neg_mean_squared_error: (train=-13.460, test=-30.275) r2: (train=0.574, test=0.182) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.847, test=-3.827) neg_mean_squared_error: (train=-15.601, test=-26.396) r2: (train=0.493, test=0.310) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, weights=uniform; neg_mean_absolute_error: (train=-2.903, test=-3.129) neg_mean_squared_error: (train=-14.474, test=-14.036) r2: (train=0.571, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.023) neg_mean_squared_error: (train=-0.000, test=-18.853) r2: (train=1.000, test=-0.438) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.458) neg_mean_squared_error: (train=-0.000, test=-16.750) r2: (train=1.000, test=0.621) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.030) neg_mean_squared_error: (train=-0.000, test=-27.224) r2: (train=1.000, test=0.264) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.622) neg_mean_squared_error: (train=-0.000, test=-23.053) r2: (train=1.000, test=0.398) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.557) neg_mean_squared_error: (train=-0.000, test=-10.116) r2: (train=1.000, test=0.641) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.141, test=-3.541) neg_mean_squared_error: (train=-15.718, test=-23.346) r2: (train=0.585, test=-0.780) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.874, test=-3.813) neg_mean_squared_error: (train=-14.650, test=-22.932) r2: (train=0.498, test=0.481) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.799, test=-4.540) neg_mean_squared_error: (train=-14.177, test=-32.405) r2: (train=0.551, test=0.124) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-2.703, test=-3.687) neg_mean_squared_error: (train=-13.821, test=-23.463) r2: (train=0.551, test=0.387) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=5, weights=uniform; neg_mean_absolute_error: (train=-3.194, test=-3.594) neg_mean_squared_error: (train=-16.672, test=-16.195) r2: (train=0.506, test=0.425) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.982) neg_mean_squared_error: (train=-0.000, test=-18.941) r2: (train=1.000, test=-0.444) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.501) neg_mean_squared_error: (train=-0.000, test=-19.738) r2: (train=1.000, test=0.553) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-4.111) neg_mean_squared_error: (train=-0.000, test=-28.126) r2: (train=1.000, test=0.240) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.435) neg_mean_squared_error: (train=-0.000, test=-21.189) r2: (train=1.000, test=0.446) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=5, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.779) neg_mean_squared_error: (train=-0.000, test=-11.332) r2: (train=1.000, test=0.597) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.148, test=-3.267) neg_mean_squared_error: (train=-15.704, test=-20.101) r2: (train=0.585, test=-0.533) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.927, test=-3.824) neg_mean_squared_error: (train=-14.553, test=-24.656) r2: (train=0.502, test=0.441) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.992, test=-4.089) neg_mean_squared_error: (train=-15.371, test=-26.621) r2: (train=0.514, test=0.280) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-2.673, test=-3.676) neg_mean_squared_error: (train=-12.857, test=-24.292) r2: (train=0.582, test=0.365) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=6, weights=uniform; neg_mean_absolute_error: (train=-3.262, test=-3.301) neg_mean_squared_error: (train=-16.675, test=-14.053) r2: (train=0.506, test=0.501) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.804) neg_mean_squared_error: (train=-0.000, test=-16.598) r2: (train=1.000, test=-0.266) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.455) neg_mean_squared_error: (train=-0.000, test=-20.768) r2: (train=1.000, test=0.530) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.834) neg_mean_squared_error: (train=-0.000, test=-24.436) r2: (train=1.000, test=0.339) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.438) neg_mean_squared_error: (train=-0.000, test=-21.787) r2: (train=1.000, test=0.431) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=6, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.710) neg_mean_squared_error: (train=-0.000, test=-11.432) r2: (train=1.000, test=0.594) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.308, test=-3.596) neg_mean_squared_error: (train=-17.094, test=-20.583) r2: (train=0.548, test=-0.569) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.978, test=-3.932) neg_mean_squared_error: (train=-14.762, test=-26.627) r2: (train=0.495, test=0.397) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.048, test=-3.784) neg_mean_squared_error: (train=-16.050, test=-22.170) r2: (train=0.492, test=0.401) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-2.764, test=-3.668) neg_mean_squared_error: (train=-13.739, test=-23.609) r2: (train=0.554, test=0.383) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=7, weights=uniform; neg_mean_absolute_error: (train=-3.173, test=-3.181) neg_mean_squared_error: (train=-15.923, test=-13.272) r2: (train=0.528, test=0.528) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.928) neg_mean_squared_error: (train=-0.000, test=-16.104) r2: (train=1.000, test=-0.228) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.544) neg_mean_squared_error: (train=-0.000, test=-22.410) r2: (train=1.000, test=0.492) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.651) neg_mean_squared_error: (train=-0.000, test=-21.817) r2: (train=1.000, test=0.410) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.427) neg_mean_squared_error: (train=-0.000, test=-21.078) r2: (train=1.000, test=0.449) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=7, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.682) neg_mean_squared_error: (train=-0.000, test=-11.113) r2: (train=1.000, test=0.605) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.390, test=-3.718) neg_mean_squared_error: (train=-18.209, test=-20.917) r2: (train=0.519, test=-0.595) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.220, test=-4.003) neg_mean_squared_error: (train=-16.669, test=-27.993) r2: (train=0.429, test=0.366) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.102, test=-3.603) neg_mean_squared_error: (train=-16.097, test=-22.064) r2: (train=0.491, test=0.404) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.016, test=-3.428) neg_mean_squared_error: (train=-15.562, test=-22.095) r2: (train=0.494, test=0.423) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=8, weights=uniform; neg_mean_absolute_error: (train=-3.316, test=-3.345) neg_mean_squared_error: (train=-17.722, test=-14.867) r2: (train=0.475, test=0.472) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.965) neg_mean_squared_error: (train=-0.000, test=-15.566) r2: (train=1.000, test=-0.187) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.491) neg_mean_squared_error: (train=-0.000, test=-22.684) r2: (train=1.000, test=0.486) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.536) neg_mean_squared_error: (train=-0.000, test=-21.290) r2: (train=1.000, test=0.424) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.271) neg_mean_squared_error: (train=-0.000, test=-19.744) r2: (train=1.000, test=0.484) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=8, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.749) neg_mean_squared_error: (train=-0.000, test=-11.615) r2: (train=1.000, test=0.587) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.365, test=-3.563) neg_mean_squared_error: (train=-18.857, test=-19.320) r2: (train=0.502, test=-0.473) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.200, test=-4.364) neg_mean_squared_error: (train=-17.299, test=-34.211) r2: (train=0.408, test=0.225) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.174, test=-3.523) neg_mean_squared_error: (train=-17.049, test=-23.514) r2: (train=0.461, test=0.364) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.082, test=-3.454) neg_mean_squared_error: (train=-16.459, test=-22.190) r2: (train=0.465, test=0.420) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=9, weights=uniform; neg_mean_absolute_error: (train=-3.361, test=-3.338) neg_mean_squared_error: (train=-18.504, test=-15.034) r2: (train=0.452, test=0.466) total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.929) neg_mean_squared_error: (train=-0.000, test=-14.931) r2: (train=1.000, test=-0.138) total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.718) neg_mean_squared_error: (train=-0.000, test=-26.442) r2: (train=1.000, test=0.401) total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.441) neg_mean_squared_error: (train=-0.000, test=-21.753) r2: (train=1.000, test=0.412) total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-3.279) neg_mean_squared_error: (train=-0.000, test=-19.509) r2: (train=1.000, test=0.490) total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=9, weights=distance; neg_mean_absolute_error: (train=-0.000, test=-2.751) neg_mean_squared_error: (train=-0.000, test=-11.576) r2: (train=1.000, test=0.589) total time=   0.0s
# MAE: 3.271339916299843
# MAPE: 0.04329365261555481

# %% [markdown]
# Visualize the predicting result:

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %% [markdown]
# #### (3.6) Gaussian process model

# %%
model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)

#Now we use scikit learn to train a random forest model using k-fold cross validation and grid search to find the best model with hyperparameters tunned
model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
model_search.fit(X_train, y_train)
model = model_search.best_estimator_

#And make predictions on the test set
y_pred = model.predict(X_test)
#Let's examine the mean absolute error and mean absolute percentage error
mae6 = mean_absolute_error(y_test, y_pred)
mape6 = mean_absolute_percentage_error(y_test, y_pred)

print('MAE:', mae6)
print('MAPE:', mape6)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-1.999) neg_mean_squared_error: (train=-0.000, test=-12.839) r2: (train=1.000, test=0.021) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-3.921) neg_mean_squared_error: (train=-0.000, test=-28.334) r2: (train=1.000, test=0.358) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.650) neg_mean_squared_error: (train=-0.000, test=-12.379) r2: (train=1.000, test=0.665) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.582) neg_mean_squared_error: (train=-0.000, test=-9.409) r2: (train=1.000, test=0.754) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.490) neg_mean_squared_error: (train=-0.000, test=-9.387) r2: (train=1.000, test=0.666) total time=   0.0s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.002, test=-1.723) neg_mean_squared_error: (train=-0.000, test=-9.035) r2: (train=1.000, test=0.311) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.001, test=-2.224) neg_mean_squared_error: (train=-0.000, test=-11.107) r2: (train=1.000, test=0.748) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.001, test=-1.592) neg_mean_squared_error: (train=-0.000, test=-5.489) r2: (train=1.000, test=0.852) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.001, test=-2.340) neg_mean_squared_error: (train=-0.000, test=-8.438) r2: (train=1.000, test=0.779) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.001, test=-1.514) neg_mean_squared_error: (train=-0.000, test=-4.714) r2: (train=1.000, test=0.833) total time=   0.0s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.002, test=-1.762) neg_mean_squared_error: (train=-0.000, test=-11.176) r2: (train=1.000, test=0.148) total time=   0.1s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-3.490) neg_mean_squared_error: (train=-0.000, test=-21.990) r2: (train=1.000, test=0.502) total time=   0.1s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.650) neg_mean_squared_error: (train=-0.000, test=-12.379) r2: (train=1.000, test=0.665) total time=   0.2s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.456) neg_mean_squared_error: (train=-0.000, test=-9.398) r2: (train=1.000, test=0.754) total time=   0.1s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.001, test=-2.137) neg_mean_squared_error: (train=-0.000, test=-7.459) r2: (train=1.000, test=0.735) total time=   0.2s
# [CV 1/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.002, test=-1.999) neg_mean_squared_error: (train=-0.000, test=-12.839) r2: (train=1.000, test=0.021) total time=   0.0s
# [CV 2/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-5.477) neg_mean_squared_error: (train=-0.000, test=-47.380) r2: (train=1.000, test=-0.073) total time=   0.0s
# [CV 3/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.001, test=-2.650) neg_mean_squared_error: (train=-0.000, test=-12.379) r2: (train=1.000, test=0.665) total time=   0.0s
# [CV 4/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-4.970) neg_mean_squared_error: (train=-0.000, test=-40.861) r2: (train=1.000, test=-0.068) total time=   0.0s
# [CV 5/5] END alpha=0.0001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.000, test=-4.366) neg_mean_squared_error: (train=-0.000, test=-28.264) r2: (train=1.000, test=-0.004) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.019, test=-2.002) neg_mean_squared_error: (train=-0.001, test=-12.589) r2: (train=1.000, test=0.040) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.008, test=-3.928) neg_mean_squared_error: (train=-0.000, test=-28.346) r2: (train=1.000, test=0.358) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.011, test=-2.657) neg_mean_squared_error: (train=-0.000, test=-12.429) r2: (train=1.000, test=0.664) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.009, test=-2.581) neg_mean_squared_error: (train=-0.000, test=-9.398) r2: (train=1.000, test=0.754) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.008, test=-2.486) neg_mean_squared_error: (train=-0.000, test=-9.361) r2: (train=1.000, test=0.667) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.018, test=-1.694) neg_mean_squared_error: (train=-0.001, test=-8.789) r2: (train=1.000, test=0.330) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.015, test=-2.242) neg_mean_squared_error: (train=-0.001, test=-11.263) r2: (train=1.000, test=0.745) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.013, test=-1.584) neg_mean_squared_error: (train=-0.000, test=-5.402) r2: (train=1.000, test=0.854) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.010, test=-2.329) neg_mean_squared_error: (train=-0.000, test=-8.361) r2: (train=1.000, test=0.781) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.011, test=-1.471) neg_mean_squared_error: (train=-0.000, test=-4.585) r2: (train=1.000, test=0.837) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.019, test=-1.724) neg_mean_squared_error: (train=-0.001, test=-10.868) r2: (train=1.000, test=0.171) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.007, test=-3.491) neg_mean_squared_error: (train=-0.000, test=-21.951) r2: (train=1.000, test=0.503) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.011, test=-2.657) neg_mean_squared_error: (train=-0.000, test=-12.429) r2: (train=1.000, test=0.664) total time=   0.1s
# [CV 4/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.009, test=-2.454) neg_mean_squared_error: (train=-0.000, test=-9.373) r2: (train=1.000, test=0.755) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.008, test=-2.131) neg_mean_squared_error: (train=-0.000, test=-7.431) r2: (train=1.000, test=0.736) total time=   0.0s
# [CV 1/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.005, test=-2.978) neg_mean_squared_error: (train=-0.000, test=-13.347) r2: (train=1.000, test=-0.018) total time=   0.0s
# [CV 2/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-5.477) neg_mean_squared_error: (train=-0.000, test=-47.380) r2: (train=1.000, test=-0.073) total time=   0.0s
# [CV 3/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-4.379) neg_mean_squared_error: (train=-0.000, test=-36.995) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 4/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-4.970) neg_mean_squared_error: (train=-0.000, test=-40.861) r2: (train=1.000, test=-0.068) total time=   0.0s
# [CV 5/5] END alpha=0.001, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.004, test=-4.366) neg_mean_squared_error: (train=-0.000, test=-28.264) r2: (train=1.000, test=-0.004) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.160, test=-2.147) neg_mean_squared_error: (train=-0.052, test=-10.942) r2: (train=0.999, test=0.166) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.071, test=-3.963) neg_mean_squared_error: (train=-0.012, test=-27.972) r2: (train=1.000, test=0.366) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.097, test=-2.655) neg_mean_squared_error: (train=-0.021, test=-12.424) r2: (train=0.999, test=0.664) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.088, test=-2.581) neg_mean_squared_error: (train=-0.017, test=-9.326) r2: (train=0.999, test=0.756) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-0.079, test=-2.436) neg_mean_squared_error: (train=-0.013, test=-9.037) r2: (train=1.000, test=0.679) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.160, test=-1.644) neg_mean_squared_error: (train=-0.048, test=-6.978) r2: (train=0.999, test=0.468) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.150, test=-2.382) neg_mean_squared_error: (train=-0.057, test=-12.118) r2: (train=0.998, test=0.725) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.139, test=-1.677) neg_mean_squared_error: (train=-0.042, test=-5.232) r2: (train=0.999, test=0.859) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.125, test=-1.935) neg_mean_squared_error: (train=-0.038, test=-5.456) r2: (train=0.999, test=0.857) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.127, test=-1.290) neg_mean_squared_error: (train=-0.039, test=-3.860) r2: (train=0.999, test=0.863) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.155, test=-1.627) neg_mean_squared_error: (train=-0.047, test=-8.432) r2: (train=0.999, test=0.357) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.069, test=-3.509) neg_mean_squared_error: (train=-0.011, test=-21.700) r2: (train=1.000, test=0.508) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.097, test=-2.655) neg_mean_squared_error: (train=-0.021, test=-12.424) r2: (train=0.999, test=0.664) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.084, test=-2.434) neg_mean_squared_error: (train=-0.015, test=-9.195) r2: (train=1.000, test=0.760) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-0.079, test=-2.076) neg_mean_squared_error: (train=-0.014, test=-7.121) r2: (train=1.000, test=0.747) total time=   0.0s
# [CV 1/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.048, test=-3.214) neg_mean_squared_error: (train=-0.004, test=-15.110) r2: (train=1.000, test=-0.152) total time=   0.0s
# [CV 2/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.041, test=-5.477) neg_mean_squared_error: (train=-0.003, test=-47.380) r2: (train=1.000, test=-0.073) total time=   0.0s
# [CV 3/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.044, test=-4.379) neg_mean_squared_error: (train=-0.003, test=-36.995) r2: (train=1.000, test=-0.000) total time=   0.0s
# [CV 4/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.043, test=-4.970) neg_mean_squared_error: (train=-0.003, test=-40.861) r2: (train=1.000, test=-0.068) total time=   0.0s
# [CV 5/5] END alpha=0.01, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-0.044, test=-4.366) neg_mean_squared_error: (train=-0.003, test=-28.264) r2: (train=1.000, test=-0.004) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.317, test=-1.338) neg_mean_squared_error: (train=-3.182, test=-3.095) r2: (train=0.916, test=0.764) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.073, test=-1.939) neg_mean_squared_error: (train=-2.295, test=-6.444) r2: (train=0.921, test=0.854) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.138, test=-1.617) neg_mean_squared_error: (train=-2.465, test=-5.624) r2: (train=0.922, test=0.848) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.063, test=-1.821) neg_mean_squared_error: (train=-2.365, test=-6.728) r2: (train=0.923, test=0.824) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-1.238, test=-1.479) neg_mean_squared_error: (train=-2.957, test=-3.362) r2: (train=0.912, test=0.881) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-1.201, test=-1.339) neg_mean_squared_error: (train=-2.600, test=-3.755) r2: (train=0.931, test=0.714) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.854, test=-2.014) neg_mean_squared_error: (train=-1.648, test=-6.319) r2: (train=0.944, test=0.857) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.966, test=-1.636) neg_mean_squared_error: (train=-1.858, test=-5.647) r2: (train=0.941, test=0.847) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-0.996, test=-1.815) neg_mean_squared_error: (train=-2.025, test=-6.279) r2: (train=0.934, test=0.836) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-1.062, test=-1.272) neg_mean_squared_error: (train=-2.231, test=-2.677) r2: (train=0.934, test=0.905) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.334, test=-1.323) neg_mean_squared_error: (train=-3.241, test=-3.114) r2: (train=0.914, test=0.763) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.072, test=-1.953) neg_mean_squared_error: (train=-2.321, test=-6.429) r2: (train=0.921, test=0.854) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.155, test=-1.671) neg_mean_squared_error: (train=-2.538, test=-5.943) r2: (train=0.920, test=0.839) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.074, test=-1.816) neg_mean_squared_error: (train=-2.384, test=-6.685) r2: (train=0.923, test=0.825) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-1.243, test=-1.482) neg_mean_squared_error: (train=-2.975, test=-3.358) r2: (train=0.912, test=0.881) total time=   0.0s
# [CV 1/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.327, test=-1.329) neg_mean_squared_error: (train=-3.216, test=-3.101) r2: (train=0.915, test=0.764) total time=   0.0s
# [CV 2/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.237, test=-3.331) neg_mean_squared_error: (train=-10.206, test=-19.904) r2: (train=0.651, test=0.549) total time=   0.0s
# [CV 3/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.145, test=-1.656) neg_mean_squared_error: (train=-2.499, test=-5.853) r2: (train=0.921, test=0.842) total time=   0.0s
# [CV 4/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.070, test=-1.817) neg_mean_squared_error: (train=-2.378, test=-6.695) r2: (train=0.923, test=0.825) total time=   0.0s
# [CV 5/5] END alpha=0.1, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-1.242, test=-1.479) neg_mean_squared_error: (train=-2.970, test=-3.358) r2: (train=0.912, test=0.881) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.983, test=-2.605) neg_mean_squared_error: (train=-15.747, test=-10.590) r2: (train=0.584, test=0.192) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.824, test=-4.254) neg_mean_squared_error: (train=-14.832, test=-31.040) r2: (train=0.492, test=0.297) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.713, test=-3.176) neg_mean_squared_error: (train=-13.712, test=-22.407) r2: (train=0.566, test=0.394) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-2.686, test=-3.714) neg_mean_squared_error: (train=-13.752, test=-22.498) r2: (train=0.553, test=0.412) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * RBF(length_scale=1); neg_mean_absolute_error: (train=-3.040, test=-2.824) neg_mean_squared_error: (train=-16.248, test=-13.848) r2: (train=0.519, test=0.508) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.994, test=-2.589) neg_mean_squared_error: (train=-16.399, test=-10.568) r2: (train=0.567, test=0.194) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.765, test=-4.254) neg_mean_squared_error: (train=-14.488, test=-32.122) r2: (train=0.504, test=0.272) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.735, test=-3.152) neg_mean_squared_error: (train=-14.136, test=-22.400) r2: (train=0.553, test=0.395) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-2.699, test=-3.616) neg_mean_squared_error: (train=-14.112, test=-22.500) r2: (train=0.542, test=0.412) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * Matern(length_scale=1, nu=1.5); neg_mean_absolute_error: (train=-3.021, test=-2.864) neg_mean_squared_error: (train=-16.569, test=-14.225) r2: (train=0.509, test=0.495) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.983, test=-2.605) neg_mean_squared_error: (train=-15.747, test=-10.590) r2: (train=0.584, test=0.192) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.809, test=-4.241) neg_mean_squared_error: (train=-14.728, test=-31.123) r2: (train=0.496, test=0.295) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.713, test=-3.176) neg_mean_squared_error: (train=-13.712, test=-22.407) r2: (train=0.566, test=0.394) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-2.686, test=-3.714) neg_mean_squared_error: (train=-13.752, test=-22.499) r2: (train=0.553, test=0.412) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * RationalQuadratic(alpha=0.1, length_scale=1); neg_mean_absolute_error: (train=-3.040, test=-2.824) neg_mean_squared_error: (train=-16.248, test=-13.848) r2: (train=0.519, test=0.508) total time=   0.0s
# [CV 1/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.983, test=-2.605) neg_mean_squared_error: (train=-15.747, test=-10.590) r2: (train=0.584, test=0.192) total time=   0.0s
# [CV 2/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.824, test=-4.254) neg_mean_squared_error: (train=-14.832, test=-31.042) r2: (train=0.492, test=0.297) total time=   0.0s
# [CV 3/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.713, test=-3.176) neg_mean_squared_error: (train=-13.712, test=-22.407) r2: (train=0.566, test=0.394) total time=   0.0s
# [CV 4/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-2.686, test=-3.714) neg_mean_squared_error: (train=-13.752, test=-22.498) r2: (train=0.553, test=0.412) total time=   0.0s
# [CV 5/5] END alpha=1.0, kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1); neg_mean_absolute_error: (train=-3.040, test=-2.824) neg_mean_squared_error: (train=-16.251, test=-13.850) r2: (train=0.519, test=0.508) total time=   0.0s
# MAE: 1.5999132065279351
# MAPE: 0.021663451346374426

# %%
plt.figure()
plt.scatter(y_pred, y_test)
plt.plot([50,120], [50,120], color='C1')
plt.xlabel('Predicted relative SOC drop (%)')
plt.ylabel('Real relative SOC drop (%)')
plt.show()

# %% [markdown]
# #### (3.7) Summary
# Compare the mean absolute percent error of each regression method. Each method is repeated 10 times by random train and test data, and average mean absolute percent errors are taken in order to make the results more general.

# %%
mape_t=np.zeros((10,6))
original_stdout = sys.stdout

for i in tqdm(range(10)):
    sys.stdout = open(os.devnull, 'w')
    
    mape=[]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    model = DecisionTreeRegressor()
    skf = KFold(n_splits=5, random_state=10, shuffle=True)
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    model = ExtraTreeRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    model = RandomForestRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    model = KNeighborsRegressor()
    model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)
    model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
    model_search.fit(X_train, y_train)
    model = model_search.best_estimator_
    y_pred = model.predict(X_test)
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

    mape_t[i]=mape
    sys.stdout = original_stdout

plt.figure(figsize = (10, 6))
bars=plt.bar(['Linear','Decision tree','Extremely \nrandomrized tree','Random forest','k-nearest \nneighbors','Gaussian process'],np.mean(mape_t,axis=0)*100,width = 0.5)
plt.xlabel("Regression methods")
plt.ylabel("Mean absolute percent error")
plt.ylim([0,10])
plt.bar_label(bars, fmt='%.4f%%')
plt.show()

# %% [markdown]
# ### 4. Benchmark how many seconds of data used for featurization affect the accuracy of prediction of SOC at 800 seconds

# %% [markdown]
# In this part, we will first obtain the SOC of all the time series data at 800 seconds. Then, we will cut all the data to 300 ~ $x$ seconds, and extract features from the already cut data. After that, we will use these features to predict the SOC at 800 seconds using different regression methods. We will increase $x$ from 325 to 800, with increments of 25, and observe the accuracy of prediction (mean absolute percent error) when $x$ is increasing. We will run the test for 10 times and take the average to ensure the accuracy of the result. The x axis of the plots will be calculated as (x-300) seconds.

# %%
def curve_plot(mape_t, label, color):
    # Calculate mean and standard error
    mean_mape = np.mean(mape_t, axis=0)
    std_error = np.std(mape_t, axis=0) / np.sqrt(mape_t.shape[0])

    # Calculate confidence interval
    confidence = 0.95
    n = mape_t.shape[0]
    t = np.abs(stats.t.ppf((1 - confidence) / 2, n - 1))
    margin_of_error = t * std_error
    confidence_interval = margin_of_error

    plt.plot(np.arange(25, 501, 25), mean_mape * 100, label = label, color = color)
    plt.fill_between(np.arange(25, 501, 25), (mean_mape - confidence_interval) * 100, (mean_mape + confidence_interval) * 100, alpha = 0.2, color = tuple(np.array(color) / 2))

# %%
def features_ext(dict):
    end_volts_arr = []
    med_curr_arr = []
    min_dvdt_arr = []
    curr_rise_arr = []
    soc_cc_arr = []
    
    for key in dict.keys():
        # End Voltage
        end_volts = dict[key]['Voltage (V)'].iloc[-1]
        end_volts_arr.append(end_volts)

        # Median Current
        med_curr = dict[key]['Current (A)'].median()
        med_curr_arr.append(med_curr)

        # Min dV/dt
        min_dvdt = dict[key]['dV/dt (V/s)'].min()
        min_dvdt_arr.append(min_dvdt)

        # Total Current Rise
        curr_rise = currdrop_sum(dict[key])
        curr_rise_arr.append(curr_rise)

        # SOC Drop
        discharge = dis_cap_drop(dict[key])
        soc_cc = (discharge / 3) * 100
        soc_cc_arr.append(soc_cc)

    info_data_2['End Voltage(V)'] = end_volts_arr
    info_data_2['Median Current(A)'] = med_curr_arr
    info_data_2['Min dV/dt'] = min_dvdt_arr
    info_data_2['Total Current Rise'] = curr_rise_arr
    info_data_2['SOC_drop (%)'] = soc_cc_arr
    info_data_2['Relative_SOC_drop'] = (((info_data_2['SOC_drop (%)'] - relative_soc) / relative_soc) + 1) * 100

    return info_data_2

# %%
def features_ext_test(dict_test):
    end_volts_arr = []
    med_curr_arr = []
    min_dvdt_arr = []
    curr_rise_arr = []
    soc_cc_arr = []

    for key in dict_test.keys():
        # End Voltage
        end_volts = dict_test[key]['Voltage (V)'].iloc[-1]
        end_volts_arr.append(end_volts)
        
        # Median Current
        med_curr = dict_test[key]['Current (A)'].median()
        med_curr_arr.append(med_curr)
        
        # Min dV/dt
        min_dvdt = dict_test[key]['dV/dt (V/s)'].min()
        min_dvdt_arr.append(min_dvdt)
        
        # Total Current Rise
        curr_rise = currdrop_sum(dict_test[key])
        curr_rise_arr.append(curr_rise)
        
        # Relative_SOC_drop
        discharge = dis_cap_drop(dict_test[key])
        soc_cc = (discharge / 3) * 100
        soc_cc_arr.append(soc_cc)
    
    info_data_test['End Voltage(V)'] = end_volts_arr
    info_data_test['Median Current(A)'] = med_curr_arr
    info_data_test['Min dV/dt'] = min_dvdt_arr
    info_data_test['Total Current Rise'] = curr_rise_arr
    info_data_test['SOC_drop (%)'] = soc_cc_arr
    info_data_test['Relative_SOC_drop'] = (((info_data_test['SOC_drop (%)'] - relative_soc) / relative_soc) + 1) * 100
    
    return info_data_test

# %%
iteration = 10

mape_t1 = np.zeros((iteration, 20))
mape_t2 = np.zeros((iteration, 20))
mape_t3 = np.zeros((iteration, 20))
mape_t4 = np.zeros((iteration, 20))
mape_t5 = np.zeros((iteration, 20))
mape_t6 = np.zeros((iteration, 20))
mape_test_t1 = np.zeros((iteration, 20))
mape_test_t2 = np.zeros((iteration, 20))
mape_test_t3 = np.zeros((iteration, 20))
mape_test_t4 = np.zeros((iteration, 20))
mape_test_t5 = np.zeros((iteration, 20))
mape_test_t6 = np.zeros((iteration, 20))
original_stdout = sys.stdout

cut_dict = {}
data_list = []
for key in dict.keys():
    datafr = cut_time(dict[key], 300, 800)
    data_list.append(datafr)
cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

cut_data = features_ext(cut_dict)

number_of_tests = np.shape(cut_data.values)[0]
y = np.zeros(number_of_tests)

for i in range(number_of_tests):
    y[i] = cut_data['Relative_SOC_drop'][i]

cut_dict = {}
data_list = []
for key in dict_test.keys():
    datafr = cut_time(dict_test[key], 300, 800)
    data_list.append(datafr)
cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

cut_data = features_ext_test(cut_dict)

number_of_tests = np.shape(cut_data.values)[0]
y_test2 = np.zeros(number_of_tests)

for i in range(number_of_tests):
    y_test2[i] = cut_data['Relative_SOC_drop'][i]

for ii in tqdm(range(iteration)):
    mape1 = []
    mape2 = []
    mape3 = []
    mape4 = []
    mape5 = []
    mape6 = []
    mape_test_1 = []
    mape_test_2 = []
    mape_test_3 = []
    mape_test_4 = []
    mape_test_5 = []
    mape_test_6 = []

    for kk in range(325, 801, 25):
        sys.stdout = open(os.devnull, 'w')

        cut_dict = {}
        data_list = []
        for key in dict.keys():
            datafr = cut_time(dict[key], 300, kk)
            data_list.append(datafr)
        cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

        cut_data = features_ext(cut_dict)

        number_of_tests = np.shape(cut_data.values)[0]
        X = np.zeros((number_of_tests, 4))

        for i in range(number_of_tests):
            X[i, 0] = cut_data['End Voltage(V)'][i]
            X[i, 1] = cut_data['Median Current(A)'][i]
            X[i, 2] = cut_data['Min dV/dt'][i]
            X[i, 3] = cut_data['Total Current Rise'][i]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        cut_dict = {}
        data_list = []
        for key in dict_test.keys():
            datafr = cut_time(dict_test[key], 300, kk)
            data_list.append(datafr)
        cut_dict = {f'Minitrip{i+1}': dataf for i, dataf in enumerate(data_list)}

        cut_data = features_ext_test(cut_dict)

        number_of_tests = np.shape(cut_data.values)[0]
        X_test2 = np.zeros((number_of_tests, 4))

        for i in range(number_of_tests):
            X_test2[i, 0] = cut_data['End Voltage(V)'][i]
            X_test2[i, 1] = cut_data['Median Current(A)'][i]
            X_test2[i, 2] = cut_data['Min dV/dt'][i]
            X_test2[i, 3] = cut_data['Total Current Rise'][i]
        
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mape1.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_1.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = DecisionTreeRegressor()
        skf = KFold(n_splits=5, random_state=10, shuffle=True)
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape2.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_2.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = ExtraTreeRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape3.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_3.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = RandomForestRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 'max_depth':np.arange(2,10)}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape4.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_4.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = KNeighborsRegressor()
        model_search = GridSearchCV(estimator=model, param_grid={'n_neighbors':np.arange(2,10), 'weights':['uniform', 'distance'], 'algorithm':['ball_tree', 'kd_tree', 'brute']}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape5.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_5.append(mean_absolute_percentage_error(y_test2, y_pred2))

        model = GaussianProcessRegressor(n_restarts_optimizer=5,normalize_y=True, random_state=0)
        model_search = GridSearchCV(estimator=model, param_grid={'kernel': [1.0*RBF(length_scale=1),1.0*Matern(length_scale=1.0, nu=1.5),1.0*RationalQuadratic(alpha=0.1, length_scale=1.0),1.0*ExpSineSquared(length_scale=1.0, periodicity=1.0)], 'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1.0]}, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'], cv=skf, refit='neg_mean_absolute_error', verbose=3, return_train_score=True)
        model_search.fit(X_train, y_train)
        model = model_search.best_estimator_
        y_pred = model.predict(X_test)
        mape6.append(mean_absolute_percentage_error(y_test, y_pred))
        y_pred2 = model.predict(X_test2)
        mape_test_6.append(mean_absolute_percentage_error(y_test2, y_pred2))

        sys.stdout = original_stdout
        original_stdout.close()

    mape_t1[ii] = mape1
    mape_t2[ii] = mape2
    mape_t3[ii] = mape3
    mape_t4[ii] = mape4
    mape_t5[ii] = mape5
    mape_t6[ii] = mape6
    mape_test_t1[ii] = mape_test_1
    mape_test_t2[ii] = mape_test_2
    mape_test_t3[ii] = mape_test_3
    mape_test_t4[ii] = mape_test_4
    mape_test_t5[ii] = mape_test_5
    mape_test_t6[ii] = mape_test_6

# Saving for replotting
np.save('plot1.npy', [mape_t1, mape_t2, mape_t3, mape_t4, mape_t5, mape_t6, mape_test_t1, mape_test_t2, mape_test_t3, mape_test_t4, mape_test_t5, mape_test_t6])
# Out:
# 100%|██████████| 10/10 [1:13:08<00:00, 438.90s/it]

# %%
plt.figure(figsize=(10, 6))

curve_plot(mape_t1, 'Linear model', (230/255, 25/255, 75/255))
curve_plot(mape_t2, 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(mape_t3, 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(mape_t4, 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(mape_t5, 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(mape_t6, 'Gaussian process model', (0/255, 130/255, 200/255))

plt.xlabel("Number of seconds of data used for featurization (sec)")
plt.ylabel("Mean absolute percent error of relative SOC drop (%)")
plt.legend()
plt.show()

# %% [markdown]
# **We also add new 12 test data in addition to the original 96 test results and check the performance of the models using them.**

# %%
plt.figure(figsize=(10, 6))

curve_plot(mape_test_t1, 'Linear model', (230/255, 25/255, 75/255))
curve_plot(mape_test_t2, 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(mape_test_t3, 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(mape_test_t4, 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(mape_test_t5, 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(mape_test_t6, 'Gaussian process model', (0/255, 130/255, 200/255))

plt.xlabel("Number of seconds of data used for featurization (sec)")
plt.ylabel("Mean absolute percent error of relative SOC drop (%)")
plt.legend()
plt.show()

# %% [markdown]
# #### ***Replotting

# %%
def curve_plot(mape_t, label, color):
    # Calculate mean and standard error
    mean_mape = np.mean(mape_t, axis=0)
    std_error = np.std(mape_t, axis=0) / np.sqrt(mape_t.shape[0])

    # Calculate confidence interval
    confidence = 0.95
    n = mape_t.shape[0]
    t = np.abs(stats.t.ppf((1 - confidence) / 2, n - 1))
    margin_of_error = t * std_error
    confidence_interval = margin_of_error

    plt.plot(np.arange(25/5, 501/5, 25/5), mean_mape * 100, label = label, color = color)
    plt.fill_between(np.arange(25/5, 501/5, 25/5), (mean_mape - confidence_interval) * 100, (mean_mape + confidence_interval) * 100, alpha = 0.2, color = tuple(np.array(color) / 2))

# %%
plot1 = np.load('plot1.npy')
plt.figure(figsize = (13/2.54, 6/2.54))
curve_plot(plot1[0], 'Linear model', (230/255, 25/255, 75/255))
curve_plot(plot1[1], 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(plot1[2], 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(plot1[3], 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(plot1[4], 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(plot1[5], 'Gaussian process model', (0/255, 130/255, 200/255))
plt.tick_params(axis='x', labelfontfamily='Arial', labelsize=7)
plt.tick_params(axis='y', labelfontfamily='Arial', labelsize=7)
plt.xlabel("Percentage trip completed from 300 seconds to 800 seconds (%)", fontname='Arial', fontsize=7)
plt.ylabel("Mean absolute percent error \nof relative SOC drop (%)", fontname='Arial', fontsize=7)
# plt.title("Prediction on the 20% test set of \nthe original 96 time-series data", fontname='Arial', fontsize=9)
plt.xlim((25/5, 501/5))
plt.rc('legend', fontsize=7)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'family': 'Arial'})
plt.tight_layout()
plt.savefig('plot1.png', format='png', dpi=1000)
plt.show()

# %%
plt.figure(figsize = (13/2.54, 6/2.54))
curve_plot(plot1[6], 'Linear model', (230/255, 25/255, 75/255))
curve_plot(plot1[7], 'Decision tree model', (245/255, 130/255, 48/255))
curve_plot(plot1[8], 'Extremely randomrized tree model', (255/255, 225/255, 25/255))
curve_plot(plot1[9], 'Random forest model', (60/255, 180/255, 75/255))
curve_plot(plot1[10], 'k-nearest neighbors model', (70/255, 240/255, 240/255))
curve_plot(plot1[11], 'Gaussian process model', (0/255, 130/255, 200/255))
plt.tick_params(axis='x', labelfontfamily='Arial', labelsize=7)
plt.tick_params(axis='y', labelfontfamily='Arial', labelsize=7)
plt.xlabel("Percentage trip completed from 300 seconds to 800 seconds (%)", fontname='Arial', fontsize=7)
plt.ylabel("Mean absolute percent error \nof relative SOC drop (%)", fontname='Arial', fontsize=7)
# plt.title("Prediction on the new 12 test data", fontname='Arial', fontsize=9)
plt.xlim((25/5, 501/5))
plt.rc('legend', fontsize=7)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'family': 'Arial'})
plt.tight_layout()
plt.savefig('plot2.png', format='png', dpi=1000)
plt.show()
